# %%
import os
import re
from langdetect import detect
import shutil
import pandas as pd

# %%
def read_report(filepath, filename):
    with open(os.path.join(filepath, filename), mode="r", encoding="utf-8") as f:
        report = f.read()
    return report

def write_report(filepath, filename, data):
    with open(os.path.join(filepath, filename), mode="w", encoding="utf-8") as f:
        f.write(data)

def find_failed_reports(data_path, failure_message):
    failed = []
    failed_urls = []
    for folder in os.listdir(data_path):
        folderpath = os.path.join(data_path, folder)
        for ref in os.listdir(folderpath):
            filepath = os.path.join(data_path, folder)
            report = read_report(filepath, ref)
            url = re.findall(r'https?://\S+', report)[0]
            if failure_message in report:
                failed_ref = folder + "-" + str(ref)
                failed.append(failed_ref)
                failed_urls.append(url)
            else:
                continue
    return failed, failed_urls

def seperate_non_english_reports(raw_data_path, language):
    folders_to_be_copied = []
    # Find non english reports and translate them
    for folder in os.listdir(raw_data_path):
        if folder in ["korean", "russian"]:
            continue
        folderpath = os.path.join(raw_data_path, folder)
        for ref in os.listdir(folderpath):
            report = read_report(folderpath, ref)
            # Split text into sentences (or use any other method)
            sentences = re.split(r'(?<=[.!?]) +', report)
            non_english = []
            for sentence in sentences:
                try:
                    lang = detect(sentence)
                    if lang == language:
                        non_english.append((sentence, lang))
                except:
                    break
            if non_english:
                folders_to_be_copied.append(folder)

    if language=="ko":
        language = "korean"
    elif language=="ru":
        language = "russian"

    folders_to_be_copied = list(set(folders_to_be_copied))

    if folders_to_be_copied:
        os.mkdir(os.path.join(raw_data_path, language))
    
    for f in folders_to_be_copied:
        shutil.copytree(os.path.join(raw_data_path, f),
                        os.path.join(raw_data_path, language, f))
        
def move_to_failed(data_path, report_type, failure_message):

    failed_path = os.path.join(data_path, "failed")
    failed_dest_path = os.path.join(failed_path, report_type)

    if not os.path.exists(failed_path):
        os.mkdir(failed_path)

    if not os.path.exists(failed_dest_path):
        os.mkdir(failed_dest_path)

    if report_type:
        data_source_path = os.path.join(data_path, report_type)
    else:
        raise Exception("Provide a correct report_type ('raw' or 'alienvault')")

    for report_name in os.listdir(data_source_path):
        folderpath = os.path.join(data_source_path, report_name)
        OK = 0
        for ref in os.listdir(folderpath):
            report = read_report(folderpath, ref)
            # Keep only valid reports
            if failure_message in report:
                continue
            else:
                OK += 1
        
        if not OK:
            src = os.path.join(data_source_path, report_name)
            dst = os.path.join(failed_dest_path, report_name)
            shutil.copytree(src=src,
                            dst=dst)
            shutil.rmtree(src)

def combine_results(formatted_data_path, failure_message, non_english_languages_in_reports):
    # Iterate over raw reports
    for report_name in os.listdir(formatted_data_path):
        if folderpath in non_english_languages_in_reports:
            continue
        folderpath = os.path.join(formatted_data_path, report_name)
        report_doc = ""
        # Iterate over refs of reports
        for filename in os.listdir(folderpath):
            ref = read_report(folderpath, filename)
            if failure_message in ref:
                continue
            elif "# Image URLs #" in ref:
                ref = ref.split("# Image URLs #")[0]
                report_doc += ref
            else:
                report_doc += ref
        write_report(folderpath, "report", report_doc)

def split_by_language(path):
    if "english" not in os.listdir(path):
        os.mkdir(os.path.join(path, "english"))
    
    for folder in os.listdir(path):
        if folder in ["english", "korean", "russian"]:
            continue

        if folder not in os.listdir(os.path.join(path, "korean")) and  folder not in os.listdir(os.path.join(path, "russian")):
            shutil.copytree(os.path.join(path, folder), os.path.join(path, "english", folder))

# %%
data_path = "C:/Users/AIAS/Documents/cti-model-training/data/reports_formatted"
raw_data_path = os.path.join(data_path, "raw")
alienvault_data_path = os.path.join(data_path, "alienvault")
failure_message = "REPORT IS NOT EXTRACTED! Reason caused the failure:"
non_english_languages_in_reports = ["korean", "russian"]

# %%
# failed_av_list, failed_av_urls = find_failed_reports(alienvault_data_path, failure_message)
# failed_raw_list, failed_raw_urls = find_failed_reports(raw_data_path, failure_message)

# %%
# print(f"Failed alienvault references: {len(failed_av_list)}")
# print(f"Failed raw references: {len(failed_raw_list)}")

# %%
# Save failed in a new folder
# Failed raw reports are those with no reference at all

if False:
    move_to_failed(data_path=data_path,
                report_type="raw",
                failure_message=failure_message)

    move_to_failed(data_path=data_path,
                report_type="alienvault",
                failure_message=failure_message)

# %%
if False:
    combine_results(raw_data_path, failure_message)

# %%
# Delete failed alienvault references
if False:
    for f in failed_av_list:
        folder = f.split("-ref")[0]
        shutil.rmtree(os.path.join(alienvault_data_path, folder))

# %%
# Delete failed raw references
if False:
    for f in failed_raw_list:
        folder = f.split("-ref")[0]
        try:
            shutil.rmtree(os.path.join(raw_data_path, folder))
        except:
            continue

# %%
# Seperate reports by language
if False:
    seperate_non_english_reports(raw_data_path, language="ko")
    seperate_non_english_reports(raw_data_path, language="ru")

# %%
if False:
    split_by_language(raw_data_path)

# %%
48+17+2275
# Out:
# 2340

# %%
def load_reports_in_dict(path):
    data = {}
    for filename in os.listdir(path):
        report = read_report(path, filename)
        data.update({filename.split(".txt")[0]:report})
    return data

data = load_reports_in_dict("C:/Users/AIAS/Documents/cti-model-training/data/reports")

# %%
def load_formatted_reports_in_dict(path):
    data = {}
    for foldername in os.listdir(path):
        filepath = os.path.join(path, foldername)
        report = read_report(filepath, "report")
        data.update({foldername:report})
    return data

formatted_data = load_formatted_reports_in_dict("C:/Users/AIAS/Documents/cti-model-training/data/reports_formatted/raw/english")

# %%
# Analyze images
report_names = pd.read_csv("C:/Users/AIAS/Documents/cti-model-training/data/opencti_reports_external_references.csv")["ID"].tolist()
img_analysis_dict = {
    "report":[],
    "cnt_formatted_imgs":[],
    "cnt_imgs":[]
}
for rn in report_names:
    if rn in formatted_data.keys() and rn in data.keys():

        formatted_report = formatted_data[rn]
        report = data[rn]

        cnt_formatted_imgs = len(re.findall(r'<!-- image -->', formatted_report, re.DOTALL))
        cnt_images = len(re.findall(r'(.*?)', report, re.DOTALL))

        img_analysis_dict["report"].append(rn)
        img_analysis_dict["cnt_formatted_imgs"].append(cnt_formatted_imgs)
        img_analysis_dict["cnt_imgs"].append(cnt_images)

# %%
pd.DataFrame(img_analysis_dict)
# Out:
#                                     report  cnt_formatted_imgs  cnt_imgs
# 0     ab7e9b32-96c3-4d99-9143-c0393e4a5f4e                   8         0
# 1     71d86e1e-48bf-43c2-9b8d-d15edfc8105b                  16         4
# 2     4c16f35a-7646-4f41-b962-c96916d3d3da                  66        31
# 3     adb19ece-7fef-4845-925e-68e00f2cb6d0                  26         0
# 4     7768c570-7502-42f8-9fe3-58789cd398f5                  14         1
# ...                                    ...                 ...       ...
# 1247  2e8d943c-1670-4fd0-a4db-66af84013f09                  18        14
# 1248  c3fe424f-6484-421a-b8f8-0fc3a9fa1a70                  46        12
# 1249  8c5ed2c6-780e-4ae7-be0e-908a9921d9e4                  26         5
# 1250  a1e7a45b-6bcc-464b-ac9a-53056054ba31                  90         9
# 1251  d4e304fa-aff2-4c17-8999-5f566a33952c                  60        28
#
# [1252 rows x 3 columns]

# %%
unmatched = []
for rn in report_names:
    if rn in formatted_data.keys() and rn in data.keys():
        match_case_1 = data[rn].split("Article Body:")[1][:25].strip()
        match_case_2 = data[rn].split("Article Body:")[1][25:50].strip()
        match_case_3 = data[rn].split("Article Body:")[1][50:75].strip()
        match_case_4 = data[rn].split("Article Body:")[1][75:100].strip()
        if match_case_1 not in formatted_data[rn] \
            and match_case_2 not in formatted_data[rn] \
                and match_case_3 not in formatted_data[rn] \
                    and match_case_4 not in formatted_data[rn]:
            # print(f"Match case: =>  {match_case}\n")
            # print(f"Formatted report: => {formatted_data[rn][:500]}\n")
            # print(f"\n\n{'='*100}\n\n")
            unmatched.append(rn)

print(len(unmatched))
# Out:
# 58

# %%
# Match title
unmatched_titles = []
for rn in report_names:
    if rn in formatted_data.keys() and rn in data.keys():
        match_case = data[rn].split("Article Title:")[1].split("\n")[0][:40]
        match_case = match_case.strip()
        if match_case not in formatted_data[rn]:
            print(f"Report: => {rn}")
            print(f"Match case: =>  {match_case}\n")
            # print(f"Formatted report: => {formatted_data[k][:500]}")
            # print(f"\n\n{'='*100}\n\n")
            unmatched_titles.append(rn)

print(len(unmatched_titles))
# Out:
# Report: => 35ee06de-1ccd-462a-b6a8-81c254bd4b66
# Match case: =>  A closer look at Eternity Malware
#
# Report: => 02797bd3-3a72-4e84-ae6d-fd4fe573bcc9
# Match case: =>  No Title Found
#
# Report: => 000e110f-3b22-46e0-b7db-9f121d818236
# Match case: =>  ERMAC Back In Action
#
# Report: => f4f0da41-ebd3-430c-904f-c6dffb3d488f
# Match case: =>  No Title Found
#
# Report: => 14409b02-10a3-4f4a-98a1-13e463567dba
# Match case: =>  Flying in the clouds: APT31 renews its
#
# Report: => 20fc13be-ad67-4a8b-a9be-0aa4d7d9a675
# Match case: =>  No Title Found
#
# Report: => 461a9680-4c73-426a-b9bc-46cf1494146c
# Match case: =>  Raspberry Robin and Dridex: Two birds o
#
# Report: => b3f70f96-ba9c-46d6-a658-520a96f76f2f
# Match case: =>  Monster Libra (TA551/Shathak) --> IcedI
#
# Report: => 33a6e370-598a-4ba6-84ee-352cdfd3c8a7
# Match case: =>  No Title Found
#
# Report: => 0a181c9b-9e61-4ec8-b2c7-c9a9e38aa798
# Match case: =>  No Title Found
#
# Report: => 23261488-9043-4a85-bf3f-fd2c285163c6
# Match case: =>  No Title Found
#
# Report: => b0c01168-f1a4-458b-9931-fb07c015ad22
# Match case: =>  No Title Found
#
# Report: => ba4483d6-51f7-4886-a452-c3b171d7ba85
# Match case: =>  Malicious Google Ad --> Fake Notepad++
#
# Report: => aa8a2846-5742-4dd4-a22d-cbf2930d2331
# Match case: =>  SEO Poisoning: Risks, Solutions & Indic
#
# Report: => 3185d124-7827-401a-9ac0-5e1886ddfc1f
# Match case: =>  Ransomware Attack on IL&FS
#
# Report: => 04198e91-d6e1-4a3b-8d7d-32e8a08e6883
# Match case: =>  Andoryu Botnet——A New Botnet Based on S
#
# Report: => b62668c9-25f9-4bbd-a9cc-171a5d8ce31e
# Match case: =>  SOC Team Essentials | How to Investigat
#
# Report: => 19f0cdde-91c9-429a-bc0a-0a37f5e1d688
# Match case: =>  No Title Found
#
# Report: => 7a796cf2-d155-498f-b968-599bed7f4730
# Match case: =>  Talos uncovers espionage campaigns targ
#
# Report: => 1aa3088e-7936-48d6-9477-f5fa50eaeca2
# Match case: =>  No Title Found
#
# Report: => 7096cb81-29ba-4c1b-8bd5-632fb1625005
# Match case: =>  X_Trader Supply Chain Attack Affects Cr
#
# Report: => 27b6715b-751d-4441-bb62-fd1b5badede3
# Match case: =>  Analysis of In-the-wild Attack Samples
#
# Report: => 08a62db5-3b1d-4b4d-8534-d791765e36f8
# Match case: =>  No Title Found
#
# Report: => c45b385d-79a5-4eaa-9f77-52c1d8d30684
# Match case: =>  What%E2%80%99s up with Emotet?
#
# Report: => 0920a611-0765-48c6-bfdc-a57eea2c95fd
# Match case: =>  New "Agent Tesla" Variant:Unusual "ZPAQ
#
# Report: => e2052883-ca39-4b16-956b-5645229d78a2
# Match case: =>  Recent DarkGate Activity & Trends
#
# Report: => 480bc565-826f-4fba-bb21-8220a8c3d324
# Match case: =>  No Title Found
#
# Report: => 539d040e-2891-4859-a5f8-34aa45ef6dde
# Match case: =>  No Title Found
#
# Report: => 0f02f552-ffe1-4d91-929d-dca34744e96f
# Match case: =>  No Title Found
#
# Report: => 361cd1cf-99f3-4db5-92c0-d31479340216
# Match case: =>  No Title Found
#
# Report: => 449a366d-8111-4088-bf44-b414755ff1f3
# Match case: =>  Breaking Boundaries: Mispadu's Infiltra
#
# Report: => 7c2ae869-af6c-40a4-91a3-29d9d9495f08
# Match case: =>  No Title Found
#
# Report: => b41bb23c-88a3-4e64-a524-6116c83e3126
# Match case: =>  No Title Found
#
# Report: => 0b9a7c2f-997a-412b-a821-6e6d6affffb8
# Match case: =>  Search & Spoof: Abuse of Windows Search
#
# Report: => 98d3d179-f091-4a22-a872-658fa40705fa
# Match case: =>  Hellhounds: Operation Lahat. Part 2
#
# Report: => 8ffab167-83ec-4cbf-90b9-a9d663f85432
# Match case: =>  No Title Found
#
# Report: => 84aba6c8-bb06-4e56-a518-52afa17af732
# Match case: =>  The Pumpkin EclipseBlack Lotus LabsPost
#
# Report: => 29732e7d-36b1-4faa-ba03-f35bc825a65b
# Match case: =>  No Title Found
#
# Report: => 386649fc-b95c-4865-901b-f4e869343f8c
# Match case: =>  The Hidden Danger of PDF Files with Emb
#
# Report: => 47c11324-04f8-4113-bf41-14a99629b3ae
# Match case: =>  Howling at the Inbox: Sticky Werewolf's
#
# Report: => 5303b35b-e174-4f50-ba1f-ba6f80279812
# Match case: =>  Disarming DarkGate: A Deep Dive into Th
#
# Report: => 93de5635-7d1f-4324-be4e-844df02f4225
# Match case: =>  No Title Found
#
# Report: => d475a622-3db2-4b94-b1a6-a3b258c84f12
# Match case: =>  StrelaStealer Resurgence: Tracking a Ja
#
# Report: => 5c38b8e5-2ea9-4b1c-bdda-d7bbb034f72c
# Match case: =>  No Title Found
#
# Report: => 4c6a49ce-0409-420e-be5a-eccc2056a1d6
# Match case: =>  Supply Chain Compromise Leads to Trojan
#
# Report: => d27dd1e7-6f51-495f-ae03-54e0a2b29f86
# Match case: =>  CoreWarrior Spreader Malware Surge
#
# Report: => e7b27293-a99d-47aa-8e66-f880df2e6094
# Match case: =>  HORUS Protector Part 2: The New Malware
#
# Report: => b88ddc51-575b-4af2-9995-c9795d14e47b
# Match case: =>  Hive0147 serving juicy Picanha with a s
#
# Report: => 91f7f31d-931c-4028-b149-eff92d7cb201
# Match case: =>  Derailing the Raptor TrainBlack Lotus L
#
# Report: => c77300a7-23f5-4ce3-8dda-901b0cc5ad6f
# Match case: =>  <url>https://www.trendmicro.com/https:/
#
# Report: => 545b516e-91ee-4d0f-99c9-2734535fc224
# Match case: =>  MDR in Action: Preventing The More_eggs
#
# Report: => 09fe9b92-f247-47e6-86e7-1e91e339a917
# Match case: =>  New Trend in MSI File Abuse: New OceanL
#
# 52

# %%
# Match images before title
imgs_before_title = []
for rn in report_names:
    if rn in formatted_data.keys() and rn in data.keys():
        match_case = "# " + data[rn].split("Article Title:")[1].split("\n")[0][:40].strip()
        if match_case in formatted_data[rn]:
            before_title = len(re.findall(r'<!-- image -->', 
                                          formatted_data[rn].split(match_case)[0]
                                          ))
            print(f"Report: => {rn}")
            print(f"Match case: =>  {match_case}")
            print(f"Number of images: => {before_title}\n\n")
            imgs_before_title.append(before_title)

print(pd.Series(imgs_before_title).describe())
# Out:
# Report: => ab7e9b32-96c3-4d99-9143-c0393e4a5f4e
# Match case: =>  # Spring Vulnerability Update - Exploitat
# Number of images: => 1
#
#
# Report: => 71d86e1e-48bf-43c2-9b8d-d15edfc8105b
# Match case: =>  # Moshen Dragon’s Triad-and-Error Approac
# Number of images: => 0
#
#
# Report: => 4c16f35a-7646-4f41-b962-c96916d3d3da
# Match case: =>  # AvosLocker Ransomware Variant Abuses Dr
# Number of images: => 0
#
#
# Report: => adb19ece-7fef-4845-925e-68e00f2cb6d0
# Match case: =>  # Fresh TOTOLINK Vulnerabilities Picked U
# Number of images: => 0
#
#
# Report: => 7768c570-7502-42f8-9fe3-58789cd398f5
# Match case: =>  # Cicada: Chinese APT Group Widens Target
# Number of images: => 2
#
#
# Report: => a5c62472-8a18-4f17-be94-0481ee1f3558
# Match case: =>  # Password-protected Excel spreadsheet pu
# Number of images: => 1
#
#
# Report: => d4848f81-4d06-4106-941c-6d1991c12baa
# Match case: =>  # Windows MetaStealer Malware
# Number of images: => 1
#
#
# Report: => 02e3d6c6-7766-402a-a6a8-dce946b80bf7
# Match case: =>  # FFDroider Stealer Targeting Social Medi
# Number of images: => 0
#
#
# Report: => 4d08c5bb-d8bb-4ec1-a8ae-5f3298309e17
# Match case: =>  # Fake e-shops on the prowl for banking c
# Number of images: => 0
#
#
# Report: => 91b50575-9d53-471c-aba3-6926c56cb565
# Match case: =>  # The Latest Remcos RAT Driven By Phishin
# Number of images: => 0
#
#
# Report: => 2bdae158-ce1d-4585-acd6-9597e3a2e535
# Match case: =>  # New SolarMarker (Jupyter) Campaign Demo
# Number of images: => 0
#
#
# Report: => db27765e-9265-4fb2-8be6-073c54560a9b
# Match case: =>  # From the Front Lines | Unsigned macOS o
# Number of images: => 0
#
#
# Report: => 024802d1-919e-420e-908e-ea1b22c91467
# Match case: =>  # Examining the Black Basta Ransomware’s
# Number of images: => 0
#
#
# Report: => 12a04078-1625-4824-96a3-ab4e34db49ee
# Match case: =>  # Mobile subscription Trojans and their l
# Number of images: => 0
#
#
# Report: => bf5f4841-b45c-456d-a458-94faab09028b
# Match case: =>  # TA578 using thread-hijacked emails to p
# Number of images: => 1
#
#
# Report: => 893ed5e3-3d89-46f6-9c80-10abe178e1a5
# Match case: =>  # CVE-2022-22965: Analyzing the Exploitat
# Number of images: => 0
#
#
# Report: => be81b074-1d4f-4b07-b93a-16736d3776a4
# Match case: =>  # SystemBC Being Used by Various Attacker
# Number of images: => 0
#
#
# Report: => 63a0316f-d3ad-479a-883d-6d6fd31494c1
# Match case: =>  # Emotet modules and recent attacks
# Number of images: => 0
#
#
# Report: => 44753306-324e-4369-99a0-cd81e0aeb6b9
# Match case: =>  # Enemybot: A Look into Keksec's Latest D
# Number of images: => 0
#
#
# Report: => 5ae62190-9450-4a8f-b20e-dfe817413eda
# Match case: =>  # Harmful Help: Analyzing a Malicious Com
# Number of images: => 0
#
#
# Report: => c845e410-2066-4d89-a1fc-63f9f800f785
# Match case: =>  # Phishing Campaign Delivering Three File
# Number of images: => 0
#
#
# Report: => 25ff1f72-202b-49e4-8150-3bf24aba1406
# Match case: =>  # Fake Mobile Apps Steal Facebook Credent
# Number of images: => 0
#
#
# Report: => 8a828bbc-d9d4-467a-a516-70df67974085
# Match case: =>  # KurayStealer: An Unscrupulous Actor Exp
# Number of images: => 0
#
#
# Report: => 76a12c2a-bbc5-4be8-b3da-0abbd2a78567
# Match case: =>  # Threat Spotlight: "Haskers Gang" Introd
# Number of images: => 0
#
#
# Report: => 70159c8b-02a0-4c9d-8df8-9b6f95ca9365
# Match case: =>  # Threat Actors Chaining Unpatched VMware
# Number of images: => 0
#
#
# Report: => 034fe0f1-c52a-4171-94b9-4eb10758e787
# Match case: =>  # Interactive Phishing: Using Chatbot-lik
# Number of images: => 3
#
#
# Report: => a8b35e16-9d4a-4d33-aa82-7c3bf11442a2
# Match case: =>  # "aa" distribution Qakbot (Qbot) infecti
# Number of images: => 1
#
#
# Report: => 34ea3158-9efe-4714-b099-048272ff2f06
# Match case: =>  # Log4j2 In The Wild | Iranian-Aligned Th
# Number of images: => 0
#
#
# Report: => 258a590e-0870-4ec5-a589-7dd3f5986fd3
# Match case: =>  # Spoofed Saudi Purchase Order Drops GuLo
# Number of images: => 0
#
#
# Report: => 44ff3bca-ff7d-4160-8a88-d0a1fa7badc3
# Match case: =>  # New Nokoyawa Variant Catching Up to Pee
# Number of images: => 0
#
#
# Report: => bc898b8e-3582-4a77-9042-2d5dc015b580
# Match case: =>  # ctx Python Library Updated with "Extra"
# Number of images: => 1
#
#
# Report: => 3a46a347-699e-4048-be7c-1bb921580202
# Match case: =>  # Quantum Ransomware
# Number of images: => 0
#
#
# Report: => 00504fc7-200f-4891-846e-e85d08b0c40d
# Match case: =>  # LockBit Ransomware Side-loads Cobalt St
# Number of images: => 0
#
#
# Report: => f1209ece-a9d6-4f34-8df8-b2246450104e
# Match case: =>  # Phishing Campaign Delivering Three File
# Number of images: => 0
#
#
# Report: => 2509ff9c-38f2-48f0-b676-38c77793504b
# Match case: =>  # Hazard Token Grabber
# Number of images: => 1
#
#
# Report: => 3fb98382-6f15-4ded-8da3-eedcd98d09ac
# Match case: =>  # First Exploitation of Follina Seen in t
# Number of images: => 1
#
#
# Report: => 6edcc0c2-903d-493c-ad8e-5ef05126ce3e
# Match case: =>  # New APT Group Earth Berberoka Targets G
# Number of images: => 0
#
#
# Report: => a2e54bc2-0d04-488d-821d-b055221b3fa7
# Match case: =>  # Karakurt Data Extortion Group
# Number of images: => 0
#
#
# Report: => 9f5cfc38-2374-4c37-a6ce-08266fbd86bc
# Match case: =>  # A new secret stash for “fileless” malwa
# Number of images: => 0
#
#
# Report: => 809c4b6e-b08a-4944-8555-8af01f604568
# Match case: =>  # WinDealer dealing on the side
# Number of images: => 0
#
#
# Report: => 8635135f-c54c-4cd5-98c1-9be54b762b64
# Match case: =>  # Threat Actors Prey on Eager Travelers
# Number of images: => 0
#
#
# Report: => 36f0dd31-a1c8-4df1-90b1-0b37c5f8d0cf
# Match case: =>  # Old Services, New Tricks: Cloud Metadat
# Number of images: => 0
#
#
# Report: => 1f47bada-8bd5-456c-b19d-90b220e45322
# Match case: =>  # NetDooka Framework Distributed via Priv
# Number of images: => 0
#
#
# Report: => 41a1b172-6912-4d3f-947a-0da84d798603
# Match case: =>  # Mustang Panda deploys a new wave of mal
# Number of images: => 0
#
#
# Report: => 77d70e9a-7f54-4622-90f7-309693beb391
# Match case: =>  # Spam Email Contains a Very Large ISO fi
# Number of images: => 1
#
#
# Report: => be89f645-0db1-408d-8b76-45bf8b344c2d
# Match case: =>  # Closing the Door: DeadBolt Ransomware L
# Number of images: => 0
#
#
# Report: => f5528704-b3fc-469b-89e6-02b5972480a2
# Match case: =>  # From the Front Lines | Another Rebrand?
# Number of images: => 0
#
#
# Report: => 830c26fb-3bf6-46cc-ba5e-c2da2d6f606f
# Match case: =>  # Attackers Exploit MSDT Follina Bug to D
# Number of images: => 3
#
#
# Report: => b233ff7a-c785-4ea4-be2a-37ddc805ee7a
# Match case: =>  # Cybereason vs. Quantum Locker Ransomwar
# Number of images: => 1
#
#
# Report: => 56f4aa1d-693d-44c6-87e1-d3aa27910872
# Match case: =>  # Cobalt Strike Analysis and Tutorial: CS
# Number of images: => 0
#
#
# Report: => 7fb3d88b-a788-4fbc-8510-5b6b91df8dc5
# Match case: =>  # Threat Brief: CVE-2022-1388
# Number of images: => 0
#
#
# Report: => 480f1ad7-dd97-4028-b2c9-0931b325e147
# Match case: =>  # Please Confirm You Received Our APT
# Number of images: => 0
#
#
# Report: => 02f3db04-a296-46d2-9244-caf44d1752ab
# Match case: =>  # New SYK Crypter Distributed Via Discord
# Number of images: => 0
#
#
# Report: => 32d27fdd-54e3-40da-a39d-42c26b73e792
# Match case: =>  # Emotet Summary: November 2021 Through J
# Number of images: => 0
#
#
# Report: => eb955bca-6f30-493c-af31-6e275ad36f04
# Match case: =>  # Bumblebee Malware from TransferXL URLs
# Number of images: => 1
#
#
# Report: => eae6fe17-283d-41ea-947f-588169a5b621
# Match case: =>  # Why Remediation Alone Is Not Enough Whe
# Number of images: => 0
#
#
# Report: => 48d231a5-14ba-48a3-98d8-98058bf50052
# Match case: =>  # CrateDepression | Rust Supply-Chain Att
# Number of images: => 0
#
#
# Report: => 5b033f42-d3c8-4ff3-be60-8e97c2d7e867
# Match case: =>  # APT ToddyCat
# Number of images: => 0
#
#
# Report: => 13b96c56-1f56-4a85-a5d7-dd7b30112b60
# Match case: =>  # Threat Brief: VMware Vulnerabilities Ex
# Number of images: => 0
#
#
# Report: => ab8d49d0-7427-4af9-9ea7-1ec584528b9f
# Match case: =>  # Websites Hosting Fake Cracks Spread Upd
# Number of images: => 0
#
#
# Report: => 2ad70f7e-ae4d-40dd-beef-fd5e02933cac
# Match case: =>  # From the Front Lines | 3 New and Emergi
# Number of images: => 0
#
#
# Report: => 3ec41094-3b85-4f42-97ac-9e91bb3417a2
# Match case: =>  # SocGholish Campaigns and Initial Access
# Number of images: => 1
#
#
# Report: => b40d2f72-d4ba-46f5-bc2e-220d4f6e7040
# Match case: =>  # Use of Obfuscated Beacons in ‘pymafka’
# Number of images: => 0
#
#
# Report: => f23acfe2-7051-421f-9d84-c1ff0dea0a4a
# Match case: =>  # Return of the Evilnum APT with updated
# Number of images: => 0
#
#
# Report: => ae6c2803-9c0b-4819-92fe-8069e2d0c424
# Match case: =>  # New Info-stealer Disguised as Crack Bei
# Number of images: => 0
#
#
# Report: => dc251450-3ee9-4f37-88e5-140e9c451d81
# Match case: =>  # Smash-and-grab: AstraLocker 2.0 pushes
# Number of images: => 0
#
#
# Report: => 22ccc2d1-499a-4ce9-83f5-d70cdb5ce5eb
# Match case: =>  # #StopRansomware: MedusaLocker
# Number of images: => 0
#
#
# Report: => 64542d37-13a3-4dcb-9d52-328c49ba9295
# Match case: =>  # Popping Eagle: How We Leveraged Global
# Number of images: => 0
#
#
# Report: => 09eb2b54-d470-4378-9d96-70258c4f7f24
# Match case: =>  # Clipminer Botnet Makes Operators at Lea
# Number of images: => 2
#
#
# Report: => 2f748192-303c-427b-85c9-e93cf4499f87
# Match case: =>  # CVE-2022-30190: Microsoft Support Diagn
# Number of images: => 0
#
#
# Report: => 7c27f876-9f6a-4ceb-8313-9feab008e0fe
# Match case: =>  # Zero-Day Exploitation of Atlassian Conf
# Number of images: => 0
#
#
# Report: => fde8b623-e394-4ff1-81a3-11e54e06227b
# Match case: =>  # From the Front Lines | New macOS ‘covid
# Number of images: => 0
#
#
# Report: => c714dfff-c882-45b4-83e0-a90f101f2313
# Match case: =>  # North Korean State-Sponsored Cyber Acto
# Number of images: => 0
#
#
# Report: => 8e617ae1-7844-48fe-9448-1d0946f7493c
# Match case: =>  # Threat Brief: Atlassian Confluence Remo
# Number of images: => 0
#
#
# Report: => 446011f2-2283-4419-81bc-6b8f175ed2f5
# Match case: =>  # Stonefly: North Korea-linked Spying Ope
# Number of images: => 2
#
#
# Report: => 4d7365e8-9f55-4155-9d03-d68891848785
# Match case: =>  # MakeMoney malvertising campaign adds fa
# Number of images: => 0
#
#
# Report: => eeb71b97-fc63-4b83-817a-16d26a452ae3
# Match case: =>  # Aoqin Dragon | Newly-Discovered Chinese
# Number of images: => 0
#
#
# Report: => 42b83b90-09e3-41cc-9ea6-fa49366db373
# Match case: =>  # TA570 Qakbot (Qbot) tries CVE-2022-3019
# Number of images: => 1
#
#
# Report: => 564d1e0b-4155-4264-9bf2-d3b60ad559ea
# Match case: =>  # GALLIUM Expands Targeting Across Teleco
# Number of images: => 0
#
#
# Report: => 08f96060-6c3f-4b60-a009-788b7aaeb921
# Match case: =>  # Lyceum .NET DNS Backdoor
# Number of images: => 0
#
#
# Report: => 27bf1951-0ed7-4853-a6f9-84e3d99c8e18
# Match case: =>  # Exposing HelloXD Ransomware and x4k
# Number of images: => 0
#
#
# Report: => d7f6ec01-9499-4128-b010-32cba147d534
# Match case: =>  # Malspam pushes Matanbuchus malware, lea
# Number of images: => 1
#
#
# Report: => 031e916d-c997-4858-857b-606615adfcce
# Match case: =>  # BRATA is evolving into an Advanced Pers
# Number of images: => 0
#
#
# Report: => 2f0cffde-aebe-46eb-8d6e-f1658c8581fb
# Match case: =>  # I see what you did there: A look at the
# Number of images: => 0
#
#
# Report: => 76e15276-3127-4b69-a949-8f1f2129477f
# Match case: =>  # LockBit 3.0 Update | Unpicking the Rans
# Number of images: => 0
#
#
# Report: => 81cec4ee-ed0b-4d56-8bfb-b023bfce9fb4
# Match case: =>  # Alibaba OSS Buckets Compromised to Dist
# Number of images: => 0
#
#
# Report: => 1c397c47-5f38-472d-943f-36aed0fba404
# Match case: =>  # The Return of Candiru: Zero-days in the
# Number of images: => 0
#
#
# Report: => 8b73fa80-f45f-4b69-8051-e2c4293d1f12
# Match case: =>  # Google ads lead to major malvertising c
# Number of images: => 0
#
#
# Report: => c89a2edc-d6c3-4391-b0b4-56bba6934e7a
# Match case: =>  # Russia’s APT28 uses fear of nuclear war
# Number of images: => 0
#
#
# Report: => b24abcc3-a3d2-45dc-9f32-a4dbfae7f88b
# Match case: =>  # MAR-10382580-1.v1 – Unidentified RAT
# Number of images: => 0
#
#
# Report: => 34dbe541-74ff-4a4e-97cd-dac41acdc1f1
# Match case: =>  # Malicious Cyber Actors Continue to Expl
# Number of images: => 0
#
#
# Report: => f1418613-cdfc-4daa-987f-01411c166579
# Match case: =>  # CosmicStrand: the discovery of a sophis
# Number of images: => 0
#
#
# Report: => 47f88a84-1e53-42a4-825c-42035bd948eb
# Match case: =>  # ZuoRAT Hijacks SOHO Routers to Silently
# Number of images: => 0
#
#
# Report: => 99766478-55c7-471d-b250-aa377fbaa4f6
# Match case: =>  # Vidar distributed through backdoored Wi
# Number of images: => 0
#
#
# Report: => 407e268b-559a-4ba4-bc11-3426edcabf7e
# Match case: =>  # The SessionManager IIS backdoor
# Number of images: => 0
#
#
# Report: => 73760ed8-890a-4a60-8125-f0162e3e9ea9
# Match case: =>  # Revive: from spyware to Android banking
# Number of images: => 0
#
#
# Report: => 1eece0b7-92bb-45c0-9613-a37588de1b55
# Match case: =>  # SolidBit Ransomware Enters the RaaS Sce
# Number of images: => 0
#
#
# Report: => 396ba1f7-9a23-4f64-ab62-893a6eabec95
# Match case: =>  # When Pentest Tools Go Brutal: Red-Teami
# Number of images: => 0
#
#
# Report: => 8248f4fa-6dd7-4931-bb97-b8d7a5bab423
# Match case: =>  # AsyncRAT Being Distributed to Unsecured
# Number of images: => 0
#
#
# Report: => 3052647c-b083-4df2-84f4-ef00572891b7
# Match case: =>  # NoMercy Stealer Adding New Features
# Number of images: => 1
#
#
# Report: => 50901ff8-8350-4abd-a021-ab1172a45d03
# Match case: =>  # Targets of Interest | Russian Organizat
# Number of images: => 0
#
#
# Report: => 4e1432ed-5097-4685-8d86-0ba6f40beec7
# Match case: =>  # Emotet infection with Cobalt Strike
# Number of images: => 1
#
#
# Report: => 0b2a983b-ee12-4a1d-8aff-703e85428c61
# Match case: =>  # Monero CoinMiner Being Distributed via
# Number of images: => 0
#
#
# Report: => 89d034ed-912f-4fd3-ba29-20386c1e1ffb
# Match case: =>  # Novel News on Cuba Ransomware: Greeting
# Number of images: => 0
#
#
# Report: => 3dcd6242-f7cb-4793-9d0a-fccd0ec44655
# Match case: =>  # BlueSky Ransomware: Fast Encryption via
# Number of images: => 0
#
#
# Report: => 7e8fbb17-c4ef-4182-9214-3e8b0a799cce
# Match case: =>  # #StopRansomware: Zeppelin Ransomware
# Number of images: => 0
#
#
# Report: => e4460738-73ea-4f5a-bcd0-51700133b1f4
# Match case: =>  # Rise in Qakbot attacks traced to evolvi
# Number of images: => 0
#
#
# Report: => 6dfce8c4-3751-4262-be11-6f5716a39dd2
# Match case: =>  # Shuckworm: Russia-Linked Group Maintain
# Number of images: => 2
#
#
# Report: => 8598cedb-a35b-4b76-8d8f-abb015aeb7e8
# Match case: =>  # Digium Phones Under Attack: Insight Int
# Number of images: => 0
#
#
# Report: => 3e1f6946-efdf-441c-9df2-298c74a7a991
# Match case: =>  # Threat in your browser: what dangers in
# Number of images: => 0
#
#
# Report: => 4fef346c-9277-4c0f-bafe-82afeb367b6a
# Match case: =>  # Attackers Profiting from Proxyware
# Number of images: => 0
#
#
# Report: => 83988bdd-170f-4d1e-9406-d97a4dec60c4
# Match case: =>  # From the Front Lines | 8220 Gang Massiv
# Number of images: => 0
#
#
# Report: => 5e1853ea-34ee-4175-be16-1fc49bc59a53
# Match case: =>  # Russian APT29 Hackers Use Online Storag
# Number of images: => 0
#
#
# Report: => 2677e009-22b2-411f-b45b-a813496c165b
# Match case: =>  # Amadey Bot Being Distributed Through Sm
# Number of images: => 0
#
#
# Report: => 5e04ba13-0b7d-446d-a84a-c9c8aebffb47
# Match case: =>  # Malware Being Distributed by Disguising
# Number of images: => 0
#
#
# Report: => 1749e8c0-5636-4bb7-9f9e-447798370ac6
# Match case: =>  # Ongoing Roaming Mantis smishing campaig
# Number of images: => 2
#
#
# Report: => 31601a3d-d20c-40b1-9bc6-6187e38ca9f6
# Match case: =>  # Brazil malspam pushes Astaroth (Guildma
# Number of images: => 1
#
#
# Report: => 1d760327-f7a0-4ef5-b69f-052c7f0f2a31
# Match case: =>  # Kimsuky’s GoldDragon cluster and its C2
# Number of images: => 0
#
#
# Report: => fa7e2a5e-a94e-4ff4-8289-3fd958e7b034
# Match case: =>  # IcedID (Bokbot) with Dark VNC and Cobal
# Number of images: => 1
#
#
# Report: => 20f3b0dd-bf0b-4f8f-afcc-82c648ca9fc9
# Match case: =>  # Ransomware Actor Abuses Genshin Impact
# Number of images: => 0
#
#
# Report: => 5b2ce8db-5156-4cdd-8481-37be41d2bcf0
# Match case: =>  # Gootkit Loader’s Updated Tactics and Fi
# Number of images: => 0
#
#
# Report: => ae52853b-10df-47e8-a95b-ce22127f9d8f
# Match case: =>  # Living Off Windows Defender | LockBit R
# Number of images: => 0
#
#
# Report: => 4886debc-6d7e-4b89-ad7a-5b96603ccfea
# Match case: =>  # MAR-10386789-1.v1 – Log4Shell
# Number of images: => 0
#
#
# Report: => 17747878-a6f4-4780-aa67-6e07c8649583
# Match case: =>  # Mini Stealer: Possible Predecessor of P
# Number of images: => 1
#
#
# Report: => 89e42549-afcc-43b5-a31e-ede223890726
# Match case: =>  # Threat analysis: Follina exploit fuels
# Number of images: => 0
#
#
# Report: => 26ea0e88-4f72-4182-b11d-6b7f2dbe84c3
# Match case: =>  # So RapperBot, What Ya Bruting For?
# Number of images: => 0
#
#
# Report: => 218aa95d-7493-4f40-927d-0e11f480c2db
# Match case: =>  # Flight of the Bumblebee: Email Lures an
# Number of images: => 0
#
#
# Report: => 51b10882-6dba-41a4-966b-bc5adbf82361
# Match case: =>  # APT42: Crooked Charms, Cons, and Compro
# Number of images: => 0
#
#
# Report: => 466ddf2c-44e3-42a3-9dcb-688aabbc7c98
# Match case: =>  # Andariel deploys DTrack and Maui ransom
# Number of images: => 0
#
#
# Report: => 629ef2f3-f4ab-414a-9b05-dce4df27ab70
# Match case: =>  # BumbleBee Roasts Its Way to Domain Admi
# Number of images: => 0
#
#
# Report: => 86edf382-789a-4e5e-9e24-4bd824cf0083
# Match case: =>  # VileRAT: DeathStalker’s continuous stri
# Number of images: => 0
#
#
# Report: => c56e7521-11e1-47c1-a4a2-2365fca76993
# Match case: =>  # APT-C-35 Gets a New Upgrade
# Number of images: => 0
#
#
# Report: => adc85ffe-215e-42c1-8e9d-ea3f5e9d0a54
# Match case: =>  # Monster Libra (TA551/Shathak) pushes Ic
# Number of images: => 1
#
#
# Report: => 5872f11d-4407-47cf-8b80-54c8d9d5d93d
# Match case: =>  # Phishing Word Documents with Suspicious
# Number of images: => 1
#
#
# Report: => 7418b761-c817-48b8-b331-212c94976c78
# Match case: =>  # Iron Tiger Compromises Chat Application
# Number of images: => 0
#
#
# Report: => bf4ac930-d8b4-45e8-ae67-3be099557f1b
# Match case: =>  # Webworm: Espionage Attackers Testing an
# Number of images: => 2
#
#
# Report: => f8f4ac76-c47d-4ee2-8420-788f35ba9c76
# Match case: =>  # Malvertising on Microsoft Edge’s News F
# Number of images: => 0
#
#
# Report: => b7c0d85d-f9a5-49e7-8786-92530fb8a52f
# Match case: =>  # XCSSET Malware Update | macOS Threat Ac
# Number of images: => 0
#
#
# Report: => d5347d56-d7d1-47e1-935f-4c1675eff53a
# Match case: =>  # Grandoreiro Banking Trojan with New TTP
# Number of images: => 0
#
#
# Report: => 5596cb81-8a3e-456a-877f-559455b824b4
# Match case: =>  # Iranian State Actors Conduct Cyber Oper
# Number of images: => 0
#
#
# Report: => 80ef60f3-b9cc-47d4-beec-c49ae0ddd506
# Match case: =>  # Noberus Ransomware: Darkside and BlackM
# Number of images: => 2
#
#
# Report: => 40cf0950-1f74-4b26-8e57-324a687df944
# Match case: =>  # THREAT ANALYSIS REPORT: Bumblebee Loade
# Number of images: => 1
#
#
# Report: => 5a2acd23-0404-4d05-ba9b-a9fe35b52a95
# Match case: =>  # Mass email campaign with a pinch of tar
# Number of images: => 0
#
#
# Report: => c1674110-3699-4516-8400-eae3fde677fd
# Match case: =>  # QBOT Malware Analysis
# Number of images: => 0
#
#
# Report: => 947d47e6-25f7-4699-b2ab-db324d5e85d4
# Match case: =>  # A Tale of PivNoxy and Chinoxy Puppeteer
# Number of images: => 0
#
#
# Report: => 7c27ceb4-40ca-42a9-9d64-c5d24624593a
# Match case: =>  # BlueSky Ransomware | AD Lateral Movemen
# Number of images: => 0
#
#
# Report: => dda739ec-1e7c-4276-beaa-4de8f48f13d3
# Match case: =>  # Lazarus ‘Operation In(ter)ception’ Targ
# Number of images: => 0
#
#
# Report: => 8aa7eb7a-2f0d-4ae4-9aeb-7c27297a40fb
# Match case: =>  # PyPI Phishing Campaign | JuiceLedger Th
# Number of images: => 0
#
#
# Report: => 3b5525ee-65dd-4867-89e1-86931b0b6b0e
# Match case: =>  # DeftTorero: tactics, techniques and pro
# Number of images: => 0
#
#
# Report: => 326433aa-9e2d-4f13-b443-3ea9db8d7ab4
# Match case: =>  # OnionPoison: infected Tor Browser insta
# Number of images: => 0
#
#
# Report: => 76db4d54-6b95-439d-b314-1d27f34d6cb1
# Match case: =>  # MAR-10365227-1.v1 - Impacket
# Number of images: => 0
#
#
# Report: => 8a208c8d-aaa8-4e1c-8bc4-dfb164d78394
# Match case: =>  # LockBit 3.0 Ransomware Distributed via
# Number of images: => 0
#
#
# Report: => 3476a3e5-d150-4f47-92f1-e3048588473b
# Match case: =>  # Worok: The big picture
# Number of images: => 0
#
#
# Report: => a0d4f75b-46fa-477c-bbfa-33252b3dc4e3
# Match case: =>  # #StopRansomware: Vice Society
# Number of images: => 0
#
#
# Report: => 4ce0c8c7-5d69-4768-b626-9c320803ddf0
# Match case: =>  # Mirai Variant MooBot Targeting D-Link D
# Number of images: => 0
#
#
# Report: => d74f9150-8726-43ae-802b-e9b4c726dfa3
# Match case: =>  # MagicRAT: Lazarus’ latest gateway into
# Number of images: => 0
#
#
# Report: => 0cb67701-d6a7-4d6c-8f8b-334eba8c4e0c
# Match case: =>  # Dead or Alive? An Emotet Story
# Number of images: => 0
#
#
# Report: => 4677914a-b652-4265-9c42-ac721cf34bf5
# Match case: =>  # New Wave of Espionage Activity Targets
# Number of images: => 2
#
#
# Report: => debd4ad1-bcfa-495c-85fc-206acb00c928
# Match case: =>  # A Post-exploitation Look at Coinminers
# Number of images: => 0
#
#
# Report: => d908758f-2c53-4fcc-9852-7b373db691be
# Match case: =>  # OriginLogger: A Look at Agent Tesla’s S
# Number of images: => 0
#
#
# Report: => 4ddecfd8-2b0b-4106-bf9c-78fe54139f8a
# Match case: =>  # WIP19 Espionage | New Chinese APT Targe
# Number of images: => 0
#
#
# Report: => 33735ea5-2795-4683-a7ae-f22816f372c0
# Match case: =>  # Iranian Islamic Revolutionary Guard Cor
# Number of images: => 0
#
#
# Report: => ad94cced-67ea-4df4-bc02-79fd0836f254
# Match case: =>  # Self-spreading stealer attacks gamers v
# Number of images: => 0
#
#
# Report: => 2898280a-f245-4896-88dd-afa438a32d2d
# Match case: =>  # Ransom Cartel Ransomware: A Possible Co
# Number of images: => 0
#
#
# Report: => a5bf4d51-7638-46e3-aabe-d834a4b2eaa0
# Match case: =>  # DiceyF deploys GamePlayerFramework in o
# Number of images: => 0
#
#
# Report: => e02e13f0-7d21-4796-afa3-b211d9742bcd
# Match case: =>  # Gamaredon APT targets Ukrainian governm
# Number of images: => 0
#
#
# Report: => fd8665c9-4f5f-4c4a-adf9-7f34fcb64e6b
# Match case: =>  # New PHP Variant of Ducktail Infostealer
# Number of images: => 0
#
#
# Report: => c9c705f1-f4dd-41c8-8804-6c0b09140b7f
# Match case: =>  # sczriptzzbn inject pushes malware for N
# Number of images: => 1
#
#
# Report: => 5739188a-69e4-4abe-b378-1ebab0245fa4
# Match case: =>  # Domain Shadowing: A Stealthy Use of DNS
# Number of images: => 0
#
#
# Report: => 83a2b332-209e-404f-8577-565480706de9
# Match case: =>  # Void Balaur | The Sprawling Infrastruct
# Number of images: => 0
#
#
# Report: => 002871d3-36d7-4bdc-9306-1555ab433456
# Match case: =>  # Watch Out for the New NFT-001
# Number of images: => 0
#
#
# Report: => 6df261a4-bde7-4e0b-918f-a35cdd437598
# Match case: =>  # #StopRansomware: Daixin Team
# Number of images: => 0
#
#
# Report: => 4fb080c1-68be-4512-8e91-6c9c997af1c4
# Match case: =>  # Broken Dreams and Piggy Banks: Pig Butc
# Number of images: => 1
#
#
# Report: => 07d6ebfe-a956-40fc-9cc4-9fd05e527673
# Match case: =>  # Buzzing in the Background: BumbleBee, a
# Number of images: => 0
#
#
# Report: => 7151f553-1d1c-4c76-8063-67a605153ada
# Match case: =>  # Exbyte: BlackByte Ransomware Attackers
# Number of images: => 2
#
#
# Report: => 693680d3-a1e6-4d5c-be0a-3a39a95c78eb
# Match case: =>  # Unveil the evolution of Kimsuky targeti
# Number of images: => 1
#
#
# Report: => d8fa75dd-8791-4296-a463-edf6b5a2b4bb
# Match case: =>  # Rapidly Evolving Magniber Ransomware
# Number of images: => 0
#
#
# Report: => c6698e24-dfad-4ff5-9338-779e1232958c
# Match case: =>  # Trends in Web Threats in CY Q2 2022: Ma
# Number of images: => 0
#
#
# Report: => c29d1eb5-447b-44b0-8274-959ecc0dcd4c
# Match case: =>  # NullMixer: oodles of Trojans in a singl
# Number of images: => 0
#
#
# Report: => 49aabf26-9342-4e1b-b3b1-f7eb8dc51966
# Match case: =>  # Cranefly: Threat Actor Uses Previously
# Number of images: => 2
#
#
# Report: => 429cbfe8-2eac-4b42-abd5-a091717d4b33
# Match case: =>  # Defeating Guloader Anti-Analysis Techni
# Number of images: => 0
#
#
# Report: => 1129afd1-c53b-4d51-a4b5-cf948d795100
# Match case: =>  # Banking Trojan Techniques: How Financia
# Number of images: => 0
#
#
# Report: => 22967eb1-a9e2-4735-bed6-571fa379fed0
# Match case: =>  # It's Time to PuTTY! DPRK Job Opportunit
# Number of images: => 0
#
#
# Report: => c093d571-fbef-433a-9598-80ab4131aeda
# Match case: =>  # Amazon-themed campaigns of Lazarus in t
# Number of images: => 0
#
#
# Report: => d2d4284a-3f2e-42a5-936c-3dba6e15c58d
# Match case: =>  # APT-36 Uses New TTPs and New Tools to T
# Number of images: => 0
#
#
# Report: => ec084372-172c-4ea7-990c-e20e12953e3d
# Match case: =>  # MAR-10365227-2.v1 - Impacket 2
# Number of images: => 0
#
#
# Report: => 60002856-844d-42c2-9eac-aaf82c653adf
# Match case: =>  # Analysis of LilithBot Malware and Etern
# Number of images: => 0
#
#
# Report: => 5cfccbc2-db9a-4a9d-a084-fc4afb5d0db6
# Match case: =>  # Agent Tesla RAT Delivered by Quantum Bu
# Number of images: => 0
#
#
# Report: => b39a903b-3fbf-47c5-b9cc-da98c34514df
# Match case: =>  # MSSQL, meet Maggie
# Number of images: => 0
#
#
# Report: => b0bfaa3c-a5cc-4cf4-9fd2-f557b5f2496e
# Match case: =>  # A Visualizza into Recent IcedID Campaig
# Number of images: => 0
#
#
# Report: => 9b534368-4119-41c5-a75a-455b24847d04
# Match case: =>  # POLONIUM targets Israel with Creepy mal
# Number of images: => 0
#
#
# Report: => 293e983f-8d72-4997-b137-ebff5be70c7b
# Match case: =>  # Budworm: Espionage Group Returns to Tar
# Number of images: => 2
#
#
# Report: => dc102dff-66af-44d9-9cfd-e1e89638c890
# Match case: =>  # 8220 Gang Cloud Botnet Targets Misconfi
# Number of images: => 0
#
#
# Report: => f98f6200-6592-4764-a268-21fd1148f69c
# Match case: =>  # Typhon Reborn With New Capabilities
# Number of images: => 0
#
#
# Report: => 848dead3-12ae-4166-83af-07d57b0a0196
# Match case: =>  # Billbug: State-sponsored Actor Targets
# Number of images: => 2
#
#
# Report: => 5334cd53-eb83-4bce-98de-4e9b7501749f
# Match case: =>  # DTrack activity targeting Europe and La
# Number of images: => 0
#
#
# Report: => 191577a7-0698-4b5b-b94a-e00610cf0452
# Match case: =>  # A Comprehensive Look at Emotet’s Fall 2
# Number of images: => 1
#
#
# Report: => 7d274d7a-8449-4c0c-82d1-89fbd023df2e
# Match case: =>  # Pilfered Keys: Free App Infected by Mal
# Number of images: => 0
#
#
# Report: => d3df6513-f12b-4a64-8756-36165a954cfc
# Match case: =>  # Venus Ransomware | Zeoticus Spin-off Sh
# Number of images: => 0
#
#
# Report: => 99c77347-1f67-40fa-ab92-cbda0dc507ae
# Match case: =>  # Get a Loda This: LodaRAT meets new frie
# Number of images: => 0
#
#
# Report: => 3d15f48a-e142-457b-8542-d5c5e8905f26
# Match case: =>  # HZ RAT goes China
# Number of images: => 0
#
#
# Report: => 28c63e31-d0a5-43c1-a9de-53c855a600ae
# Match case: =>  # GuLoader Malware Disguised as a Word Fi
# Number of images: => 0
#
#
# Report: => 2c6f4806-908c-4a9e-90ed-a1d59c43db26
# Match case: =>  # Attackers Abusing Various Remote Contro
# Number of images: => 0
#
#
# Report: => 63a81460-28a6-4c60-bad0-420408c22a78
# Match case: =>  # Android SharkBot Droppers on Google Pla
# Number of images: => 0
#
#
# Report: => 4816be38-424e-47b8-8148-7f58a70bfb2a
# Match case: =>  # WarHawk: the New Backdoor in the Arsena
# Number of images: => 0
#
#
# Report: => 9289fa54-ec23-4ef4-aae6-b97fe57df72c
# Match case: =>  # Beware of Cybercriminals Preying on Onl
# Number of images: => 0
#
#
# Report: => 8775851a-f163-4b40-a0c0-1ebd2ab115db
# Match case: =>  # Bahamut cybermercenary group targets An
# Number of images: => 0
#
#
# Report: => f9a2ea8f-a919-4e96-ab84-86006d7d5158
# Match case: =>  # Koxic Ransomware Being Distributed in K
# Number of images: => 0
#
#
# Report: => 5c85fec1-5124-4cb1-b85b-d8163f3e1a3e
# Match case: =>  # LV Ransomware Exploits ProxyShell in At
# Number of images: => 0
#
#
# Report: => 5f8c82bf-1712-4004-8768-22c9e87a748d
# Match case: =>  # Alchimist: A new attack framework in Ch
# Number of images: => 0
#
#
# Report: => 3688b452-62a7-4fdf-8ba2-6eae43604d98
# Match case: =>  # Emotet Strikes Again – LNK File Leads t
# Number of images: => 0
#
#
# Report: => 892f40dd-c24e-4143-9d3d-26d157b449d8
# Match case: =>  # Wiki Ransomware Being Distributed in Ko
# Number of images: => 0
#
#
# Report: => 407a98dd-9352-4591-bb14-07a8fa624045
# Match case: =>  # APT10: Tracking down LODEINFO 2022, par
# Number of images: => 0
#
#
# Report: => ecaeb510-1b70-41c3-b581-63228b15e066
# Match case: =>  # Who’s swimming in South Korean waters?
# Number of images: => 0
#
#
# Report: => fff4fed3-41e4-4a9a-8161-d6c3214ea62a
# Match case: =>  # LockBit 3.0 ‘Black’ attacks and leaks r
# Number of images: => 0
#
#
# Report: => 06702bff-4b94-4bfe-8c08-44ee5c074306
# Match case: =>  # ₿uyer ₿eware: Fake Cryptocurrency Appli
# Number of images: => 0
#
#
# Report: => b6f9be12-e8a8-4a04-8399-7bc8a15ada48
# Match case: =>  # Back in Black... Basta
# Number of images: => 0
#
#
# Report: => 40b1e6ec-67cf-4411-9e97-81c7e1b477d2
# Match case: =>  # Black Basta Ransomware | Attacks Deploy
# Number of images: => 0
#
#
# Report: => a2ac35ce-f5e5-4cf6-8491-016db6bcf09e
# Match case: =>  # Blowing Cobalt Strike Out of the Water
# Number of images: => 0
#
#
# Report: => 7f18b3ea-8a07-420b-8720-00a6bc98ad9d
# Match case: =>  # Vice Society: Profiling a Persistent Th
# Number of images: => 0
#
#
# Report: => c5f4530a-e393-4f8b-a6d2-e46ab2c3bef9
# Match case: =>  # Fantasy – a new Agrius wiper deployed t
# Number of images: => 0
#
#
# Report: => 7f25617c-ba26-4f92-999f-0716a6d9e0a9
# Match case: =>  # New MuddyWater Threat: Old Kitten; New
# Number of images: => 1
#
#
# Report: => 477c965b-b40b-4027-9932-797586dc47c0
# Match case: =>  # Hack the Real Box: APT41’s New Subgroup
# Number of images: => 0
#
#
# Report: => 32baa731-f63b-4a7b-8588-c85ab7d05b2c
# Match case: =>  # Mallox Ransomware showing signs of Incr
# Number of images: => 1
#
#
# Report: => bd61277d-3ed5-4eab-a328-1d95c8f6da40
# Match case: =>  # GoTrim: Go-based Botnet Actively Brute
# Number of images: => 0
#
#
# Report: => 3e04a108-49ec-44bd-9c65-262740c345a7
# Match case: =>  # Royal Rumble: Analysis of Royal Ransomw
# Number of images: => 1
#
#
# Report: => 566b6e62-1b63-4e01-8931-660dfa02e575
# Match case: =>  # Bumblebee: New Loader Rapidly Assuming
# Number of images: => 3
#
#
# Report: => e5ef5338-574a-4d15-8089-61ce58d2d11e
# Match case: =>  # Agenda Ransomware Uses Rust to Target M
# Number of images: => 0
#
#
# Report: => 216fce2e-3a79-4f8f-9209-75b51e8c37f9
# Match case: =>  # New RapperBot Campaign – We Know What Y
# Number of images: => 0
#
#
# Report: => 0bc21c0d-82ca-47bc-a889-b058c149d846
# Match case: =>  # Technical Analysis of the RedLine Steal
# Number of images: => 2
#
#
# Report: => 34464763-844b-498f-9303-4944d9e43d0b
# Match case: =>  # SentinelSneak: Malicious PyPI module po
# Number of images: => 0
#
#
# Report: => 87b7f3cf-db33-4401-b976-95ccb20fc28c
# Match case: =>  # Threat Spotlight: XLLing in Excel - thr
# Number of images: => 0
#
#
# Report: => 549fdfdb-5aac-4f83-a31e-38a600b21799
# Match case: =>  # Meddler-in-the-Middle Phishing Attacks
# Number of images: => 0
#
#
# Report: => f358c086-e46b-47aa-81a4-6c493cc71cdb
# Match case: =>  # Custom-Branded Ransomware: The Vice Soc
# Number of images: => 0
#
#
# Report: => d41e4fcf-7b03-4cda-ad68-ae7274344161
# Match case: =>  # Phishing Attacks Impersonating Famous K
# Number of images: => 0
#
#
# Report: => d58378bc-2ef3-46ca-ac4e-3012b21dda47
# Match case: =>  # Trying to Steal Christmas (Again!)
# Number of images: => 0
#
#
# Report: => e6abf30d-ad29-4b9a-a053-339060cb9898
# Match case: =>  # THREAT ALERT: Aggressive Qakbot Campaig
# Number of images: => 1
#
#
# Report: => 9b363133-0ce0-42a6-a4b5-4daebbe46c9d
# Match case: =>  # Ransomware Roundup - Cryptonite
# Number of images: => 0
#
#
# Report: => 690c6594-d03c-4fe5-8686-be9070041e1b
# Match case: =>  # Ransomware and wiper signed with stolen
# Number of images: => 0
#
#
# Report: => 3f2db979-df8a-473e-84c4-972390353a62
# Match case: =>  # Navigating the Vast Ocean of Sandbox Ev
# Number of images: => 0
#
#
# Report: => 97585c1e-21ac-4c69-bbe0-7f582fba93f6
# Match case: =>  # #StopRansomware: Cuba Ransomware
# Number of images: => 0
#
#
# Report: => 3259e7c7-6fcd-4732-b0e9-f0428c02333d
# Match case: =>  # W4SP continues to nest in PyPI: Same su
# Number of images: => 1
#
#
# Report: => 34bd688e-458c-4582-b854-c4998a6f0a9d
# Match case: =>  # Suspected Iran-Nexus TAG-56 Uses UAE Fo
# Number of images: => 3
#
#
# Report: => 42a04e01-4848-4655-b05c-37492e944998
# Match case: =>  # Mirai Botnet and Gafgyt DDoS Team Up Ag
# Number of images: => 1
#
#
# Report: => fc517e80-92b8-49f1-9c66-04c9f5ea4d66
# Match case: =>  # More Brazil malspam pushing Astaroth (G
# Number of images: => 1
#
#
# Report: => 3f937c45-32b2-4318-a2b6-304cf723f5f9
# Match case: =>  # Zerobot – New Go-Based Botnet Campaign
# Number of images: => 0
#
#
# Report: => bb7072ed-6110-47c0-b51b-0a981be7d1c2
# Match case: =>  # Threat Source newsletter (Jan. 5, 2023)
# Number of images: => 0
#
#
# Report: => 7d4ad78f-6dd7-41d6-9a27-48b76472de80
# Match case: =>  # AutoIT Remains Popular in the Malware L
# Number of images: => 1
#
#
# Report: => 1caaedbc-5b25-4c22-9404-850f22838f20
# Match case: =>  # Exposing TAG-53’s Credential Harvesting
# Number of images: => 3
#
#
# Report: => f0f2586c-5183-4cad-b8d7-b3f2b0f3453b
# Match case: =>  # Breaking the silence - Recent Truebot a
# Number of images: => 0
#
#
# Report: => 4c6a74e3-2be7-4505-80c8-ce59496cb6a0
# Match case: =>  # Raspberry Robin’s botnet second life
# Number of images: => 1
#
#
# Report: => 898e21c2-1e0c-48a9-ab9a-684a90b1a995
# Match case: =>  # DeathStalker targets legal entities wit
# Number of images: => 0
#
#
# Report: => 1864f508-7799-40bb-b502-96d243ab31f1
# Match case: =>  # Rhadamanthys: New Stealer Spreading Thr
# Number of images: => 1
#
#
# Report: => e7579b89-b363-468b-9b4a-f825358dec5c
# Match case: =>  # Probing Weaponized Chat Applications Ab
# Number of images: => 0
#
#
# Report: => fe22fa1b-8bf2-41a7-86cc-fe4731edc992
# Match case: =>  # Google ads lead to fake software pages
# Number of images: => 1
#
#
# Report: => 1a5e0000-927f-4a16-bba9-395cafb201af
# Match case: =>  # Gotta Catch ‘Em All | Understanding the
# Number of images: => 0
#
#
# Report: => d263751e-33dd-428a-9041-f85763848595
# Match case: =>  # CVE-2022-41040 and CVE-2022-41082 – zer
# Number of images: => 0
#
#
# Report: => dedd8bd9-8c7d-474b-b576-e051d67aacbe
# Match case: =>  # Batloader Malware Abuses Legitimate Too
# Number of images: => 0
#
#
# Report: => 7b855c66-773d-48b6-bbc0-ae6d4932c594
# Match case: =>  # Google ad traffic leads to stealer pack
# Number of images: => 1
#
#
# Report: => 654dcbe5-e1d8-4d88-9a67-765d40043e54
# Match case: =>  # Threat Brief: OWASSRF Vulnerability Exp
# Number of images: => 0
#
#
# Report: => a252b80c-69e0-4f7c-ad01-cff406c3f674
# Match case: =>  # Inside the IcedID BackConnect Protocol
# Number of images: => 0
#
#
# Report: => 0a6bcabc-b163-41fb-8479-177ad362d5b4
# Match case: =>  # Nitol DDoS Malware Installing Amadey Bo
# Number of images: => 0
#
#
# Report: => 7000adcd-5cec-495a-98a3-8df77a86df2d
# Match case: =>  # Vidar Stealer Exploiting Various Platfo
# Number of images: => 0
#
#
# Report: => d9990418-ab7b-473b-8060-5c83173312b6
# Match case: =>  # Qakbot Being Distributed via Virtual Di
# Number of images: => 0
#
#
# Report: => 97229530-802f-445e-a56e-6b3fcde0076d
# Match case: =>  # Album Stealer Targets Facebook Adult-On
# Number of images: => 0
#
#
# Report: => 63653205-cbd0-453e-8863-19a52719ca55
# Match case: =>  # Protecting Against Malicious Use of Rem
# Number of images: => 0
#
#
# Report: => 6d1c1025-7fed-4b07-9e85-0a1fb8d53974
# Match case: =>  # BlueNoroff introduces new methods bypas
# Number of images: => 0
#
#
# Report: => 1fd95e6c-4ba3-45ab-b79c-0c1e3b7f9b67
# Match case: =>  # Chinese PlugX Malware Hidden in Your US
# Number of images: => 0
#
#
# Report: => ed57ac05-c79a-4414-9e3b-6b3ca71c48c4
# Match case: =>  # New Mimic Ransomware Abuses Everything
# Number of images: => 0
#
#
# Report: => 0d20e5f2-41bc-422f-9156-73ccd0af26b5
# Match case: =>  # Analyzing and remediating a malware inf
# Number of images: => 0
#
#
# Report: => 8b9916cd-4279-440b-8800-835ff4adf3c2
# Match case: =>  # Google sponsored ads malvertising targe
# Number of images: => 0
#
#
# Report: => d865997c-a0e0-4082-b8ff-f37184bd66a2
# Match case: =>  # Machine Learning Versus Memory Resident
# Number of images: => 0
#
#
# Report: => e4bb707b-1ab7-4919-9f4e-5d3d2cb79509
# Match case: =>  # MalVirt  | .NET Virtualization Thrives
# Number of images: => 0
#
#
# Report: => 43f97428-5a72-4353-a397-98347b6d90a7
# Match case: =>  # Malicious LNK File Disguised as a Norma
# Number of images: => 0
#
#
# Report: => 0d724a6c-d48b-4ce0-8719-3deffa74e0ac
# Match case: =>  # Shc Linux Malware Installing CoinMiner
# Number of images: => 0
#
#
# Report: => 1f99c135-97d1-42a0-b868-4d3a1b530ab3
# Match case: =>  # Ransomware Roundup – Trigona
# Number of images: => 0
#
#
# Report: => 89edf297-3c42-43a8-9def-e3bd7fb54333
# Match case: =>  # New APT34 Malware Targets The Middle Ea
# Number of images: => 0
#
#
# Report: => 11b4bd8e-c007-47e1-92ba-0494892b8c16
# Match case: =>  # Bluebottle: Campaign Hits Banks in Fren
# Number of images: => 2
#
#
# Report: => 602f6856-c6e1-410b-957a-db0885dc7338
# Match case: =>  # PixPirate: a new Brazilian Banking Troj
# Number of images: => 0
#
#
# Report: => 7e16d027-3a21-47e2-ab49-02031907e490
# Match case: =>  # TgToxic Malware’s Automated Framework T
# Number of images: => 0
#
#
# Report: => 7bc09b4a-a87e-4ff1-ae05-7f6d90429e25
# Match case: =>  # Cl0p Ransomware Targets Linux Systems w
# Number of images: => 0
#
#
# Report: => 17f77d43-568a-451d-9bae-2912e7ca02e0
# Match case: =>  # Graphiron: New Russian Information Stea
# Number of images: => 2
#
#
# Report: => 2fd15978-40cb-4d96-836c-0c6cef3e2136
# Match case: =>  # Turla: A Galaxy of Opportunity
# Number of images: => 0
#
#
# Report: => ce452690-865e-49a3-8286-72a1a83fa79a
# Match case: =>  # Crypto-inspired Magecart skimmer surfac
# Number of images: => 0
#
#
# Report: => bd82212e-64d0-4801-84f7-8518dfb6553c
# Match case: =>  # Cloud Credentials Phishing | Malicious
# Number of images: => 0
#
#
# Report: => e14f2c92-258f-4bdf-bfec-6dcbdc231f10
# Match case: =>  # A Backdoor with Smart Screenshot Capabi
# Number of images: => 1
#
#
# Report: => a2e58e78-08ab-48d7-9302-a24811e43dc2
# Match case: =>  # #StopRansomware: Ransomware Attacks on
# Number of images: => 0
#
#
# Report: => 61d90b2e-8fc8-4247-be79-90cedbbe4147
# Match case: =>  # Open-source repository malware sows Hav
# Number of images: => 0
#
#
# Report: => dc82154c-59ab-47de-a667-6869ff8410c8
# Match case: =>  # StrongPity espionage campaign targeting
# Number of images: => 0
#
#
# Report: => aecd2125-89b6-4340-8a6e-e111a996eac1
# Match case: =>  # Gootkit Loader Actively Targets Austral
# Number of images: => 0
#
#
# Report: => 52433ebd-174b-4945-974b-a4a444bd8820
# Match case: =>  # NoName057(16) – The Pro-Russian Hacktiv
# Number of images: => 0
#
#
# Report: => b6d3596e-a05a-45ef-81d2-8f9db807ff1f
# Match case: =>  # Analysis of FG-IR-22-398 – FortiOS - he
# Number of images: => 0
#
#
# Report: => 27afd1b9-2698-4166-8e9b-1d9fc32c9e7e
# Match case: =>  # Gootloader Malware Leads to Cobalt Stri
# Number of images: => 3
#
#
# Report: => 66ef7de1-fdac-459c-8a3b-e6d558c58860
# Match case: =>  # Dalbit (m00nlight): Chinese Hacker Grou
# Number of images: => 0
#
#
# Report: => 4b9cdb39-9dd0-4b0f-b364-5c851bc21461
# Match case: =>  # Recent TZW Campaigns Revealed As Part o
# Number of images: => 0
#
#
# Report: => 55a710a2-0218-4dc9-8cbd-3fe564e5cbc4
# Match case: =>  # Frebniis: New Malware Abuses Microsoft
# Number of images: => 2
#
#
# Report: => 38732899-d6d5-4c81-8371-be91243ca2e2
# Match case: =>  # Mirai Variant V3G4 Targets IoT Devices
# Number of images: => 0
#
#
# Report: => 17f12c03-64a1-486f-9420-1c260a01bb1d
# Match case: =>  # Don’t Sleep on the New ProxyShellMiner
# Number of images: => 0
#
#
# Report: => 392b537c-cf3c-4aa3-95da-3ff37db1e2a4
# Match case: =>  # Malware Disguised as a Manuscript Solic
# Number of images: => 0
#
#
# Report: => 29aa3290-8aee-4248-9134-f9e87605749e
# Match case: =>  # Chinese Playful Taurus Activity in Iran
# Number of images: => 0
#
#
# Report: => eb0f2bda-18d2-4f55-b971-f94b81c5c3a2
# Match case: =>  # Roaming Mantis implements new DNS chang
# Number of images: => 0
#
#
# Report: => 7f7f5664-1895-4bef-a3fe-48c3bd2f9815
# Match case: =>  # Royal Ransomware Expands Attacks by Tar
# Number of images: => 0
#
#
# Report: => afd0e3f5-e901-414e-91e3-8f4df2b3b09a
# Match case: =>  # Darth Vidar: The Dark Side of Evolving
# Number of images: => 0
#
#
# Report: => 58703ae2-c49d-46ee-a6a3-d8113ca27102
# Match case: =>  # The Growing Threat of ChatGPT-Based Phi
# Number of images: => 1
#
#
# Report: => e7ac409c-0b3d-434b-8dc6-5a82db1b139e
# Match case: =>  # CVE-2022-47966: Rapid7 Observed Exploit
# Number of images: => 0
#
#
# Report: => 4a1aeee9-2d83-4351-bb99-1e7493051b42
# Match case: =>  # DragonSpark | Attacks Evade Detection w
# Number of images: => 0
#
#
# Report: => f2610452-5f2e-44cb-ba1d-a25910433ffb
# Match case: =>  # Clasiopa: New Group Targets Materials R
# Number of images: => 2
#
#
# Report: => 6e8c995c-fd00-44b0-9182-446a0b0a643c
# Match case: =>  # Realtek SDK Vulnerability Attacks Highl
# Number of images: => 0
#
#
# Report: => 2cc2513f-5aef-46d7-86c0-abb5a226606e
# Match case: =>  # The Titan Stealer: Infamous Telegram Ma
# Number of images: => 0
#
#
# Report: => 2eaee600-8b9e-4243-ab11-c84ab96c544e
# Match case: =>  # Evasive cryptojacking malware targeting
# Number of images: => 0
#
#
# Report: => 25d4ef7f-a908-487e-8b71-ba7b6524c2e3
# Match case: =>  # A year of wiper attacks in Ukraine
# Number of images: => 0
#
#
# Report: => 2bc2c6b9-c90f-4718-824b-4300397a1ebe
# Match case: =>  # DoNot Go! Do not respawn!
# Number of images: => 0
#
#
# Report: => a1e400cb-e235-429b-88b7-92c8cea4a309
# Match case: =>  # Blackfly: Espionage Group Targets Mater
# Number of images: => 2
#
#
# Report: => 4f9ec89a-5dba-41dc-b10a-8af8614800d4
# Match case: =>  # Hunting for Honkbox | Multistage macOS
# Number of images: => 0
#
#
# Report: => b6c11cc3-356f-4590-9f76-ab11dadfa8f3
# Match case: =>  # Threat Source newsletter (March 2, 2023
# Number of images: => 0
#
#
# Report: => 2360d426-9e9b-4d47-ac48-c16871506f47
# Match case: =>  # Spike in LokiBot Activity During Final
# Number of images: => 0
#
#
# Report: => 4ca6190a-1e7a-4414-9519-64d63189fc70
# Match case: =>  # Mustang Panda APT Group Uses European C
# Number of images: => 13
#
#
# Report: => 5483a5e5-aaeb-4884-a3f6-076fc1b70a97
# Match case: =>  # NETWIRE Dynamic Configuration Extractio
# Number of images: => 0
#
#
# Report: => 51d832b1-07ee-4c55-8171-81e4817a8b9c
# Match case: =>  # Dynamic Approaches seen in AveMaria's D
# Number of images: => 0
#
#
# Report: => 2153e26b-8b89-4d4c-9a6e-21a396cbe93d
# Match case: =>  # How SYS01 Stealer Will Get Your Sensiti
# Number of images: => 0
#
#
# Report: => ff363584-eb30-4488-9ef1-5241b8be14c2
# Match case: =>  # Sliver Malware With BYOVD Distributed T
# Number of images: => 0
#
#
# Report: => ce294018-ef29-43d3-8b71-155263661fd8
# Match case: =>  # DeepStreamer: Illegal movie streaming p
# Number of images: => 0
#
#
# Report: => edee2147-79ba-4683-b707-5d7720a5ab9a
# Match case: =>  # Nevada Ransomware: Yet Another Nokoyawa
# Number of images: => 0
#
#
# Report: => 3c6b17ac-c16f-44ce-9a7d-99fb8f27bde8
# Match case: =>  # Suspected Chinese Campaign to Persist o
# Number of images: => 0
#
#
# Report: => 43329ad1-ab2c-4489-a1c7-cfc7f0cc81e4
# Match case: =>  # Enigma Stealer Targets Cryptocurrency I
# Number of images: => 0
#
#
# Report: => 212d1f67-e6aa-4ae2-9f71-a5cb8f96bc9d
# Match case: =>  # Investigating Intrusions From Intriguin
# Number of images: => 0
#
#
# Report: => 1559ef1a-58cb-40aa-8a35-5ff5f2bd9830
# Match case: =>  # HWP Malware Using the Steganography Tec
# Number of images: => 0
#
#
# Report: => fd3da79f-a2ac-4351-87b5-fe885d5bf4a1
# Match case: =>  # Xenomorph v3: a new variant with ATS ta
# Number of images: => 0
#
#
# Report: => 44b268c0-70d5-43b6-bb4e-99c750cffe17
# Match case: =>  # CatB Ransomware | File Locker Sharpens
# Number of images: => 0
#
#
# Report: => 71809aec-7368-4f65-ac27-828a9fe82dff
# Match case: =>  # BatLoader Continues to Abuse Google Sea
# Number of images: => 3
#
#
# Report: => f5a1d08f-6bbc-4f0b-ad15-064e05a8d02d
# Match case: =>  # Havoc Across the Cyberspace
# Number of images: => 0
#
#
# Report: => cc185844-7071-43f0-842c-dae9756981d9
# Match case: =>  # WIP26 Espionage | Threat Actors Abuse C
# Number of images: => 0
#
#
# Report: => 5dfe2ba3-7ca0-48ed-b96f-bbea0e93f25a
# Match case: =>  # HookSpoofer: Amplifying Open Source Ste
# Number of images: => 0
#
#
# Report: => a8339e12-5c34-457e-84b6-d10fc72cea6c
# Match case: =>  # #StopRansomware: Ransomware Attacks on
# Number of images: => 0
#
#
# Report: => 5d778d58-7571-4656-91b1-967b5fa275af
# Match case: =>  # Bad magic: new APT found in the area of
# Number of images: => 0
#
#
# Report: => 9230ea36-ff33-46ab-8fa0-a667b318a214
# Match case: =>  # The Unintentional Leak: A glimpse into
# Number of images: => 0
#
#
# Report: => 81cca5f8-716e-4dcb-ab41-25538ce99a48
# Match case: =>  # Earth Kitsune Delivers New WhiskerSpy B
# Number of images: => 0
#
#
# Report: => 6eeda06c-0f0c-4213-ad17-eb1813148e2f
# Match case: =>  # Session Cookies, Keychains, SSH Keys an
# Number of images: => 0
#
#
# Report: => 543e0999-3838-4483-bbce-83f9ae78e0b2
# Match case: =>  # Operation Tainted Love | Chinese APTs T
# Number of images: => 0
#
#
# Report: => d0f023e6-00cf-424e-8a01-a367396d4746
# Match case: =>  # New Kritec Magecart skimmer found on Ma
# Number of images: => 0
#
#
# Report: => 0a86f461-40e7-4475-ba20-e1f359b5cc2a
# Match case: =>  # Technical Analysis of Rhadamanthys Obfu
# Number of images: => 0
#
#
# Report: => a7c12777-01b6-4191-9523-5267d13f9a2d
# Match case: =>  # Scarcruft Bolsters Arsenal for targetin
# Number of images: => 1
#
#
# Report: => dfb2c4ec-08e1-4c2d-9378-164c200c80c6
# Match case: =>  # Hydrochasma: Previously Unknown Group T
# Number of images: => 2
#
#
# Report: => 68da5162-5b48-4994-b506-9f9e8216957d
# Match case: =>  # URL files and WebDAV used for IcedID (B
# Number of images: => 1
#
#
# Report: => 30e32d02-7b52-4db8-8b63-aaffcf19cefb
# Match case: =>  # Updates from the MaaS: new threats deli
# Number of images: => 0
#
#
# Report: => 8527bbbe-210e-4c67-9a11-4f7ab4e9e429
# Match case: =>  # Copy-paste heist or clipboard-injector
# Number of images: => 0
#
#
# Report: => b11bddaa-2dc6-412c-9541-57562859e19b
# Match case: =>  # Desde Chile con Malware (From Chile wit
# Number of images: => 0
#
#
# Report: => 7e1a9f38-4177-4cae-a337-6e1119727d55
# Match case: =>  # Investigating the PlugX Trojan Disguise
# Number of images: => 0
#
#
# Report: => 99b22b61-36f1-4b17-9b6a-1be422e3ef89
# Match case: =>  # Answers to Unit 42 Wireshark Quiz, Febr
# Number of images: => 0
#
#
# Report: => 214858b7-7514-40ba-bce8-cdf5dcf9b8d6
# Match case: =>  # Makop: The Toolkit of a Criminal Gang
# Number of images: => 0
#
#
# Report: => 67765fb5-a518-46ff-8df2-6b52fa22580d
# Match case: =>  # Lumma Stealer targets YouTubers via Spe
# Number of images: => 1
#
#
# Report: => 4555c3e2-c750-493e-8b1b-d7b150165cd9
# Match case: =>  # OneNote: A Growing Threat for Malware D
# Number of images: => 0
#
#
# Report: => 3fa5c0b6-35d2-4e9a-b704-4dacc5017ff2
# Match case: =>  # Managed XDR Exposes Spear-Phishing Camp
# Number of images: => 0
#
#
# Report: => 399ec0ca-0eef-4312-b777-29de1ed59bf5
# Match case: =>  # BlackLotus UEFI bootkit: Myth confirmed
# Number of images: => 0
#
#
# Report: => 9240bb7b-bcf2-48bb-a7e4-1480daedc89c
# Match case: =>  # MQsTTang: Mustang Panda’s latest backdo
# Number of images: => 0
#
#
# Report: => cc500d90-8768-49ad-9be3-cda049b263da
# Match case: =>  # #StopRansomware: Cuba Ransomware
# Number of images: => 0
#
#
# Report: => 7b4f3f00-b0d5-4b7e-9cd5-1044fba6c91b
# Match case: =>  # BB17 distribution Qakbot (Qbot) activit
# Number of images: => 1
#
#
# Report: => dc7ba342-ce8c-4ef3-9014-306f38bd671e
# Match case: =>  # #StopRansomware: Hive Ransomware
# Number of images: => 0
#
#
# Report: => 9c78f61c-3012-42cd-ae23-79e95ae91ad1
# Match case: =>  # Can You See It Now? An Emerging LockBit
# Number of images: => 0
#
#
# Report: => 6f22f506-b7a8-4baf-b70b-689a07b82f69
# Match case: =>  # Parallax RAT Exploited by Threat Actor,
# Number of images: => 0
#
#
# Report: => ddb11c57-6392-4035-a2a2-9a3676f41fe9
# Match case: =>  # Just Because It’s Old Doesn’t Mean You
# Number of images: => 0
#
#
# Report: => 255eba4e-a5d7-4804-8cac-d25ecf94b9ef
# Match case: =>  # Not just an infostealer: Gopuram backdo
# Number of images: => 0
#
#
# Report: => 4005fa50-250c-497e-9a03-4f661c51fc16
# Match case: =>  # Supply Chain Compromise or False Positi
# Number of images: => 1
#
#
# Report: => 4d9eef1e-ed05-4a34-a09f-9e002d288a39
# Match case: =>  # Ransomware Roundup – Dark Power and Pay
# Number of images: => 0
#
#
# Report: => b982374e-c0d1-4218-8df7-4b1a44eb3aef
# Match case: =>  # Mantis: New Tooling Used in Attacks Aga
# Number of images: => 2
#
#
# Report: => 660a42a8-bf29-4a64-853c-53c551bc0523
# Match case: =>  # CryptoClippy Speaks Portuguese
# Number of images: => 0
#
#
# Report: => 14068c0e-cad5-4a87-9f1b-f3e46acf2c8e
# Match case: =>  # ImBetter: New Information Stealer Spott
# Number of images: => 1
#
#
# Report: => 0db5b6bf-3e16-47b8-89df-1eb6d751a06d
# Match case: =>  # New Cylance Ransomware with Power-Packe
# Number of images: => 1
#
#
# Report: => fb291f8d-4d1b-4dbe-8b73-c998ba6743ea
# Match case: =>  # Malvertising through search engines
# Number of images: => 0
#
#
# Report: => 4d0c9865-4922-4433-8256-3cf91ccc1a0c
# Match case: =>  # A Noteworthy Threat: How Cybercriminals
# Number of images: => 3
#
#
# ...
# Number of images: => 0
#
#
# Report: => 878fbff3-10b8-43b1-b3a8-27c50ae34011
# Match case: =>  # Tropic Trooper spies on government enti
# Number of images: => 0
#
#
# Report: => b5dd48ad-d78d-4092-a8c0-eaf8b765c790
# Match case: =>  # BlindEagle Targets Colombian Insurance
# Number of images: => 0
#
#
# Report: => f947d0d4-51fc-4da9-8078-5c5868bb48dd
# Match case: =>  # Scam Information and Event Management
# Number of images: => 0
#
#
# Report: => cb1a930d-8cf1-441e-98f9-a53093731e2f
# Match case: =>  # Chinese Hacker Group Stealing Informati
# Number of images: => 0
#
#
# Report: => 0887d0de-2274-4ff5-93dc-ab3cc6df02ac
# Match case: =>  # Awaken Likho is awake: new techniques o
# Number of images: => 0
#
#
# Report: => 11729083-34bc-4277-9067-c77ad04a59c3
# Match case: =>  # CUCKOO SPEAR Part 2: Threat Actor Arsen
# Number of images: => 1
#
#
# Report: => 48ca4b2e-a190-44c4-8ed6-12f58df5fd55
# Match case: =>  # Exploring GenAI in Cybersecurity: Gemin
# Number of images: => 0
#
#
# Report: => 13296e49-ed2e-4452-886a-d7cd1956177f
# Match case: =>  # Russian Military Cyber Actors Target US
# Number of images: => 0
#
#
# Report: => 7133e274-75f3-4e5a-929f-c66f78d703e4
# Match case: =>  # Enrichment Data: Keeping it Fresh
# Number of images: => 1
#
#
# Report: => 1cf5c2df-bd5c-4bf0-bce0-1428233b4757
# Match case: =>  # MisterioLNK: The Open-Source Builder Be
# Number of images: => 1
#
#
# Report: => b1cfe1fc-8e4f-446e-8db9-2a0402918774
# Match case: =>  # Shining Light on the Dark Angels Ransom
# Number of images: => 0
#
#
# Report: => 98ea9e1a-1909-4341-a617-9647a3a7152b
# Match case: =>  # Chinese APT Abuses VSCode to Target Gov
# Number of images: => 0
#
#
# Report: => 03e6ce95-a585-4388-8e4f-fd944af36f31
# Match case: =>  # Threat Assessment: North Korean Threat
# Number of images: => 0
#
#
# Report: => 1c788cd5-3202-41df-95aa-9ab41152ec1a
# Match case: =>  # Analyzing Recent Cyber Attacks in the U
# Number of images: => 2
#
#
# Report: => 9eecd5e4-1f48-4250-b69c-b3caf482f4a7
# Match case: =>  # Threat Assessment: Repellent Scorpius,
# Number of images: => 0
#
#
# Report: => 164b21ce-b802-418e-bdaf-6fdcd13a3b0e
# Match case: =>  # From Amos to Poseidon | A SOC Team’s Gu
# Number of images: => 0
#
#
# Report: => c3d60a26-c13f-4653-84ce-03958a373366
# Match case: =>  # Hadooken Malware Targets Weblogic Appli
# Number of images: => 0
#
#
# Report: => c622c7cd-bcca-4684-a71a-acbe3425c87f
# Match case: =>  # Lynx Ransomware: A Rebranding of INC Ra
# Number of images: => 0
#
#
# Report: => d87f7131-6d5f-474a-a11d-ec23d6413fd5
# Match case: =>  # Earth Simnavaz (aka APT34) Levies Advan
# Number of images: => 0
#
#
# Report: => 2c32d49f-ea9f-4e33-b199-3d2b5a4f87fa
# Match case: =>  # Core Werewolf hones its arsenal against
# Number of images: => 0
#
#
# Report: => 60580360-d6d8-415f-9860-e2f5db082f7f
# Match case: =>  # Hidden in Plain Sight: ErrorFather’s De
# Number of images: => 1
#
#
# Report: => 6fff48df-b1a1-43b6-a8fc-6ca075f4f6bc
# Match case: =>  # Water Makara Uses Obfuscated JavaScript
# Number of images: => 0
#
#
# Report: => 241f0b91-a369-4379-b7a6-bdd2322e41af
# Match case: =>  # Silent Threat: Red Team Tool EDRSilence
# Number of images: => 0
#
#
# Report: => cbe79f97-b25f-428b-9219-bd539f9f85c5
# Match case: =>  # Beyond the Surface: the evolution and e
# Number of images: => 0
#
#
# Report: => 84577cce-bb35-4fff-b58d-443d184ee90a
# Match case: =>  # HijackLoader evolution: abusing genuine
# Number of images: => 0
#
#
# Report: => 493b7898-5f4d-47f1-95ca-1e2ff97054c2
# Match case: =>  # Iranian Cyber Actors’ Brute Force and C
# Number of images: => 0
#
#
# Report: => 0e531c70-1dd4-452a-8e02-09742dbf4781
# Match case: =>  # Fake LockBit, Real Damage: Ransomware S
# Number of images: => 0
#
#
# Report: => 1b797c0d-41b2-4ac1-bdfc-19723d5366e0
# Match case: =>  # From Automation to Exploitation: The Gr
# Number of images: => 21
#
#
# Report: => a212c926-ff9f-44ff-b6e9-982cb7517c8f
# Match case: =>  # Phishing Pages Delivered Through Refres
# Number of images: => 0
#
#
# Report: => 6007db76-c12e-4ea7-bca9-8240438b0b44
# Match case: =>  # Medusa Ransomware: A Growing Threat wit
# Number of images: => 0
#
#
# Report: => 4748b5bb-5611-47b7-b6a3-70b15a9715e3
# Match case: =>  # Protecting Against RCE Attacks Abusing
# Number of images: => 0
#
#
# Report: => 32cf0cdf-46f3-4104-9821-fb83edbedbcd
# Match case: =>  # SAS CTF and the many ways to persist a
# Number of images: => 0
#
#
# Report: => 58005872-de43-471d-a9b5-556f38d0ce9a
# Match case: =>  # Unmasking CVE-2024-38178: The Silent Th
# Number of images: => 1
#
#
# Report: => 74b878e8-b1b3-4f18-a300-6edca3b4b59b
# Match case: =>  # #StopRansomware: Rhysida Ransomware
# Number of images: => 0
#
#
# Report: => 21965140-1475-4b70-8e82-2d416b645f90
# Match case: =>  # WebDAV-as-a-Service: Uncovering the inf
# Number of images: => 1
#
#
# Report: => eca72e88-88b5-40a6-baba-845eb7d99458
# Match case: =>  # Earth Baxia Uses Spear-Phishing and Geo
# Number of images: => 0
#
#
# Report: => 4fecdea8-c02b-4d8b-a22b-64435ac66908
# Match case: =>  # Supershell Malware Being Distributed to
# Number of images: => 0
#
#
# Report: => bd2fb4ed-79e9-418c-a335-3d803f137f5a
# Match case: =>  # THREAT ANALYSIS: Beast Ransomware
# Number of images: => 1
#
#
# Report: => 134a1362-70e6-4d18-b1e9-938c9784da6b
# Match case: =>  # Tricks and Treats: GHOSTPULSE’s new pix
# Number of images: => 0
#
#
# Report: => ba9b8cb9-8684-409f-8dbe-90c586ca2d1b
# Match case: =>  # Analysis of the Crypt Ghouls group: con
# Number of images: => 0
#
#
# Report: => dc9bd658-e299-49cb-aefb-71967141f0f4
# Match case: =>  # Stealer here, stealer there, stealers e
# Number of images: => 0
#
#
# Report: => dbfaf849-a454-4bbe-8666-3cb9bccf1d3d
# Match case: =>  # Using gRPC and HTTP/2 for Cryptominer D
# Number of images: => 0
#
#
# Report: => 8c90808e-c799-4107-84f2-0dbfe5cc0afc
# Match case: =>  # Akira ransomware continues to evolve
# Number of images: => 0
#
#
# Report: => 1cf1e8f8-cd4b-4455-9bff-3f4a7cdedde0
# Match case: =>  # Attackers Target Exposed Docker Remote
# Number of images: => 0
#
#
# Report: => 06c1c27f-aa06-4c58-a57f-9762120e382f
# Match case: =>  # Experts warn of a new wave of Bumblebee
# Number of images: => 0
#
#
# Report: => 6f88a5e3-f8ad-4069-a6f3-018164d704a1
# Match case: =>  # Grandoreiro, the global trojan with gra
# Number of images: => 0
#
#
# Report: => da8e9142-20f0-4ede-b9ad-75559b28e783
# Match case: =>  # The Crypto Game of Lazarus APT: Investo
# Number of images: => 0
#
#
# Report: => b9d18820-b546-41e4-8c65-9985fab2e6db
# Match case: =>  # Unveiling Triad Nexus: How FUNNULL CDN
# Number of images: => 0
#
#
# Report: => 7d25db9a-0a73-40ca-971d-b41719ca3f43
# Match case: =>  # -=TWELVE=- is back
# Number of images: => 0
#
#
# Report: => ab619b73-f7af-45de-bcfd-8f7a188d8a70
# Match case: =>  # Embargo ransomware: Rock’n’Rust
# Number of images: => 0
#
#
# Report: => 96fa162b-d10e-493f-a032-e78aec57e339
# Match case: =>  # Inside SnipBot: The Latest RomCom Malwa
# Number of images: => 0
#
#
# Report: => c8b7f7cb-1e6b-4b78-9f0e-65c3d79d4de2
# Match case: =>  # Understanding the Initial Stages of Web
# Number of images: => 0
#
#
# Report: => 441af0ba-500f-4f77-b3d2-760ee57be22d
# Match case: =>  # How the Necro Trojan infiltrated Google
# Number of images: => 0
#
#
# Report: => 362b9b9a-5750-44a4-85be-eee42565761f
# Match case: =>  # Kryptina RaaS | From Unsellable Cast-Of
# Number of images: => 0
#
#
# Report: => 8b003be9-a375-4fb9-8d8b-3bde7bd6d1dd
# Match case: =>  # How Ransomhub Ransomware Uses EDRKillSh
# Number of images: => 0
#
#
# Report: => 6ce29c7e-2d6a-43c9-8d4f-54dbace91916
# Match case: =>  # ReadText34 Ransomware Incident
# Number of images: => 0
#
#
# Report: => 490db90d-ebb8-4476-88c5-78db79c9d7dc
# Match case: =>  # Security Brief: Actor Uses Compromised
# Number of images: => 1
#
#
# Report: => 705262de-8644-4ed1-9bf2-4e04c9d9afac
# Match case: =>  # Unraveling Sparkling Pisces’s Tool Set:
# Number of images: => 0
#
#
# Report: => 04ab839d-108a-4290-a46f-28eccff3ef09
# Match case: =>  # HeptaX: Unauthorized RDP Connections fo
# Number of images: => 1
#
#
# Report: => d922082c-47d2-4135-9f2d-2a199d63893f
# Match case: =>  # TeamTNT’s Docker Gatling Gun Campaign
# Number of images: => 0
#
#
# Report: => a0920a6f-2396-4919-9af2-056e836182b0
# Match case: =>  # Uncovering the Lounge Pass Scam Campaig
# Number of images: => 2
#
#
# Report: => 5ee1efaf-0b06-49ad-8e03-13491fe20a0d
# Match case: =>  # The Good, the Bad and the Ugly in Cyber
# Number of images: => 0
#
#
# Report: => ac4d57b8-a6e3-49fa-97b9-e168ced79bca
# Match case: =>  # CloudScout: Evasive Panda scouting clou
# Number of images: => 0
#
#
# Report: => a4aab77d-0331-4da0-9003-e2920d564996
# Match case: =>  # Lumma/Amadey: fake CAPTCHAs want to kno
# Number of images: => 0
#
#
# Report: => 25bca896-6320-4365-af8d-ad04583da27e
# Match case: =>  # More Than Just a Corporate Wiki? How Th
# Number of images: => 1
#
#
# Report: => 07cbea9c-1c17-45df-9092-1881b80b2e61
# Match case: =>  # Strela Stealer targets Central and Sout
# Number of images: => 1
#
#
# Report: => 8b4f5ee5-2968-4425-a0e0-424515acff63
# Match case: =>  # Inside Intelligence Center: LUNAR SPIDE
# Number of images: => 13
#
#
# Report: => 51e52f5d-345f-4dc9-8074-a4329f5d057e
# Match case: =>  # Pacific Rim timeline: Information for d
# Number of images: => 0
#
#
# Report: => 3e92af08-5b90-4249-8392-5aadc88f6296
# Match case: =>  # Separating the bee from the panda: Cera
# Number of images: => 0
#
#
# Report: => 36902870-3ddf-4a1d-be63-972707081d71
# Match case: =>  # Stonefly: Extortion Attacks Continue Ag
# Number of images: => 2
#
#
# Report: => 545cde54-727d-4b82-a39b-0266a8f639a5
# Match case: =>  # perfctl: A Stealthy Malware Targeting M
# Number of images: => 0
#
#
# Report: => 56f5ae63-0576-48a1-81e6-5e35d3d7d4a9
# Match case: =>  # No Way to Hide: Uncovering New Campaign
# Number of images: => 0
#
#
# Report: => f8ec21fa-61dc-4a46-af25-fe6947309be4
# Match case: =>  # TA Phone Home: EDR Evasion Testing Reve
# Number of images: => 0
#
#
# Report: => e1bf1708-12bd-4e79-9b9e-a285b77b5f1a
# Match case: =>  # Attacker Abuses Victim Resources to Rea
# Number of images: => 0
#
#
# Report: => 1ebdc932-3650-476e-9a96-02640abf49b3
# Match case: =>  # Cloudy With a Chance of RATs: Unveiling
# Number of images: => 1
#
#
# Report: => d6c09d24-6fdb-4b8a-9145-f5a5d8ecd252
# Match case: =>  # Automatically Detecting DNS Hijacking i
# Number of images: => 0
#
#
# Report: => ebff1d61-7507-45c1-834a-6720dd687506
# Match case: =>  # Analyzing an Encrypted Phishing PDF
# Number of images: => 1
#
#
# Report: => 02405e94-774e-418e-a725-a759c922ddc1
# Match case: =>  # Venture Wolf attempts to disrupt Russia
# Number of images: => 0
#
#
# Report: => 005cb3b3-926b-430f-abf1-61f061d7383d
# Match case: =>  # Python RAT with a Nice Screensharing Fe
# Number of images: => 1
#
#
# Report: => a2096f8b-b5a4-4a91-8148-31239c0df7b0
# Match case: =>  # Investigating a SharePoint Compromise:
# Number of images: => 0
#
#
# Report: => c12b02f9-4ab8-4733-b7b4-90f85d14884a
# Match case: =>  # ToxicPanda: a new banking trojan from A
# Number of images: => 0
#
#
# Report: => 2550ad8d-ccaf-4a31-b850-90363b6adbd1
# Match case: =>  # Bengal cat lovers in Australia get pssp
# Number of images: => 0
#
#
# Report: => 2d032dd8-f6e6-45d0-adb9-4baa23702abe
# Match case: =>  # Mamba 2FA: A new contender in the AiTM
# Number of images: => 1
#
#
# Report: => e6c09380-bd56-4430-91f0-1b07b8671d9b
# Match case: =>  # Wreaking havoc in cyberspace: threat ac
# Number of images: => 0
#
#
# Report: => 59c38333-73b3-462c-91c4-cdec160e8b2d
# Match case: =>  # Not All Fun and Games: Lua Malware Targ
# Number of images: => 0
#
#
# Report: => 049a8766-d18e-4b7c-9997-59c267ad144e
# Match case: =>  # DPRK-linked BlueNoroff used macOS malwa
# Number of images: => 0
#
#
# Report: => 1456c5c4-ab87-4215-bf27-a18e9ee7b6fd
# Match case: =>  # European diplomats targeted by APT29 (C
# Number of images: => 0
#
#
# Report: => 49e5a3df-0c15-4b96-9064-0ef05ab97fc9
# Match case: =>  # 2024 Credit Card Theft Season Arrives
# Number of images: => 0
#
#
# Report: => 5bb17291-a23f-4f2a-9678-d517a10e5790
# Match case: =>  # From Perfctl to InfoStealer
# Number of images: => 1
#
#
# Report: => 82d4ef6e-2fe4-4cf3-b980-6f13f3f84acc
# Match case: =>  # Contagious Interview: DPRK Threat Actor
# Number of images: => 0
#
#
# Report: => 89715e52-d1c5-439d-8a1d-68869a87b911
# Match case: =>  # QSC: A multi-plugin framework used by C
# Number of images: => 0
#
#
# Report: => efd659d9-eaf6-48f2-8928-a5155b79e309
# Match case: =>  # CVE-2024-38213: From Crumbs to Full Com
# Number of images: => 1
#
#
# Report: => 5aaaf115-9429-4303-b90f-34d9c3b41cfb
# Match case: =>  # Operation MiddleFloor: Disinformation c
# Number of images: => 1
#
#
# Report: => 85015e2c-26bf-40cf-81c7-105c17cfc794
# Match case: =>  # Core Werewolf hones its arsenal against
# Number of images: => 0
#
#
# Report: => da0ecd4e-407c-4437-b920-05a6a511a8a2
# Match case: =>  # "Don't feed the toll troll": Silent Pus
# Number of images: => 0
#
#
# Report: => d69cbedd-44ac-4f8e-a46a-2b70ee481c44
# Match case: =>  # Malware Steals Account Credentials
# Number of images: => 0
#
#
# Report: => f9aceb14-8c32-4d47-ad5a-24348da1a442
# Match case: =>  # Hello again, FakeBat: popular loader re
# Number of images: => 0
#
#
# Report: => d2775533-2522-44a5-84af-c7545480f2f2
# Match case: =>  # Ymir: new stealthy ransomware in the wi
# Number of images: => 0
#
#
# Report: => e4d78c01-de09-4212-a7a3-62673c0a8ac2
# Match case: =>  # Mozi Resurfaces as Androxgh0st Botnet:
# Number of images: => 2
#
#
# Report: => 2b580e07-22d0-4d90-93f9-7d18efa95cfe
# Match case: =>  # Harnessing Chisel for Covert Operations
# Number of images: => 1
#
#
# Report: => c9e49348-4342-48c4-b6ba-a11759617410
# Match case: =>  # China-Nexus TAG-112 Compromises Tibetan
# Number of images: => 3
#
#
# Report: => 35e22189-3de6-4296-9a0d-0a818fd80fd7
# Match case: =>  # PHP Reinfector and Backdoor Malware Tar
# Number of images: => 0
#
#
# Report: => f2acdda4-d8c6-4244-91d9-95fa3dfd94b7
# Match case: =>  # The State of Cloud Ransomware in 2024
# Number of images: => 0
#
#
# Report: => 37d89695-9d51-490f-8b96-62fe54421940
# Match case: =>  # Malware Spotlight:  A Deep-Dive Analysi
# Number of images: => 1
#
#
# Report: => 5c89e4d5-4179-4720-9ba3-02feb5517e03
# Match case: =>  # Fake North Korean IT Worker Linked to B
# Number of images: => 0
#
#
# Report: => 16468486-df79-4a94-beac-5b3a32d2aad9
# Match case: =>  # Inside Water Barghest’s Rapid Exploit-t
# Number of images: => 0
#
#
# Report: => 0206906c-cd57-4436-ada7-1d800d36ae76
# Match case: =>  # Telekopye transitions to targeting tour
# Number of images: => 0
#
#
# Report: => 233d9141-4dff-4db6-ac55-814699e13b11
# Match case: =>  # Mind the (air) gap: GoldenJackal gooses
# Number of images: => 0
#
#
# Report: => 74460ee0-8f76-49ea-9820-18812df3f00a
# Match case: =>  # Life on a crooked RedLine: Analyzing th
# Number of images: => 0
#
#
# Report: => 7a6358e0-a26a-4dea-a9b7-9bdd82f14bf2
# Match case: =>  # Sailing Into Danger: DONOT APT’s Attack
# Number of images: => 1
#
#
# Report: => cffaefc7-9ae0-4b23-9d1f-ec2a0c19fd76
# Match case: =>  # BrazenBamboo Weaponizes FortiClient Vul
# Number of images: => 0
#
#
# Report: => 9231cae1-27de-4a77-956b-8a6d17286b4f
# Match case: =>  # Threat Brief: Operation Lunar Peek, Act
# Number of images: => 0
#
#
# Report: => ae6bf849-79d1-4fe3-aa1f-4d6aec4ea8d1
# Match case: =>  # Spot the Difference: Earth Kasha's New
# Number of images: => 0
#
#
# Report: => 536dfd26-ac2e-4a8f-ad7f-26290380f98d
# Match case: =>  # FrostyGoop’s Zoom-In: A Closer Look int
# Number of images: => 0
#
#
# Report: => dd9b1034-9b2a-4cde-b197-02f88fd132a8
# Match case: =>  # Unraveling Raspberry Robin's Layers: An
# Number of images: => 0
#
#
# Report: => c8634df0-4b2f-4ce1-9eb3-eaf5133cc5c6
# Match case: =>  # Threat Actors Hijack Misconfigured Serv
# Number of images: => 0
#
#
# Report: => 2e8d943c-1670-4fd0-a4db-66af84013f09
# Match case: =>  # One Sock Fits All: The use and abuse of
# Number of images: => 0
#
#
# Report: => c3fe424f-6484-421a-b8f8-0fc3a9fa1a70
# Match case: =>  # Differential analysis raises red flags
# Number of images: => 1
#
#
# Report: => 8c5ed2c6-780e-4ae7-be0e-908a9921d9e4
# Match case: =>  # Unveiling WolfsBane: Gelsemium’s Linux
# Number of images: => 0
#
#
# Report: => a1e7a45b-6bcc-464b-ac9a-53056054ba31
# Match case: =>  # Know Thy Enemy: A Novel November Case o
# Number of images: => 0
#
#
# Report: => d4e304fa-aff2-4c17-8999-5f566a33952c
# Match case: =>  # Unveiling the Past and Present of APT-K
# Number of images: => 0
#
#
# count    1200.000000
# mean        0.468333
# std         1.726214
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        21.000000
# dtype: float64

# %%
# Clean formatted
mm = [k for k, v in formatted_data.items() if "## Main menu" in v]
atu = [k for k, v in formatted_data.items() if "## About the Author" in v]

print(f"Main menu: {len(mm)}")
print(f"About the Author: {len(atu)}")
# Out:
# Main menu: 53
# About the Author: 66

# %%
#print(data[rn])

# %%
# print(formatted_data[rn])

# %%
# # Compare failed raw reports with initial reports
# for f in failed_raw_list:
#     fname = f.split("-ref")[0] + ".txt"
#     if fname in os.listdir("C:/Users/AIAS/Documents/cti-model-training/data/reports"):
#         print(fname)
