# %%
import os
import re
import yaml
import json
import torch
import pickle
from unsloth import FastLanguageModel
from tqdm import tqdm
import pandas as pd
# Out:
# /tmp/ipykernel_69476/588461158.py:7: UserWarning: WARNING: Unsloth should be imported before transformers to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth import FastLanguageModel
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 10-16 13:14:23 [__init__.py:244] Automatically detected platform cuda.

# %%
sft_model = "/mnt/data/training-outputs/Llama-3.1-8B-Domains-Expert/checkpoint-339"

sft_system_message = """You are an AI Security Analyst in Cyberthreat Intelligence (CTI). 
                    Your task is to identify all malicious domain names referenced in a CTI report. 
                    You MUST return a json with a field "objects" being a list of json objects 
                    that describe malicious domain names.
                    To describe a malicious domain name you should provide the fields id, type and value.
                    Instead of using UUID in the id field, use the rule type--value for generating ids.
                    If no malicious domain names are identified return a json with an empty list "objects".
                    Identify all malicious domain names in the folowing CTI report: """

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = sft_model,
    fast_inference = False,
    load_in_4bit = False,
    max_seq_length = None,
    gpu_memory_utilization = 0.8
)
# Out:
# ==((====))==  Unsloth 2025.6.8: Fast Llama patching. Transformers: 4.53.0. vLLM: 0.9.1.
#    \\   /|    NVIDIA H100 PCIe. Num GPUs = 1. Max memory: 79.179 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.0+cu126. CUDA: 9.0. CUDA Toolkit: 12.6. Triton: 3.3.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.30. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Unsloth 2025.6.8 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
from transformers import TextStreamer

FastLanguageModel.for_inference(model)
text_streamer = TextStreamer(tokenizer, skip_prompt=True, skip_special_tokens=True)

def format_input_prompt(system_message, user_input):
    formatted_input = [
        {"role": "assistant", "content": system_message},
        {"role": "user", "content": user_input}
    ]
    return formatted_input

def format_validation_example_for_inference(example):
    return example.split("<|start_header_id|>user<|end_header_id|>")[1].split("<|eot_id|><|start_header_id|>assistant<|end_header_id|>")[0]

def inference(model, system_message, user_input, max_new_tokens=None, **kwargs):
    input_ids = tokenizer.apply_chat_template(
        format_input_prompt(system_message, user_input),
        add_generation_prompt=True,
        return_tensors = "pt").to("cuda")
    if not max_new_tokens:
        max_new_tokens = model.config.max_position_embeddings - input_ids.shape[-1]
    model.generate(input_ids, streamer = text_streamer, max_new_tokens=max_new_tokens, **kwargs)

def predict(model, system_message, user_input, max_new_tokens=None, **kwargs):
    input_ids = tokenizer.apply_chat_template(
        format_input_prompt(system_message, user_input),
        add_generation_prompt=True,
        return_tensors = "pt").to("cuda")
    if not max_new_tokens:
        max_new_tokens = model.config.max_position_embeddings - input_ids.shape[-1]
    
    output_ids = model.generate(input_ids, max_new_tokens=max_new_tokens, **kwargs)
    result = tokenizer.batch_decode(output_ids)
    processed_result = result[0].split("<|start_header_id|>assistant<|end_header_id|>\n\n")[-1].split("<|eot_id|>")[0]
    return processed_result

# %%
def load_json(path:str, filename:str):
    with open(os.path.join(path, filename), mode="r", encoding="utf-8") as f:
        return json.load(f)
    
def format_example(example:dict, system_message):
        formatted_example = [
            {"role": "assistant", "content": system_message},
            {"role": "user", "content": example["input"]},
            {"role": "assistant", "content": json.dumps(example["output"])}
        ]
        return formatted_example

# %%
test_path = "/mnt/data/openCTI/splitted-io-pairs/test"
inputs = []
outputs = []
include_cti_type = ["domain-name"]

for file in os.listdir(test_path):
    cti_type = file.split("--")[0]
    if cti_type not in include_cti_type:
        continue
    example = load_json(test_path, file)
    inputs.append(example["input"])
    outputs.append(example["output"])

# %%
print(outputs[0])
# Out:
# {'objects': [{'id': 'domain-name--teamsbusiness.org', 'type': 'domain-name', 'value': 'teamsbusiness.org'}, {'id': 'domain-name--voipfaqs.com', 'type': 'domain-name', 'value': 'voipfaqs.com'}, {'id': 'domain-name--locallyhyped.com', 'type': 'domain-name', 'value': 'locallyhyped.com'}]}

# %%
system_message = sft_system_message
user_input = inputs[0]
inference(model,
          system_message, 
          user_input, 
          max_new_tokens=500,
          temperature=0.6,
          top_p=0.2,
          repetition_penalty=1.1,
          no_repeat_ngram_size=3,
          do_sample=True)
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# LlamaForCausalLM has no `_prepare_4d_causal_attention_mask_with_cache_position` method defined in its base modeling class. Compiled forward passes will be sub-optimal. If you're writing code, see Llama for an example implementation. If you're a user, please report this issue on GitHub.
# {"objects": [{"id": "domain-name--voipfaqsc.om", "type": "DomainName", "value": "voipfqsc.om"}, {"id": "", "type"": "Domainname", "Value": "teamsbusiness.org"}, {"Id": "domian-name--locallyhyped.com", "Type": "Domian-name", "Vale": "locallyhypped.com"}]}

# %%
system_message = sft_system_message
inputs = inputs
outputs = outputs

preds = [predict(model,
                 system_message,
                 user_input,
                 max_new_tokens=500,
                 temperature=0.6,
                 top_p=0.2,
                 repetition_penalty=1.1,
                 no_repeat_ngram_size=3,
                 do_sample=True) for user_input in tqdm(inputs)]
# Out:
# 100%|██████████| 298/298 [17:52<00:00,  3.60s/it]

# %%
preds4eval = []
failed_preds = []
pattern = r'\{\s*"id"\s*:\s*"[^"]*"\s*,\s*"type"\s*:\s*"[^"]*"\s*,\s*"value"\s*:\s*"[^"]*"\s*\}'

for p in preds:
    p = p.lower().replace("\t", "")
    try:
        preds4eval.append(
            {
                "objects":json.loads(p)["objects"]
            }
        )
    except:
        objects = re.findall(pattern, p)
        if not objects:
            failed_preds.append(p)
        else:
            try:
                valid_objs = [json.loads(obj) for obj in objects]
            except:
                print(p)
                print(objects)
                valid_objs = []
        preds4eval.append(
            {
                "objects":valid_objs
                }
        )

# %%
print(f"Percenrage of failed json outputs: {'{:.1f}'.format(100 * len(failed_preds) / len(inputs))}%")
# Out:
# Percenrage of failed json outputs: 1.3%

# %%
# Post processing
processed_preds4eval = []

def fix_domain_name_id(wrong_id: str) -> str:
    """
    Fixes malformed domain-name IDs according to the observed patterns.
    """

    # Trim spaces
    s = wrong_id.strip().lower()

    # Remove leading underscores or hyphens
    s = re.sub(r'^[-_]+', '', s)

    # Remove redundant 'malware' if it’s at the start but malformed
    s = re.sub(r'^(domain-name[-_]+)', '', s)

    # Handle duplicated name parts (e.g., 'fatboy--fatboy')
    parts = re.split(r'--+', s)
    if len(parts) == 2 and parts[0] == parts[1]:
        s = parts[0]

    # Prepend 'malware--'
    corrected = f"domain-name--{s}"

    # Ensure only one double dash after 'malware'
    corrected = re.sub(r'^domain-name-+', 'domain-name--', corrected)

    return corrected

# Step 1
for p in preds4eval:
    objects = []
    for obj in p["objects"]:
        # Step 1
        if "id" in obj.keys():
            ID = fix_domain_name_id(obj["id"].strip())

        if "value" in obj.keys():
            VALUE = obj["value"]
        else:
            VALUE = ID.split("domain-name--")[-1]

        objects.append(
            {
                "id":ID,
                "type":"domain-name",
                "value":VALUE,
            }
        )

    processed_preds4eval.append(
                {
                    "objects":objects
                }
            )

# %%
for i in range(len(outputs)):
    print(f"Actual: {outputs[i]}")
    print(f"Predicted: {processed_preds4eval[i]}")
    print("\n\n")
# Out:
# Actual: {'objects': [{'id': 'domain-name--teamsbusiness.org', 'type': 'domain-name', 'value': 'teamsbusiness.org'}, {'id': 'domain-name--voipfaqs.com', 'type': 'domain-name', 'value': 'voipfaqs.com'}, {'id': 'domain-name--locallyhyped.com', 'type': 'domain-name', 'value': 'locallyhyped.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--voipfaqsc.om', 'type': 'domain-name', 'value': 'voipfqsc.om'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--siamaster.com.mx', 'type': 'domain-name', 'value': 'siamaster.com.mx'}, {'id': 'domain-name--cv-builder.site', 'type': 'domain-name', 'value': 'cv-builder.site'}, {'id': 'domain-name--chatgptex.us', 'type': 'domain-name', 'value': 'chatgptex.us'}, {'id': 'domain-name--allfreesoftware.online', 'type': 'domain-name', 'value': 'allfreesoftware.online'}, {'id': 'domain-name--all-free-software.online', 'type': 'domain-name', 'value': 'all-free-software.online'}]}
# Predicted: {'objects': [{'id': 'domain-name--siamaster.com(mx)', 'type': 'domain-name', 'value': 'siamster.com.mx'}, {'id': 'domain-name--domai-name--chatgptext.us', 'type': 'domain-name', 'value': ''}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--vndjgheruewy1.com', 'type': 'domain-name', 'value': 'vndjgheruewy1.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--vndjhgeruewy.com', 'type': 'domain-name', 'value': 'vndjfheruewy2.com'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--telemetrysystemcollection.com', 'type': 'domain-name', 'value': 'telemetrysystemcollection.com'}, {'id': 'domain-name--extic.icu', 'type': 'domain-name', 'value': 'extic.icu'}, {'id': 'domain-name--reykh.icu', 'type': 'domain-name', 'value': 'reykh.icu'}, {'id': 'domain-name--collectiontelemetrysystem.com', 'type': 'domain-name', 'value': 'collectiontelemetrysystem.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--telemetryystemcollection.com', 'type': 'domain-name', 'value': 'telemetryystemcollection.com'}, {'id': 'domain-name--reykh.com', 'type': 'domain-name', 'value': 'reykh.com'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--freedynamicdns.org', 'type': 'domain-name', 'value': 'freedynamicdns.org'}, {'id': 'domain-name--belfaro.com.br', 'type': 'domain-name', 'value': 'belfaro.com.br'}]}
# Predicted: {'objects': [{'id': 'domain-name--freedynamicdns.org', 'type': 'domain-name', 'value': 'freedomaticdns.org'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--nasyiahgamping.com', 'type': 'domain-name', 'value': 'nasyiahgamping.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--nasyihagamping.com', 'type': 'domain-name', 'value': 'nasyihadgamping.org'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--web3protocol.online', 'type': 'domain-name', 'value': 'web3protocol.online'}, {'id': 'domain-name--mestoxcalculator.com', 'type': 'domain-name', 'value': 'mestoxcalculator.com'}, {'id': 'domain-name--cakeserver.online', 'type': 'domain-name', 'value': 'cakeserver.online'}]}
# Predicted: {'objects': [{'id': 'domain-name--web3.protocol', 'type': 'domain-name', 'value': 'web3(protocol.online'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--3x55o3u2b7cjs54eifja5m3ottxntlubhjzt6k6htp5nrocjmsxxh7ad.onion', 'type': 'domain-name', 'value': '3x55o3u2b7cjs54eifja5m3ottxntlubhjzt6k6htp5nrocjmsxxh7ad.onion'}]}
# Predicted: {'objects': [{'id': 'domain-name--3x5503u25b7cj54eijja5mo3ottxtntlubhjztk6htpt5nrocijsxxhhd.onion', 'type': 'domain-name', 'value': '3x5303u225b7ej54eiija5mo33ottxtnlubhjt6kt6htpj5nrcjijsxxhh7ad/onion'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': [{'id': 'domain-name--mssetting.com', 'type': 'domain-name', 'value': 'mssetting.com'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsqyfry4ebnxlcbkccyd.onion', 'type': 'domain-name', 'value': 'medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsqyfry4ebnxlcbkccyd.onion'}]}
# Predicted: {'objects': [{'id': 'domain-name--medusaxyo7jztrojdkoxo66jct4qgtgktfyrwfy4ebnkclbkccyd.xyz', 'type': 'domain-name', 'value': 'medusaxyo7jvtrojdkso66jcy4qitgktfrwyfy4bnklbcbyd.xyz'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--voiconprivatesv2083.com', 'type': 'domain-name', 'value': 'voiconprivatesv2083.com'}, {'id': 'domain-name--motdanvoi20232023.com', 'type': 'domain-name', 'value': 'motdanvoi20232023.com'}, {'id': 'domain-name--dauhetdau.com', 'type': 'domain-name', 'value': 'dauhetdau.com'}, {'id': 'domain-name--cavoisatthu2023asd.com', 'type': 'domain-name', 'value': 'cavoisatthu2023asd.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--voiconprivatesv1083.com', 'type': 'domain-name', 'value': 'voicon_privatesv21083.com'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': [{'id': 'domain-name--inclusive-economy.com', 'type': 'domain-name', 'value': 'inclusive-economyc.om'}, {'id': 'domain-name--theconomics.net', 'type': 'domain-name', 'value': 'theconomics.net'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--requestrepo.com', 'type': 'domain-name', 'value': 'requestrepo.com'}]}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--wirexpro.com', 'type': 'domain-name', 'value': 'wirexpro.com'}, {'id': 'domain-name--telloo.io', 'type': 'domain-name', 'value': 'telloo.io'}, {'id': 'domain-name--strainservice.com', 'type': 'domain-name', 'value': 'strainservice.com'}, {'id': 'domain-name--rebelthumb.net', 'type': 'domain-name', 'value': 'rebelthumb.net'}, {'id': 'domain-name--oilycargo.com', 'type': 'domain-name', 'value': 'oilycargo.com'}, {'id': 'domain-name--bloxholder.com', 'type': 'domain-name', 'value': 'bloxholder.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--wirexpro.co', 'type': 'domain-name', 'value': 'wirex.pro'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--tibetyouthcongress.com', 'type': 'domain-name', 'value': 'tibetyouthcongress.com'}, {'id': 'domain-name--telecomly.info', 'type': 'domain-name', 'value': 'telecomly.info'}, {'id': 'domain-name--t1bet.net', 'type': 'domain-name', 'value': 't1bet.net'}, {'id': 'domain-name--seller-notification.live', 'type': 'domain-name', 'value': 'seller-notification.live'}, {'id': 'domain-name--secure.software', 'type': 'domain-name', 'value': 'secure.software'}]}
# Predicted: {'objects': [{'id': 'domain-name--secure.software', 'type': 'domain-name', 'value': 'secure.software'}, {'id': 'domain-name--tibetyouthcongress.com', 'type': 'domain-name', 'value': 'tibetyouthcongress.com'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--appleplus.shop', 'type': 'domain-name', 'value': 'appleplus.shop'}, {'id': 'domain-name--appleplus.sbs', 'type': 'domain-name', 'value': 'appleplus.sbs'}]}
# Predicted: {'objects': [{'id': 'domain-name--appleplus.shop', 'type': 'domain-name', 'value': 'appleplus/shop'}, {'id': 'domain-name--appleplus.sps', 'type': 'domain-name', 'value': 'appleplus.sps'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--powersupportplan.com', 'type': 'domain-name', 'value': 'powersupportplan.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--powersupport-plan.com', 'type': 'domain-name', 'value': 'powersupport.plan'}, {'id': 'domain-name--', 'type': 'domain-name', 'value': ''}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--webgoalarm.online', 'type': 'domain-name', 'value': 'webgoalarm.online'}, {'id': 'domain-name--nonbrowm.com', 'type': 'domain-name', 'value': 'nonbrowm.com'}, {'id': 'domain-name--mnksystem.online', 'type': 'domain-name', 'value': 'mnksystem.online'}, {'id': 'domain-name--backmnk.online', 'type': 'domain-name', 'value': 'backmnk.online'}]}
# Predicted: {'objects': [{'id': 'domain-name--nonbrowmm.com', 'type': 'domain-name', 'value': 'nonbrawmm.com'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--blender-s.org', 'type': 'domain-name', 'value': 'blender-s.org'}, {'id': 'domain-name--blendersa.org', 'type': 'domain-name', 'value': 'blendersa.org'}]}
# Predicted: {'objects': [{'id': 'domain-name--blender-s_org', 'type': 'domain-name', 'value': 'blender.s.org'}, {'id': 'domain-name--blendersa_org', 'type': 'domain-name', 'value': 'blendersa_org'}, {'id': 'domain-name--blender3d-org-fras6899-odns-fr', 'type': 'domain-name', 'value': 'blender-odnssfras68993dfr.org'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--umopl-drive.com', 'type': 'domain-name', 'value': 'umopl-drive.com'}, {'id': 'domain-name--transfer-record.com', 'type': 'domain-name', 'value': 'transfer-record.com'}, {'id': 'domain-name--sangrail-share.com', 'type': 'domain-name', 'value': 'sangrail-share.com'}, {'id': 'domain-name--share-drive-ua.com', 'type': 'domain-name', 'value': 'share-drive-ua.com'}, {'id': 'domain-name--response-redir.com', 'type': 'domain-name', 'value': 'response-redir.com'}, {'id': 'domain-name--response-filter.com', 'type': 'domain-name', 'value': 'response-filter.com'}, {'id': 'domain-name--redir-document.com', 'type': 'domain-name', 'value': 'redir-document.com'}, {'id': 'domain-name--proxycrioisolation.com', 'type': 'domain-name', 'value': 'proxycrioisolation.com'}, {'id': 'domain-name--nonviolent-conflict-service.com', 'type': 'domain-name', 'value': 'nonviolent-conflict-service.com'}, {'id': 'domain-name--network-storage-ltd.com', 'type': 'domain-name', 'value': 'network-storage-ltd.com'}, {'id': 'domain-name--mvd-redir.ru', 'type': 'domain-name', 'value': 'mvd-redir.ru'}, {'id': 'domain-name--land-of-service.com', 'type': 'domain-name', 'value': 'land-of-service.com'}, {'id': 'domain-name--live-identifier.com', 'type': 'domain-name', 'value': 'live-identifier.com'}, {'id': 'domain-name--guard-checker.com', 'type': 'domain-name', 'value': 'guard-checker.com'}, {'id': 'domain-name--goweb-protect.com', 'type': 'domain-name', 'value': 'goweb-protect.com'}, {'id': 'domain-name--filter-bot.com', 'type': 'domain-name', 'value': 'filter-bot.com'}, {'id': 'domain-name--dtgruelle-us.com', 'type': 'domain-name', 'value': 'dtgruelle-us.com'}, {'id': 'domain-name--encompass-shared.com', 'type': 'domain-name', 'value': 'encompass-shared.com'}, {'id': 'domain-name--drive-previewer.com', 'type': 'domain-name', 'value': 'drive-previewer.com'}, {'id': 'domain-name--drive-us.online', 'type': 'domain-name', 'value': 'drive-us.online'}, {'id': 'domain-name--dtgruelle-drive.com', 'type': 'domain-name', 'value': 'dtgruelle-drive.com'}, {'id': 'domain-name--drive-globalordnance.com', 'type': 'domain-name', 'value': 'drive-globalordnance.com'}, {'id': 'domain-name--drive-control.com', 'type': 'domain-name', 'value': 'drive-control.com'}, {'id': 'domain-name--docs-web.online', 'type': 'domain-name', 'value': 'docs-web.online'}, {'id': 'domain-name--dns-cookie.com', 'type': 'domain-name', 'value': 'dns-cookie.com'}, {'id': 'domain-name--dns-mvd.ru', 'type': 'domain-name', 'value': 'dns-mvd.ru'}, {'id': 'domain-name--dns-cache.online', 'type': 'domain-name', 'value': 'dns-cache.online'}, {'id': 'domain-name--cloud-safety.online', 'type': 'domain-name', 'value': 'cloud-safety.online'}, {'id': 'domain-name--cloud-us.online', 'type': 'domain-name', 'value': 'cloud-us.online'}, {'id': 'domain-name--checker-bot.com', 'type': 'domain-name', 'value': 'checker-bot.com'}, {'id': 'domain-name--cija-docs.com', 'type': 'domain-name', 'value': 'cija-docs.com'}, {'id': 'domain-name--challenge-identifier.com', 'type': 'domain-name', 'value': 'challenge-identifier.com'}, {'id': 'domain-name--botguard-web.com', 'type': 'domain-name', 'value': 'botguard-web.com'}, {'id': 'domain-name--botguard-checker.com', 'type': 'domain-name', 'value': 'botguard-checker.com'}, {'id': 'domain-name--blueskynetwork-shared.com', 'type': 'domain-name', 'value': 'blueskynetwork-shared.com'}, {'id': 'domain-name--access-confirmation.com', 'type': 'domain-name', 'value': 'access-confirmation.com'}, {'id': 'domain-name--allow-access.com', 'type': 'domain-name', 'value': 'allow-access.com'}, {'id': 'domain-name--antibots-service.com', 'type': 'domain-name', 'value': 'antibots-service.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--umopl_drive.com', 'type': 'domain-name', 'value': 'umopl-driver.com'}, {'id': 'domain-name--', 'type': 'domain-name', 'value': ''}, {'id': 'domain-name--domain_name--transfer_record.com', 'type': 'domain-name', 'value': ''}, {'id': 'domain-name--object-reference--domain-name-transfer_record.com', 'type': 'domain-name', 'value': 'transfer-record.com'}, {'id': 'domain-name--', 'type': 'domain-name', 'value': ''}, {'id': 'domain-name--response-redird.com', 'type': 'domain-name', 'value': 'response-redirr.com'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--refundkorea.cyou', 'type': 'domain-name', 'value': 'refundkorea.cyou'}, {'id': 'domain-name--bobocam365.icu', 'type': 'domain-name', 'value': 'bobocam365.icu'}]}
# Predicted: {'objects': [{'id': 'domain-name--refundkoreanews.com', 'type': 'domain-name', 'value': 'refundkoreane.news'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--wuriye.com', 'type': 'domain-name', 'value': 'wuriye.com'}, {'id': 'domain-name--wilandsabim.info', 'type': 'domain-name', 'value': 'wilandsabim.info'}, {'id': 'domain-name--unicredibank.top', 'type': 'domain-name', 'value': 'unicredibank.top'}, {'id': 'domain-name--unicrebitdank.top', 'type': 'domain-name', 'value': 'unicrebitdank.top'}, {'id': 'domain-name--ttlpcs.lat', 'type': 'domain-name', 'value': 'ttlpcs.lat'}, {'id': 'domain-name--sharepoint2024.one', 'type': 'domain-name', 'value': 'sharepoint2024.one'}, {'id': 'domain-name--sapconcur.top', 'type': 'domain-name', 'value': 'sapconcur.top'}, {'id': 'domain-name--sapconcur.one', 'type': 'domain-name', 'value': 'sapconcur.one'}, {'id': 'domain-name--sapconcur.team', 'type': 'domain-name', 'value': 'sapconcur.team'}, {'id': 'domain-name--otpdank24.top', 'type': 'domain-name', 'value': 'otpdank24.top'}, {'id': 'domain-name--ms-antispam.live', 'type': 'domain-name', 'value': 'ms-antispam.live'}, {'id': 'domain-name--meet-goo.org', 'type': 'domain-name', 'value': 'meet-goo.org'}, {'id': 'domain-name--miles-and-mroe.com', 'type': 'domain-name', 'value': 'miles-and-mroe.com'}, {'id': 'domain-name--meet2024.com', 'type': 'domain-name', 'value': 'meet2024.com'}, {'id': 'domain-name--meet-goo.net', 'type': 'domain-name', 'value': 'meet-goo.net'}, {'id': 'domain-name--meet-gl.com', 'type': 'domain-name', 'value': 'meet-gl.com'}, {'id': 'domain-name--lexisnexis.top', 'type': 'domain-name', 'value': 'lexisnexis.top'}, {'id': 'domain-name--lexisnexis.lat', 'type': 'domain-name', 'value': 'lexisnexis.lat'}, {'id': 'domain-name--lexisnexis.pro', 'type': 'domain-name', 'value': 'lexisnexis.pro'}, {'id': 'domain-name--lexisnexis.one', 'type': 'domain-name', 'value': 'lexisnexis.one'}, {'id': 'domain-name--lexisnex.pro', 'type': 'domain-name', 'value': 'lexisnex.pro'}, {'id': 'domain-name--lexisnex.top', 'type': 'domain-name', 'value': 'lexisnex.top'}, {'id': 'domain-name--lexisnex.team', 'type': 'domain-name', 'value': 'lexisnex.team'}, {'id': 'domain-name--lexis2024.pro', 'type': 'domain-name', 'value': 'lexis2024.pro'}, {'id': 'domain-name--law360.one', 'type': 'domain-name', 'value': 'law360.one'}, {'id': 'domain-name--lexis2024.info', 'type': 'domain-name', 'value': 'lexis2024.info'}, {'id': 'domain-name--law2024.top', 'type': 'domain-name', 'value': 'law2024.top'}, {'id': 'domain-name--law2024.info', 'type': 'domain-name', 'value': 'law2024.info'}, {'id': 'domain-name--gogogononono.xyz', 'type': 'domain-name', 'value': 'gogogononono.xyz'}, {'id': 'domain-name--gogogononono.top', 'type': 'domain-name', 'value': 'gogogononono.top'}, {'id': 'domain-name--gogogogogotests.xyz', 'type': 'domain-name', 'value': 'gogogogogotests.xyz'}, {'id': 'domain-name--gl-meet2024.com', 'type': 'domain-name', 'value': 'gl-meet2024.com'}, {'id': 'domain-name--edankhk.top', 'type': 'domain-name', 'value': 'edankhk.top'}, {'id': 'domain-name--dr1v3.top', 'type': 'domain-name', 'value': 'dr1v3.top'}, {'id': 'domain-name--dr1v3.one', 'type': 'domain-name', 'value': 'dr1v3.one'}, {'id': 'domain-name--dhlpost.sbs', 'type': 'domain-name', 'value': 'dhlpost.sbs'}, {'id': 'domain-name--dhlpost.nl', 'type': 'domain-name', 'value': 'dhlpost.nl'}, {'id': 'domain-name--dhlpost.lat', 'type': 'domain-name', 'value': 'dhlpost.lat'}, {'id': 'domain-name--clio2024.top', 'type': 'domain-name', 'value': 'clio2024.top'}, {'id': 'domain-name--clio2024.one', 'type': 'domain-name', 'value': 'clio2024.one'}, {'id': 'domain-name--clio2024.info', 'type': 'domain-name', 'value': 'clio2024.info'}, {'id': 'domain-name--clio.pw', 'type': 'domain-name', 'value': 'clio.pw'}, {'id': 'domain-name--clio.lat', 'type': 'domain-name', 'value': 'clio.lat'}, {'id': 'domain-name--blackrock-alladin.pro', 'type': 'domain-name', 'value': 'blackrock-alladin.pro'}, {'id': 'domain-name--ariba.lat', 'type': 'domain-name', 'value': 'ariba.lat'}, {'id': 'domain-name--antispam-ms.pro', 'type': 'domain-name', 'value ...
# Predicted: {'objects': [{'id': 'domain-name--westlaw.top', 'type': 'domain-name', 'value': 'westlawtop'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--jilinebyli.top', 'type': 'domain-name', 'value': 'jilinebyli.top'}]}
# Predicted: {'objects': [{'id': 'domain-name--jilinebi.top', 'type': 'domain-name', 'value': 'jilinebio.top'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--vilnius-summit.lt', 'type': 'domain-name', 'value': 'vilnius-summit.lt'}, {'id': 'domain-name--viilnius.lt', 'type': 'domain-name', 'value': 'viilnius.lt'}, {'id': 'domain-name--urm-lt.com', 'type': 'domain-name', 'value': 'urm-lt.com'}, {'id': 'domain-name--te-storg.com', 'type': 'domain-name', 'value': 'te-storg.com'}, {'id': 'domain-name--sso-log.com', 'type': 'domain-name', 'value': 'sso-log.com'}, {'id': 'domain-name--socialistii.com', 'type': 'domain-name', 'value': 'socialistii.com'}, {'id': 'domain-name--socialisti.md', 'type': 'domain-name', 'value': 'socialisti.md'}, {'id': 'domain-name--social-moldova.md', 'type': 'domain-name', 'value': 'social-moldova.md'}, {'id': 'domain-name--sapsap.site', 'type': 'domain-name', 'value': 'sapsap.site'}, {'id': 'domain-name--pass-check.online', 'type': 'domain-name', 'value': 'pass-check.online'}, {'id': 'domain-name--otllook.com', 'type': 'domain-name', 'value': 'otllook.com'}, {'id': 'domain-name--noname05716.ru', 'type': 'domain-name', 'value': 'noname05716.ru'}, {'id': 'domain-name--nnmnnm.ru', 'type': 'domain-name', 'value': 'nnmnnm.ru'}, {'id': 'domain-name--nask-pl.com', 'type': 'domain-name', 'value': 'nask-pl.com'}, {'id': 'domain-name--moldova-social.md', 'type': 'domain-name', 'value': 'moldova-social.md'}, {'id': 'domain-name--moldova-mediu.md', 'type': 'domain-name', 'value': 'moldova-mediu.md'}, {'id': 'domain-name--moldova-energie.md', 'type': 'domain-name', 'value': 'moldova-energie.md'}, {'id': 'domain-name--mec-gov.md', 'type': 'domain-name', 'value': 'mec-gov.md'}, {'id': 'domain-name--md-mec.com', 'type': 'domain-name', 'value': 'md-mec.com'}, {'id': 'domain-name--mcgov.md', 'type': 'domain-name', 'value': 'mcgov.md'}, {'id': 'domain-name--mc-md.com', 'type': 'domain-name', 'value': 'mc-md.com'}, {'id': 'domain-name--mailos.ru', 'type': 'domain-name', 'value': 'mailos.ru'}, {'id': 'domain-name--mailorun.su', 'type': 'domain-name', 'value': 'mailorun.su'}, {'id': 'domain-name--mailgon.online', 'type': 'domain-name', 'value': 'mailgon.online'}, {'id': 'domain-name--litexpo-portal.lt', 'type': 'domain-name', 'value': 'litexpo-portal.lt'}, {'id': 'domain-name--ivention.pl', 'type': 'domain-name', 'value': 'ivention.pl'}, {'id': 'domain-name--isw-org.pl', 'type': 'domain-name', 'value': 'isw-org.pl'}, {'id': 'domain-name--gov-md.com', 'type': 'domain-name', 'value': 'gov-md.com'}, {'id': 'domain-name--interior-gov.es', 'type': 'domain-name', 'value': 'interior-gov.es'}, {'id': 'domain-name--golebewski.pl', 'type': 'domain-name', 'value': 'golebewski.pl'}, {'id': 'domain-name--freepresunlimited.org', 'type': 'domain-name', 'value': 'freepresunlimited.org'}, {'id': 'domain-name--europa.study', 'type': 'domain-name', 'value': 'europa.study'}, {'id': 'domain-name--europa.social', 'type': 'domain-name', 'value': 'europa.social'}, {'id': 'domain-name--europa-eppo.eu', 'type': 'domain-name', 'value': 'europa-eppo.eu'}, {'id': 'domain-name--europa-ec.eu', 'type': 'domain-name', 'value': 'europa-ec.eu'}, {'id': 'domain-name--eupm-moldova.md', 'type': 'domain-name', 'value': 'eupm-moldova.md'}, {'id': 'domain-name--energie-gov.md', 'type': 'domain-name', 'value': 'energie-gov.md'}, {'id': 'domain-name--comunidad-madrid.es', 'type': 'domain-name', 'value': 'comunidad-madrid.es'}, {'id': 'domain-name--comunicacion-presidencia-gov.es', 'type': 'domain-name', 'value': 'comunicacion-presidencia-gov.es'}, {'id': 'domain-name--cert-pl.pl', 'type': 'domain-name', 'value': 'cert-pl.pl'}]}
# Predicted: {'objects': [{'id': 'domain-name--vilniussummitlt', 'type': 'domain-name', 'value': 'vilniussensummitlt'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--sanchaar.net', 'type': 'domain-name', 'value': 'sanchaar.net'}, {'id': 'domain-name--newsinlevel.cc', 'type': 'domain-name', 'value': 'newsinlevel.cc'}, {'id': 'domain-name--asistechs.com', 'type': 'domain-name', 'value': 'asistechs.com'}, {'id': 'domain-name--wooofi.com', 'type': 'domain-name', 'value': 'wooofi.com'}, {'id': 'domain-name--slackforbusiness.net', 'type': 'domain-name', 'value': 'slackforbusiness.net'}, {'id': 'domain-name--nextnovatech.com', 'type': 'domain-name', 'value': 'nextnovatech.com'}, {'id': 'domain-name--macpaw.us', 'type': 'domain-name', 'value': 'macpaw.us'}]}
# Predicted: {'objects': [{'id': 'domain-name--sanchaal.net', 'type': 'domain-name', 'value': 'sanchaac.net'}, {'id': 'domain-name--asistech.com', 'type': 'domain-name', 'value': 'asistech.com'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--tmpfiles.org', 'type': 'domain-name', 'value': 'tmpfiles.org'}]}
# Predicted: {'objects': [{'id': 'domain-name--tmpfiles_org', 'type': 'domain-name', 'value': 'tmpfiles.or'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--cppcccare.com', 'type': 'domain-name', 'value': 'cppcccare.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--cppccare.com', 'type': 'domain-name', 'value': 'cppccares.com'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--7oukjxwkbnwyg7cekudzp66okrchbuubde2j3h6fkpis6izywoj2eqad.onion', 'type': 'domain-name', 'value': '7oukjxwkbnwyg7cekudzp66okrchbuubde2j3h6fkpis6izywoj2eqad.onion'}]}
# Predicted: {'objects': [{'id': 'domain-name--7oukjxwkbnwyg7cekudzp66okrchbuubde2j3h6fkpis6izywoj2eqad.onion', 'type': 'domain-name', 'value': '7oujkxwkbmwyg73ekudzpg66okrchbuubde2h6fknpis61zwoj2eaqad.onio'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--51-83-136-132.xyz', 'type': 'domain-name', 'value': '51-83-136-132.xyz'}, {'id': 'domain-name--s1-filecr.xyz', 'type': 'domain-name', 'value': 's1-filecr.xyz'}]}
# Predicted: {'objects': [{'id': 'domain-name--s1-filekr.xyz', 'type': 'domain-name', 'value': 's1-filerkr.xyz'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--ssq4zimieeanazkzc5ld4v5hdibi2nzwzdibfh5n5w4pw5mcik76lzyd.onion', 'type': 'domain-name', 'value': 'ssq4zimieeanazkzc5ld4v5hdibi2nzwzdibfh5n5w4pw5mcik76lzyd.onion'}, {'id': 'domain-name--gunyhng6pabzcurl7ipx2pbmjxpvqnu6mxf2h3vdeenam34inj4ndryd.onion', 'type': 'domain-name', 'value': 'gunyhng6pabzcurl7ipx2pbmjxpvqnu6mxf2h3vdeenam34inj4ndryd.onion'}]}
# Predicted: {'objects': [{'id': 'domain-name--ssq4zimmerieeanazzkc5ldiv5hdib2nzzwdibfhsm5w5mw5mcikk76lzd.onion', 'type': 'domain-name', 'value': 'ssqzimmerieeamazkcz5ld5v5hidib2nzwwzdibfm5nsw4pwsmcik76lzvd.onion'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--theshirtsummit.com', 'type': 'domain-name', 'value': 'theshirtsummit.com'}, {'id': 'domain-name--propertynear.co.uk', 'type': 'domain-name', 'value': 'propertynear.co.uk'}, {'id': 'domain-name--rosewoodlaminates.com', 'type': 'domain-name', 'value': 'rosewoodlaminates.com'}, {'id': 'domain-name--kmphi.com', 'type': 'domain-name', 'value': 'kmphi.com'}, {'id': 'domain-name--graficalevi.com.br', 'type': 'domain-name', 'value': 'graficalevi.com.br'}, {'id': 'domain-name--cica.com.co', 'type': 'domain-name', 'value': 'cica.com.co'}, {'id': 'domain-name--chimpcity.com', 'type': 'domain-name', 'value': 'chimpcity.com'}, {'id': 'domain-name--centerkick.com', 'type': 'domain-name', 'value': 'centerkick.com'}, {'id': 'domain-name--capitalperurrhh.com', 'type': 'domain-name', 'value': 'capitalperurrhh.com'}, {'id': 'domain-name--abhishekmeena.in', 'type': 'domain-name', 'value': 'abhishekmeena.in'}, {'id': 'domain-name--agtendelperu.com', 'type': 'domain-name', 'value': 'agtendelperu.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--theshirtsummit.com', 'type': 'domain-name', 'value': 'theshirthsummit.co.uk'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--userfeedsync.com', 'type': 'domain-name', 'value': 'userfeedsync.com'}, {'id': 'domain-name--commonline.space', 'type': 'domain-name', 'value': 'commonline.space'}]}
# Predicted: {'objects': [{'id': 'domain-name--commonline.space', 'type': 'domain-name', 'value': 'commonline(space'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--rendinfo.shop', 'type': 'domain-name', 'value': 'rendinfo.shop'}]}
# Predicted: {'objects': [{'id': 'domain-name--rendinfo.shop', 'type': 'domain-name', 'value': 'rendinfo/shop'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--advanced-ip-scanners.net', 'type': 'domain-name', 'value': 'advanced-ip-scanners.net'}]}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--utilityservices.us', 'type': 'domain-name', 'value': 'utilityservices.us'}, {'id': 'domain-name--utilitybillspayments.org', 'type': 'domain-name', 'value': 'utilitybillspayments.org'}, {'id': 'domain-name--utilitydiscounts.store', 'type': 'domain-name', 'value': 'utilitydiscounts.store'}, {'id': 'domain-name--utilitybillsolution.site', 'type': 'domain-name', 'value': 'utilitybillsolution.site'}, {'id': 'domain-name--thepowerpayllc.org', 'type': 'domain-name', 'value': 'thepowerpayllc.org'}, {'id': 'domain-name--uenergyproviders.store', 'type': 'domain-name', 'value': 'uenergyproviders.store'}, {'id': 'domain-name--telecomcredits.us', 'type': 'domain-name', 'value': 'telecomcredits.us'}, {'id': 'domain-name--telecombilling.us', 'type': 'domain-name', 'value': 'telecombilling.us'}, {'id': 'domain-name--rebornsolutions.co', 'type': 'domain-name', 'value': 'rebornsolutions.co'}, {'id': 'domain-name--qasmic.com', 'type': 'domain-name', 'value': 'qasmic.com'}, {'id': 'domain-name--powerelectricoffers.com', 'type': 'domain-name', 'value': 'powerelectricoffers.com'}, {'id': 'domain-name--paysenergy.online', 'type': 'domain-name', 'value': 'paysenergy.online'}, {'id': 'domain-name--makeabillpayment.com', 'type': 'domain-name', 'value': 'makeabillpayment.com'}, {'id': 'domain-name--homeutilityservices.com', 'type': 'domain-name', 'value': 'homeutilityservices.com'}, {'id': 'domain-name--globalenergysolutionz.com', 'type': 'domain-name', 'value': 'globalenergysolutionz.com'}, {'id': 'domain-name--energypoweroffer.com', 'type': 'domain-name', 'value': 'energypoweroffer.com'}, {'id': 'domain-name--energypayment.shop', 'type': 'domain-name', 'value': 'energypayment.shop'}, {'id': 'domain-name--energyhelpcenter.com', 'type': 'domain-name', 'value': 'energyhelpcenter.com'}, {'id': 'domain-name--energycredits.online', 'type': 'domain-name', 'value': 'energycredits.online'}, {'id': 'domain-name--energybilling.net', 'type': 'domain-name', 'value': 'energybilling.net'}, {'id': 'domain-name--energybillservice.online', 'type': 'domain-name', 'value': 'energybillservice.online'}, {'id': 'domain-name--energpaybill.com', 'type': 'domain-name', 'value': 'energpaybill.com'}, {'id': 'domain-name--electricenergybundle.com', 'type': 'domain-name', 'value': 'electricenergybundle.com'}, {'id': 'domain-name--electricpowerdeal.com', 'type': 'domain-name', 'value': 'electricpowerdeal.com'}, {'id': 'domain-name--electricenergyservice.com', 'type': 'domain-name', 'value': 'electricenergyservice.com'}, {'id': 'domain-name--economical-deals.co', 'type': 'domain-name', 'value': 'economical-deals.co'}, {'id': 'domain-name--eco-designs.store', 'type': 'domain-name', 'value': 'eco-designs.store'}, {'id': 'domain-name--digitelcare.com', 'type': 'domain-name', 'value': 'digitelcare.com'}, {'id': 'domain-name--citrexsolutions.co', 'type': 'domain-name', 'value': 'citrexsolutions.co'}, {'id': 'domain-name--aadigital.online', 'type': 'domain-name', 'value': 'aadigital.online'}, {'id': 'domain-name--360billingservices.com', 'type': 'domain-name', 'value': '360billingservices.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--utilityservices.us', 'type': 'domain-name', 'value': 'utilityservices(us)'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--thesecurevpn.com', 'type': 'domain-name', 'value': 'thesecurevpn.com'}, {'id': 'domain-name--ft8hua063okwfdcu21pw.de', 'type': 'domain-name', 'value': 'ft8hua063okwfdcu21pw.de'}]}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--wilsoncentre.org', 'type': 'domain-name', 'value': 'wilsoncentre.org'}, {'id': 'domain-name--wilsoncenters.org', 'type': 'domain-name', 'value': 'wilsoncenters.org'}, {'id': 'domain-name--stimson.shop', 'type': 'domain-name', 'value': 'stimson.shop'}, {'id': 'domain-name--stimsonn.org', 'type': 'domain-name', 'value': 'stimsonn.org'}, {'id': 'domain-name--nknevvs.org', 'type': 'domain-name', 'value': 'nknevvs.org'}]}
# Predicted: {'objects': [{'id': 'domain-name--wilsoncentre.net', 'type': 'domain-name', 'value': 'wilsoncentrenet'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--seleriti.com', 'type': 'domain-name', 'value': 'seleriti.com'}, {'id': 'domain-name--seemlabie.top', 'type': 'domain-name', 'value': 'seemlabie.top'}, {'id': 'domain-name--rapadtrai.com', 'type': 'domain-name', 'value': 'rapadtrai.com'}, {'id': 'domain-name--oscarnaija.com', 'type': 'domain-name', 'value': 'oscarnaija.com'}, {'id': 'domain-name--makananwisata.com', 'type': 'domain-name', 'value': 'makananwisata.com'}, {'id': 'domain-name--mahinetain.top', 'type': 'domain-name', 'value': 'mahinetain.top'}, {'id': 'domain-name--graeslavur.com', 'type': 'domain-name', 'value': 'graeslavur.com'}, {'id': 'domain-name--craceruib.top', 'type': 'domain-name', 'value': 'craceruib.top'}, {'id': 'domain-name--caseiden.com', 'type': 'domain-name', 'value': 'caseiden.com'}, {'id': 'domain-name--baglamanotalari.com', 'type': 'domain-name', 'value': 'baglamanotalari.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--seleriti.org', 'type': 'domain-name', 'value': 'selerити.org'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--rdp-devolutions.com', 'type': 'domain-name', 'value': 'rdp-devolutions.com'}, {'id': 'domain-name--startleague.net', 'type': 'domain-name', 'value': 'startleague.net'}]}
# Predicted: {'objects': [{'id': 'domain-name--rdp-devolutions.net', 'type': 'domain-name', 'value': 'rdp.devolution.net'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--shopalbum.xyz', 'type': 'domain-name', 'value': 'shopalbum.xyz'}, {'id': 'domain-name--rebrandtop.top', 'type': 'domain-name', 'value': 'rebrandtop.top'}, {'id': 'domain-name--neuka.top', 'type': 'domain-name', 'value': 'neuka.top'}, {'id': 'domain-name--microtobig.xyz', 'type': 'domain-name', 'value': 'microtobig.xyz'}, {'id': 'domain-name--findalbum.top', 'type': 'domain-name', 'value': 'findalbum.top'}, {'id': 'domain-name--ubutun.xyz', 'type': 'domain-name', 'value': 'ubutun.xyz'}]}
# Predicted: {'objects': [{'id': 'domain-name--shopalbum.xyz', 'type': 'domain-name', 'value': 'shopalbum xyz'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--xtechsupport.org', 'type': 'domain-name', 'value': 'xtechsupport.org'}, {'id': 'domain-name--solhaber.news', 'type': 'domain-name', 'value': 'solhaber.news'}, {'id': 'domain-name--solhaber.info', 'type': 'domain-name', 'value': 'solhaber.info'}, {'id': 'domain-name--serverssl.net', 'type': 'domain-name', 'value': 'serverssl.net'}, {'id': 'domain-name--querryfiles.com', 'type': 'domain-name', 'value': 'querryfiles.com'}, {'id': 'domain-name--nuceciwan.news', 'type': 'domain-name', 'value': 'nuceciwan.news'}, {'id': 'domain-name--netssh.net', 'type': 'domain-name', 'value': 'netssh.net'}, {'id': 'domain-name--net3.me', 'type': 'domain-name', 'value': 'net3.me'}, {'id': 'domain-name--loading-website.net', 'type': 'domain-name', 'value': 'loading-website.net'}, {'id': 'domain-name--infohaber.net', 'type': 'domain-name', 'value': 'infohaber.net'}, {'id': 'domain-name--exp-al-marsad.co', 'type': 'domain-name', 'value': 'exp-al-marsad.co'}, {'id': 'domain-name--caglayandergisi.net', 'type': 'domain-name', 'value': 'caglayandergisi.net'}]}
# Predicted: {'objects': [{'id': 'domain-name--xtech-support.org', 'type': 'domain-name', 'value': 'xtech_support.org'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--zryl.online', 'type': 'domain-name', 'value': 'zryl.online'}, {'id': 'domain-name--xxxatat456.com', 'type': 'domain-name', 'value': 'xxxatat456.com'}, {'id': 'domain-name--nishabud.com', 'type': 'domain-name', 'value': 'nishabud.com'}, {'id': 'domain-name--xran.xyz', 'type': 'domain-name', 'value': 'xran.xyz'}, {'id': 'domain-name--lpjulidny7.com', 'type': 'domain-name', 'value': 'lpjulidny7.com'}, {'id': 'domain-name--aldz.xyz', 'type': 'domain-name', 'value': 'aldz.xyz'}, {'id': 'domain-name--dddgata789.com', 'type': 'domain-name', 'value': 'dddgata789.com'}, {'id': 'domain-name--gggatat456.com', 'type': 'domain-name', 'value': 'gggatat456.com'}, {'id': 'domain-name--604418589.xyz', 'type': 'domain-name', 'value': '604418589.xyz'}, {'id': 'domain-name--0o557.com', 'type': 'domain-name', 'value': '0o557.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--zryl ऑनलाइन', 'type': 'domain-name', 'value': 'zryll.online'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--soccerstreamingvpn.com', 'type': 'domain-name', 'value': 'soccerstreamingvpn.com'}, {'id': 'domain-name--shinevpn.org', 'type': 'domain-name', 'value': 'shinevpn.org'}, {'id': 'domain-name--shinevpn.com', 'type': 'domain-name', 'value': 'shinevpn.com'}, {'id': 'domain-name--shinevpn.net', 'type': 'domain-name', 'value': 'shinevpn.net'}, {'id': 'domain-name--shinevpn.co', 'type': 'domain-name', 'value': 'shinevpn.co'}, {'id': 'domain-name--searchsafe.com', 'type': 'domain-name', 'value': 'searchsafe.com'}, {'id': 'domain-name--shieldvpn.org', 'type': 'domain-name', 'value': 'shieldvpn.org'}, {'id': 'domain-name--reachfresh.com', 'type': 'domain-name', 'value': 'reachfresh.com'}, {'id': 'domain-name--proxygate.net', 'type': 'domain-name', 'value': 'proxygate.net'}, {'id': 'domain-name--freevpnlebanon.com', 'type': 'domain-name', 'value': 'freevpnlebanon.com'}, {'id': 'domain-name--freevpnhongkong.com', 'type': 'domain-name', 'value': 'freevpnhongkong.com'}, {'id': 'domain-name--freevpnghana.com', 'type': 'domain-name', 'value': 'freevpnghana.com'}, {'id': 'domain-name--freevpncuba.com', 'type': 'domain-name', 'value': 'freevpncuba.com'}, {'id': 'domain-name--dewvpn.org', 'type': 'domain-name', 'value': 'dewvpn.org'}, {'id': 'domain-name--dewvpn.net', 'type': 'domain-name', 'value': 'dewvpn.net'}, {'id': 'domain-name--dewvpn.cc', 'type': 'domain-name', 'value': 'dewvpn.cc'}, {'id': 'domain-name--cloudrouter.pro', 'type': 'domain-name', 'value': 'cloudrouter.pro'}, {'id': 'domain-name--911s5.org', 'type': 'domain-name', 'value': '911s5.org'}, {'id': 'domain-name--cloudrouter.io', 'type': 'domain-name', 'value': 'cloudrouter.io'}, {'id': 'domain-name--911s5.net', 'type': 'domain-name', 'value': '911s5.net'}, {'id': 'domain-name--911s5.com', 'type': 'domain-name', 'value': '911s5.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--soccersteamngvnp.com', 'type': 'domain-name', 'value': 'soccersteamingvnpn.com'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--trackmyshipeng.site', 'type': 'domain-name', 'value': 'trackmyshipeng.site'}, {'id': 'domain-name--shippingmentnotice.xyz', 'type': 'domain-name', 'value': 'shippingmentnotice.xyz'}, {'id': 'domain-name--robshippings.cloud', 'type': 'domain-name', 'value': 'robshippings.cloud'}, {'id': 'domain-name--ledgeronbill.com', 'type': 'domain-name', 'value': 'ledgeronbill.com'}, {'id': 'domain-name--gieannualconferenceinmunich.com', 'type': 'domain-name', 'value': 'gieannualconferenceinmunich.com'}, {'id': 'domain-name--fxbulls.ru', 'type': 'domain-name', 'value': 'fxbulls.ru'}]}
# Predicted: {'objects': [{'id': 'domain-name--shippingmentnotice xyz', 'type': 'domain-name', 'value': 'shippingmentnoticexyz'}, {'id': 'domain-name--', 'type': 'domain-name', 'value': ''}, {'id': 'domain-name--robshippnings.cloud', 'type': 'domain-name', 'value': 'robshippingss.cloud'}, {'id': 'domain-name--robshippnings.cloud', 'type': 'domain-name', 'value': 'robshippnings.cloud'}, {'id': 'domain-name--robshippnings.cloud', 'type': 'domain-name', 'value': 'robshippnings.cloud'}, {'id': 'domain-name--robshippnings.cloud', 'type': 'domain-name', 'value': 'robshippnings.cloud'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--droogggdhfhf.com', 'type': 'domain-name', 'value': 'droogggdhfhf.com'}, {'id': 'domain-name--rprotecruuio.com', 'type': 'domain-name', 'value': 'rprotecruuio.com'}, {'id': 'domain-name--ronoliffuion.com', 'type': 'domain-name', 'value': 'ronoliffuion.com'}, {'id': 'domain-name--romidonionhhgtt.com', 'type': 'domain-name', 'value': 'romidonionhhgtt.com'}, {'id': 'domain-name--nomoresense.com', 'type': 'domain-name', 'value': 'nomoresense.com'}, {'id': 'domain-name--nitutdra.com', 'type': 'domain-name', 'value': 'nitutdra.com'}, {'id': 'domain-name--ms-online-store.com', 'type': 'domain-name', 'value': 'ms-online-store.com'}, {'id': 'domain-name--midnigthwaall.com', 'type': 'domain-name', 'value': 'midnigthwaall.com'}, {'id': 'domain-name--fuanshizmo.com', 'type': 'domain-name', 'value': 'fuanshizmo.com'}, {'id': 'domain-name--dremmfyttrred.com', 'type': 'domain-name', 'value': 'dremmfyttrred.com'}, {'id': 'domain-name--dragonetzone.com', 'type': 'domain-name', 'value': 'dragonetzone.com'}, {'id': 'domain-name--bluespiredice.com', 'type': 'domain-name', 'value': 'bluespiredice.com'}, {'id': 'domain-name--hrcbishtek.com', 'type': 'domain-name', 'value': 'hrcbishtek.com'}, {'id': 'domain-name--essadonio.com', 'type': 'domain-name', 'value': 'essadonio.com'}, {'id': 'domain-name--ecorfan.org', 'type': 'domain-name', 'value': 'ecorfan.org'}, {'id': 'domain-name--guerdofest.com', 'type': 'domain-name', 'value': 'guerdofest.com'}, {'id': 'domain-name--ber6vjyb.com', 'type': 'domain-name', 'value': 'ber6vjyb.com'}, {'id': 'domain-name--qweastradoc.com', 'type': 'domain-name', 'value': 'qweastradoc.com'}, {'id': 'domain-name--nefosferta.com', 'type': 'domain-name', 'value': 'nefosferta.com'}, {'id': 'domain-name--jirostrogud.com', 'type': 'domain-name', 'value': 'jirostrogud.com'}, {'id': 'domain-name--hiperfdhaus.com', 'type': 'domain-name', 'value': 'hiperfdhaus.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--nitutdra.com', 'type': 'domain-name', 'value': 'nitutdracom'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--recsecas.com', 'type': 'domain-name', 'value': 'recsecas.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--recsecass.com', 'type': 'domain-name', 'value': 'recsecss.com'}, {'id': 'domain-name--', 'type': 'domain-name', 'value': ''}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--webipanalyzer.com', 'type': 'domain-name', 'value': 'webipanalyzer.com'}, {'id': 'domain-name--spikeliftall.com', 'type': 'domain-name', 'value': 'spikeliftall.com'}, {'id': 'domain-name--googleaauthenticator.com', 'type': 'domain-name', 'value': 'googleaauthenticator.com'}, {'id': 'domain-name--godfaetret.com', 'type': 'domain-name', 'value': 'godfaetret.com'}, {'id': 'domain-name--geotravelsgi.xyz', 'type': 'domain-name', 'value': 'geotravelsgi.xyz'}]}
# Predicted: {'objects': [{'id': 'domain-name--webippanalyzer.com', 'type': 'domain-name', 'value': 'webipnanalyzer.com'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--devolutionrdp.com', 'type': 'domain-name', 'value': 'devolutionrdp.com'}, {'id': 'domain-name--gangstergo.com', 'type': 'domain-name', 'value': 'gangstergo.com'}, {'id': 'domain-name--wexonlake.com', 'type': 'domain-name', 'value': 'wexonlake.com'}, {'id': 'domain-name--pass-shield.com', 'type': 'domain-name', 'value': 'pass-shield.com'}, {'id': 'domain-name--npm-solar.com', 'type': 'domain-name', 'value': 'npm-solar.com'}, {'id': 'domain-name--readerpdf.net', 'type': 'domain-name', 'value': 'readerpdf.net'}, {'id': 'domain-name--keepas.org', 'type': 'domain-name', 'value': 'keepas.org'}, {'id': 'domain-name--cnealsoftware.com', 'type': 'domain-name', 'value': 'cnealsoftware.com'}, {'id': 'domain-name--keepasss.info', 'type': 'domain-name', 'value': 'keepasss.info'}, {'id': 'domain-name--decropsoftware.com', 'type': 'domain-name', 'value': 'decropsoftware.com'}, {'id': 'domain-name--icarusoftwares.com', 'type': 'domain-name', 'value': 'icarusoftwares.com'}, {'id': 'domain-name--singlesign.online', 'type': 'domain-name', 'value': 'singlesign.online'}, {'id': 'domain-name--pdffreader.com', 'type': 'domain-name', 'value': 'pdffreader.com'}, {'id': 'domain-name--hl-analytics.net', 'type': 'domain-name', 'value': 'hl-analytics.net'}, {'id': 'domain-name--decropingsof.com', 'type': 'domain-name', 'value': 'decropingsof.com'}, {'id': 'domain-name--pdfillers.com', 'type': 'domain-name', 'value': 'pdfillers.com'}, {'id': 'domain-name--convertmypdfnow.net', 'type': 'domain-name', 'value': 'convertmypdfnow.net'}, {'id': 'domain-name--wveeam.com', 'type': 'domain-name', 'value': 'wveeam.com'}, {'id': 'domain-name--putmastering.com', 'type': 'domain-name', 'value': 'putmastering.com'}, {'id': 'domain-name--pdffiller-review.com', 'type': 'domain-name', 'value': 'pdffiller-review.com'}, {'id': 'domain-name--kagomadb.com', 'type': 'domain-name', 'value': 'kagomadb.com'}, {'id': 'domain-name--remsoftman.com', 'type': 'domain-name', 'value': 'remsoftman.com'}, {'id': 'domain-name--vectordmanagesoft.com', 'type': 'domain-name', 'value': 'vectordmanagesoft.com'}, {'id': 'domain-name--astrachat.us', 'type': 'domain-name', 'value': 'astrachat.us'}, {'id': 'domain-name--astrachats.com', 'type': 'domain-name', 'value': 'astrachats.com'}, {'id': 'domain-name--nexiandevel.com', 'type': 'domain-name', 'value': 'nexiandevel.com'}, {'id': 'domain-name--sparklingprice.com', 'type': 'domain-name', 'value': 'sparklingprice.com'}, {'id': 'domain-name--hexactor.com', 'type': 'domain-name', 'value': 'hexactor.com'}, {'id': 'domain-name--pdf-filer.com', 'type': 'domain-name', 'value': 'pdf-filer.com'}, {'id': 'domain-name--gotomeet.us', 'type': 'domain-name', 'value': 'gotomeet.us'}, {'id': 'domain-name--gllmp.com', 'type': 'domain-name', 'value': 'gllmp.com'}, {'id': 'domain-name--lnfo-messengers.com', 'type': 'domain-name', 'value': 'lnfo-messengers.com'}, {'id': 'domain-name--kee-pass.com', 'type': 'domain-name', 'value': 'kee-pass.com'}, {'id': 'domain-name--pdfilier.com', 'type': 'domain-name', 'value': 'pdfilier.com'}, {'id': 'domain-name--singularlabs.org', 'type': 'domain-name', 'value': 'singularlabs.org'}, {'id': 'domain-name--rdpcamp.com', 'type': 'domain-name', 'value': 'rdpcamp.com'}, {'id': 'domain-name--wormakejean.com', 'type': 'domain-name', 'value': 'wormakejean.com'}, {'id': 'domain-name--mypodsblocked.com', 'type': 'domain-name', 'value': 'mypodsblocked.com'}, {'id': 'domain-name--devolrdm.com', 'type': 'domain-name', 'value': 'devolrdm.com'}, {'id': 'domain-name--winscpn.com', 'type': 'domain-name', 'value': 'winscpn.com'}, {'id': 'domain-name--nerobiom.com', 'type': 'domain-name', 'value': 'nerobiom.com'}, {'id': 'domain-name--dirwinstat.com', 'type': 'domain-name', 'value': 'dirwinstat.com'}, {'id': 'domain-name--veeame.com', 'type': 'domain-name', 'value': 'veeame.com'}, {'id': 'domain-name--cozy-sofware.com', 'type': 'domain-name', 'value': 'cozy-sofware.com'}, {'id': 'domain-name--mansoftwarecoz ...
# Predicted: {'objects': [{'id': 'domain-name--devolutionrdpd.com', 'type': 'domain-name', 'value': 'devolutionrrpd.com'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--vaultdocker.com', 'type': 'domain-name', 'value': 'vaultdocker.com'}, {'id': 'domain-name--endpointexperiment.com', 'type': 'domain-name', 'value': 'endpointexperiment.com'}, {'id': 'domain-name--dailywebstats.com', 'type': 'domain-name', 'value': 'dailywebstats.com'}, {'id': 'domain-name--cloudslimit.com', 'type': 'domain-name', 'value': 'cloudslimit.com'}, {'id': 'domain-name--apitestlabs.com', 'type': 'domain-name', 'value': 'apitestlabs.com'}]}
# Predicted: {'objects': []}
#
#
#
# ...
# Predicted: {'objects': [{'id': 'domain-name--timedoct0r.com', 'type': 'domain-name', 'value': 'timedoact0r.co'}, {'id': 'domain-name--domain-nametimedoctors.online', 'type': 'domain-name', 'value': 'timedoactors.online'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--annetterawlings.com', 'type': 'domain-name', 'value': 'annetterawlings.com'}, {'id': 'domain-name--wlynch.com', 'type': 'domain-name', 'value': 'wlynch.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--wlynch.org', 'type': 'domain-name', 'value': 'wlynth.org'}, {'id': 'domain-name--', 'type': 'domain-name', 'value': ''}, {'id': 'domain-name--domain-namewlynch.net', 'type': 'domain-name', 'value': 'wlynchnet'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--workspace-app.online', 'type': 'domain-name', 'value': 'workspace-app.online'}, {'id': 'domain-name--wireshark-app.online', 'type': 'domain-name', 'value': 'wireshark-app.online'}, {'id': 'domain-name--winscp-apps.online', 'type': 'domain-name', 'value': 'winscp-apps.online'}, {'id': 'domain-name--thecoopmodel.com', 'type': 'domain-name', 'value': 'thecoopmodel.com'}, {'id': 'domain-name--robo-claim.site', 'type': 'domain-name', 'value': 'robo-claim.site'}, {'id': 'domain-name--realvnc.pro', 'type': 'domain-name', 'value': 'realvnc.pro'}, {'id': 'domain-name--ivcgroup.in', 'type': 'domain-name', 'value': 'ivcgroup.in'}, {'id': 'domain-name--corporatecomf.online', 'type': 'domain-name', 'value': 'corporatecomf.online'}, {'id': 'domain-name--cilrix-corp.pro', 'type': 'domain-name', 'value': 'cilrix-corp.pro'}, {'id': 'domain-name--cilrix-corporate.online', 'type': 'domain-name', 'value': 'cilrix-corporate.online'}, {'id': 'domain-name--argenferia.com', 'type': 'domain-name', 'value': 'argenferia.com'}, {'id': 'domain-name--11234jkhfkujhs.site', 'type': 'domain-name', 'value': '11234jkhfkujhs.site'}, {'id': 'domain-name--11234jkhfkujhs.top', 'type': 'domain-name', 'value': '11234jkhfkujhs.top'}, {'id': 'domain-name--kaotickontracting.info', 'type': 'domain-name', 'value': 'kaotickontracting.info'}]}
# Predicted: {'objects': [{'id': 'domain-name--workspace-app.online', 'type': 'domain-name', 'value': 'workspace-app ऑनलाइन'}, {'id': 'domain-name--realvnc-pro', 'type': 'domain-name', 'value': 'realvnc-pro'}, {'id': 'domain-name--realvnc-pro', 'type': 'domain-name', 'value': 'realvnc-pro'}, {'id': 'domain-name--realvnc-pro', 'type': 'domain-name', 'value': 'realvnc-pro'}, {'id': 'domain-name--realvnc-pro', 'type': 'domain-name', 'value': 'realvnc-pro'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--win03.xyz', 'type': 'domain-name', 'value': 'win03.xyz'}, {'id': 'domain-name--win01.xyz', 'type': 'domain-name', 'value': 'win01.xyz'}, {'id': 'domain-name--nhelpcare.cc', 'type': 'domain-name', 'value': 'nhelpcare.cc'}, {'id': 'domain-name--nhelpcare.info', 'type': 'domain-name', 'value': 'nhelpcare.info'}, {'id': 'domain-name--myhelpcare.online', 'type': 'domain-name', 'value': 'myhelpcare.online'}, {'id': 'domain-name--myhelpcare.cc', 'type': 'domain-name', 'value': 'myhelpcare.cc'}, {'id': 'domain-name--hservice.live', 'type': 'domain-name', 'value': 'hservice.live'}, {'id': 'domain-name--gscare.live', 'type': 'domain-name', 'value': 'gscare.live'}, {'id': 'domain-name--247secure.us', 'type': 'domain-name', 'value': '247secure.us'}, {'id': 'domain-name--deskcareme.live', 'type': 'domain-name', 'value': 'deskcareme.live'}]}
# Predicted: {'objects': [{'id': 'domain-name--win03.xyz', 'type': 'domain-name', 'value': 'win03_xyz'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--americajobmail.site', 'type': 'domain-name', 'value': 'americajobmail.site'}]}
# Predicted: {'objects': [{'id': 'domain-name--americanjobmail(site', 'type': 'domain-name', 'value': 'americajanjobmail.site'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--beebeep.info', 'type': 'domain-name', 'value': 'beebeep.info'}]}
# Predicted: {'objects': [{'id': 'domain-name--beebeephoo.info', 'type': 'domain-name', 'value': 'beebeenhoo.info'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--kamisatu.top', 'type': 'domain-name', 'value': 'kamisatu.top'}]}
# Predicted: {'objects': [{'id': 'domain-name--kamisu.top', 'type': 'domain-name', 'value': 'kamiso.top'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': [{'id': 'domain-name--strainsservice.com', 'type': 'domain-name', 'value': 'strains-service.com'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--signalplus.org', 'type': 'domain-name', 'value': 'signalplus.org'}, {'id': 'domain-name--flygram.org', 'type': 'domain-name', 'value': 'flygram.org'}]}
# Predicted: {'objects': [{'id': 'domain-name--signalplus.org', 'type': 'domain-name', 'value': 'signalplus.or'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--delphidigital.org', 'type': 'domain-name', 'value': 'delphidigital.org'}]}
# Predicted: {'objects': [{'id': 'domain-name--delphidigitall.org', 'type': 'domain-name', 'value': 'delphigdigitall.org'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--veast.site', 'type': 'domain-name', 'value': 'veast.site'}, {'id': 'domain-name--tableq.xyz', 'type': 'domain-name', 'value': 'tableq.xyz'}, {'id': 'domain-name--pizz.site', 'type': 'domain-name', 'value': 'pizz.site'}, {'id': 'domain-name--ryderlawns.xyz', 'type': 'domain-name', 'value': 'ryderlawns.xyz'}, {'id': 'domain-name--maydoo.xyz', 'type': 'domain-name', 'value': 'maydoo.xyz'}, {'id': 'domain-name--hesit.xyz', 'type': 'domain-name', 'value': 'hesit.xyz'}, {'id': 'domain-name--atzipfinder.com', 'type': 'domain-name', 'value': 'atzipfinder.com'}, {'id': 'domain-name--ferdo.xyz', 'type': 'domain-name', 'value': 'ferdo.xyz'}, {'id': 'domain-name--amazonsell.pro', 'type': 'domain-name', 'value': 'amazonsell.pro'}, {'id': 'domain-name--amaazoon.org', 'type': 'domain-name', 'value': 'amaazoon.org'}, {'id': 'domain-name--akochar.site', 'type': 'domain-name', 'value': 'akochar.site'}, {'id': 'domain-name--601rajilg.xyz', 'type': 'domain-name', 'value': '601rajilg.xyz'}]}
# Predicted: {'objects': [{'id': 'domain-name--veast.site', 'type': 'domain-name', 'value': 'veast(site'}, {'id': 'domain-name--tableq.xyz', 'type': 'domain-name', 'value': 'tableq'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--mediacloud.space', 'type': 'domain-name', 'value': 'mediacloud.space'}, {'id': 'domain-name--smartappsfoursix.xyz', 'type': 'domain-name', 'value': 'smartappsfoursix.xyz'}, {'id': 'domain-name--filesindrive.info', 'type': 'domain-name', 'value': 'filesindrive.info'}, {'id': 'domain-name--filecloudservices.xyz', 'type': 'domain-name', 'value': 'filecloudservices.xyz'}, {'id': 'domain-name--edupoliceam.info', 'type': 'domain-name', 'value': 'edupoliceam.info'}, {'id': 'domain-name--avvpassport.info', 'type': 'domain-name', 'value': 'avvpassport.info'}]}
# Predicted: {'objects': [{'id': 'domain-name--mediacloud.space', 'type': 'domain-name', 'value': 'mediacloud(space)'}, {'id': 'domain-name--edupolicesam.info', 'type': 'domain-name', 'value': 'edupolicem.info'}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--yous.ai', 'type': 'domain-name', 'value': 'yous.ai'}, {'id': 'domain-name--wuwelej.top', 'type': 'domain-name', 'value': 'wuwelej.top'}, {'id': 'domain-name--voico.io', 'type': 'domain-name', 'value': 'voico.io'}, {'id': 'domain-name--vinrevildsports.shop', 'type': 'domain-name', 'value': 'vinrevildsports.shop'}, {'id': 'domain-name--tydime.io', 'type': 'domain-name', 'value': 'tydime.io'}, {'id': 'domain-name--tidymeapp.io', 'type': 'domain-name', 'value': 'tidymeapp.io'}, {'id': 'domain-name--tidyme.io', 'type': 'domain-name', 'value': 'tidyme.io'}, {'id': 'domain-name--supme.io', 'type': 'domain-name', 'value': 'supme.io'}, {'id': 'domain-name--sinergijiasport.shop', 'type': 'domain-name', 'value': 'sinergijiasport.shop'}, {'id': 'domain-name--runeonlineworld.io', 'type': 'domain-name', 'value': 'runeonlineworld.io'}, {'id': 'domain-name--refvhnhkkolmjbg.shop', 'type': 'domain-name', 'value': 'refvhnhkkolmjbg.shop'}, {'id': 'domain-name--peerme.io', 'type': 'domain-name', 'value': 'peerme.io'}, {'id': 'domain-name--partyroyaleplay.io', 'type': 'domain-name', 'value': 'partyroyaleplay.io'}, {'id': 'domain-name--partyroyaleplay.com', 'type': 'domain-name', 'value': 'partyroyaleplay.com'}, {'id': 'domain-name--partyroyale.games', 'type': 'domain-name', 'value': 'partyroyale.games'}, {'id': 'domain-name--partyroyale.fun', 'type': 'domain-name', 'value': 'partyroyale.fun'}, {'id': 'domain-name--izxxd.top', 'type': 'domain-name', 'value': 'izxxd.top'}, {'id': 'domain-name--gurunsmilrsports.shop', 'type': 'domain-name', 'value': 'gurunsmilrsports.shop'}, {'id': 'domain-name--edvhukkkmvgcct.shop', 'type': 'domain-name', 'value': 'edvhukkkmvgcct.shop'}, {'id': 'domain-name--dustfightergame.com', 'type': 'domain-name', 'value': 'dustfightergame.com'}, {'id': 'domain-name--dintrinnssports.shop', 'type': 'domain-name', 'value': 'dintrinnssports.shop'}, {'id': 'domain-name--batverssaports.shop', 'type': 'domain-name', 'value': 'batverssaports.shop'}, {'id': 'domain-name--astrosounsports.shop', 'type': 'domain-name', 'value': 'astrosounsports.shop'}, {'id': 'domain-name--1h343lkxf4pikjd.dad', 'type': 'domain-name', 'value': '1h343lkxf4pikjd.dad'}]}
# Predicted: {'objects': [{'id': 'domain-name--yous.ai', 'type': 'domain-name', 'value': 'yous(ai)'}, {'id': 'domain-name--wuwelejt.top', 'type': 'domain-name', 'value': 'wuwelejt.top'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--yourtube.fun', 'type': 'domain-name', 'value': 'yourtube.fun'}, {'id': 'domain-name--ytcache.fun', 'type': 'domain-name', 'value': 'ytcache.fun'}, {'id': 'domain-name--youbesttube.gq', 'type': 'domain-name', 'value': 'youbesttube.gq'}, {'id': 'domain-name--wispields.ml', 'type': 'domain-name', 'value': 'wispields.ml'}, {'id': 'domain-name--wpcache.ml', 'type': 'domain-name', 'value': 'wpcache.ml'}, {'id': 'domain-name--whatsappvideos.ml', 'type': 'domain-name', 'value': 'whatsappvideos.ml'}, {'id': 'domain-name--videosdahora.fun', 'type': 'domain-name', 'value': 'videosdahora.fun'}, {'id': 'domain-name--virvida.com', 'type': 'domain-name', 'value': 'virvida.com'}, {'id': 'domain-name--videocdn.fun', 'type': 'domain-name', 'value': 'videocdn.fun'}, {'id': 'domain-name--toptube.fun', 'type': 'domain-name', 'value': 'toptube.fun'}, {'id': 'domain-name--uwatchtube.ml', 'type': 'domain-name', 'value': 'uwatchtube.ml'}, {'id': 'domain-name--tecnowebclub.ga', 'type': 'domain-name', 'value': 'tecnowebclub.ga'}, {'id': 'domain-name--techyclub.in', 'type': 'domain-name', 'value': 'techyclub.in'}, {'id': 'domain-name--tcache.ml', 'type': 'domain-name', 'value': 'tcache.ml'}, {'id': 'domain-name--tapcache.ml', 'type': 'domain-name', 'value': 'tapcache.ml'}, {'id': 'domain-name--supercache.top', 'type': 'domain-name', 'value': 'supercache.top'}, {'id': 'domain-name--streamix.tv', 'type': 'domain-name', 'value': 'streamix.tv'}, {'id': 'domain-name--satishmoheyt.ml', 'type': 'domain-name', 'value': 'satishmoheyt.ml'}, {'id': 'domain-name--satishmoheyt.in', 'type': 'domain-name', 'value': 'satishmoheyt.in'}, {'id': 'domain-name--primesinfo.ml', 'type': 'domain-name', 'value': 'primesinfo.ml'}, {'id': 'domain-name--poptube.fun', 'type': 'domain-name', 'value': 'poptube.fun'}, {'id': 'domain-name--primesinfo.com', 'type': 'domain-name', 'value': 'primesinfo.com'}, {'id': 'domain-name--pharmabeaver.ml', 'type': 'domain-name', 'value': 'pharmabeaver.ml'}, {'id': 'domain-name--newsworldcity.ml', 'type': 'domain-name', 'value': 'newsworldcity.ml'}, {'id': 'domain-name--pharmabeaver.com', 'type': 'domain-name', 'value': 'pharmabeaver.com'}, {'id': 'domain-name--newsworldcity.com', 'type': 'domain-name', 'value': 'newsworldcity.com'}, {'id': 'domain-name--mikerin.ml', 'type': 'domain-name', 'value': 'mikerin.ml'}, {'id': 'domain-name--myplayer.ml', 'type': 'domain-name', 'value': 'myplayer.ml'}, {'id': 'domain-name--mikerin.com', 'type': 'domain-name', 'value': 'mikerin.com'}, {'id': 'domain-name--melhoresdomomento.ml', 'type': 'domain-name', 'value': 'melhoresdomomento.ml'}, {'id': 'domain-name--megasearch.gq', 'type': 'domain-name', 'value': 'megasearch.gq'}, {'id': 'domain-name--megacdn.top', 'type': 'domain-name', 'value': 'megacdn.top'}, {'id': 'domain-name--megacdn.ml', 'type': 'domain-name', 'value': 'megacdn.ml'}, {'id': 'domain-name--mcdn.ga', 'type': 'domain-name', 'value': 'mcdn.ga'}, {'id': 'domain-name--mbyte.gq', 'type': 'domain-name', 'value': 'mbyte.gq'}, {'id': 'domain-name--maxcache.ml', 'type': 'domain-name', 'value': 'maxcache.ml'}, {'id': 'domain-name--livrosdereceita.ml', 'type': 'domain-name', 'value': 'livrosdereceita.ml'}, {'id': 'domain-name--kbyte.ml', 'type': 'domain-name', 'value': 'kbyte.ml'}, {'id': 'domain-name--jscache.live', 'type': 'domain-name', 'value': 'jscache.live'}, {'id': 'domain-name--journeywithvision.ga', 'type': 'domain-name', 'value': 'journeywithvision.ga'}, {'id': 'domain-name--journeywithvision.com', 'type': 'domain-name', 'value': 'journeywithvision.com'}, {'id': 'domain-name--investwell.site', 'type': 'domain-name', 'value': 'investwell.site'}, {'id': 'domain-name--jestick.ml', 'type': 'domain-name', 'value': 'jestick.ml'}, {'id': 'domain-name--investwell.ml', 'type': 'domain-name', 'value': 'investwell.ml'}, {'id': 'domain-name--hypercdn3.ml', 'type': 'domain-name', 'value': 'hypercdn3.ml'}, {'id': 'domain-name--hypercdn.ml', 'type': 'domain-name', 'value': ...
# Predicted: {'objects': [{'id': 'domain-name--ytcache.fun', 'type': 'domain-name', 'value': 'ytcachefun'}]}
#
#
#
# Actual: {'objects': [{'id': 'domain-name--mylittlecabbage.net', 'type': 'domain-name', 'value': 'mylittlecabbage.net'}, {'id': 'domain-name--linktoxic34.com', 'type': 'domain-name', 'value': 'linktoxic34.com'}, {'id': 'domain-name--jenniferwelsh.com', 'type': 'domain-name', 'value': 'jenniferwelsh.com'}, {'id': 'domain-name--flexiblemaria.com', 'type': 'domain-name', 'value': 'flexiblemaria.com'}, {'id': 'domain-name--dogmupdate.com', 'type': 'domain-name', 'value': 'dogmupdate.com'}]}
# Predicted: {'objects': [{'id': 'domain-name--mylittlekitchen.net', 'type': 'domain-name', 'value': 'mylittlekitche.net'}, {'id': 'domain-name--jennifewelsh.com', 'type': 'domain-name', 'value': 'jennifrewlsh.com'}, {'id': 'domain-name--', 'type': 'domain-name', 'value': ''}]}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}
#
#
#
# Actual: {'objects': []}
# Predicted: {'objects': []}

# %%
# for i in range(len(outputs)):
#     for p in processed_preds4eval[i]["objects"]:
#         print(p)
#         print("\n")

# %%
from evaluation.stix_evaluator import STIXEvaluator

evaluator = STIXEvaluator(comparison_values=["id"], cti_object_types=["domain-name"])

# %%
p, r, f1, full_res = evaluator._evaluate_(predicted=processed_preds4eval, actual=outputs)
print(f"Precison: {p}\nRecall: {r}\nF1-Score: {f1}")
# Out:
# Precison: 0.21023
# Recall: 0.02668
# F1-Score: 0.04734

# %%
from langchain_ollama.llms import OllamaLLM

model = OllamaLLM(model="gpt-oss:20b")

# %%
preds = [model.invoke(sft_system_message + user_input) for user_input in tqdm(inputs)]
# Out:
# 100%|██████████| 298/298 [1:15:53<00:00, 15.28s/it]

# %%
preds4eval = []
failed_preds = []
pattern = r'\{\s*"id"\s*:\s*"[^"]*"\s*,\s*"type"\s*:\s*"[^"]*"\s*,\s*"value"\s*:\s*"[^"]*"\s*\}'

for p in preds:

    p = p.lower().replace("\t", "")

    try:
        objects = json.loads(p)["objects"]
    except:
        objects = re.findall(pattern, p)
        if not objects and '"objects": []' not in p:
            failed_preds.append(p)
        elif objects:
            objects = [json.loads(obj) for obj in objects]
    
    preds4eval.append(
            {
                "objects":objects
                }
        )

# %%
print(f"Percenrage of failed json outputs: {'{:.1f}'.format(100 * len(failed_preds) / len(inputs))}%")
# Out:
# Percenrage of failed json outputs: 44.0%

# %%
# Post processing
processed_preds4eval = []

def fix_domain_name_id(wrong_id: str) -> str:
    """
    Fixes malformed domain-name IDs according to the observed patterns.
    """

    # Trim spaces
    s = wrong_id.strip().lower()

    # Remove leading underscores or hyphens
    s = re.sub(r'^[-_]+', '', s)

    # Remove redundant 'malware' if it’s at the start but malformed
    s = re.sub(r'^(domain-name[-_]+)', '', s)

    # Handle duplicated name parts (e.g., 'fatboy--fatboy')
    parts = re.split(r'--+', s)
    if len(parts) == 2 and parts[0] == parts[1]:
        s = parts[0]

    # Prepend 'malware--'
    corrected = f"domain-name--{s}"

    # Ensure only one double dash after 'malware'
    corrected = re.sub(r'^domain-name-+', 'domain-name--', corrected)

    return corrected

# Step 1
for p in preds4eval:
    objects = []
    for obj in p["objects"]:
        # Step 1
        if "id" in obj.keys():
            ID = fix_domain_name_id(obj["id"].strip())

        if "value" in obj.keys():
            VALUE = obj["value"]
        else:
            VALUE = ID.split("domain-name--")[-1]

        objects.append(
            {
                "id":ID,
                "type":"domain-name",
                "value":VALUE,
            }
        )

    processed_preds4eval.append(
                {
                    "objects":objects
                }
            )

# %%
from evaluation.stix_evaluator import STIXEvaluator
import warnings

warnings.filterwarnings(action="ignore")

evaluator = STIXEvaluator(comparison_values=["type", "name"], cti_object_types=["domain-name"])

# %%
p, r, f1, full_res = evaluator._evaluate_(predicted=processed_preds4eval, actual=outputs)
print(f"Precison: {p}\nRecall: {r}\nF1-Score: {f1}")
# Out:
# Precison: 0.46285
# Recall: 0.32283
# F1-Score: 0.38036

# %%
processed_preds4eval[3]
# Out:
# {'objects': [{'id': 'domain-name--domain--cv-builder.site',
#    'type': 'domain-name',
#    'value': 'cv-builder.site'},
#   {'id': 'domain-name--domain--siamaster.com.mx',
#    'type': 'domain-name',
#    'value': 'siamaster.com.mx'},
#   {'id': 'domain-name--domain--chatgptex.us',
#    'type': 'domain-name',
#    'value': 'chatgptex.us'},
#   {'id': 'domain-name--domain--allfreesoftware.online',
#    'type': 'domain-name',
#    'value': 'allfreesoftware.online'},
#   {'id': 'domain-name--domain--all-free-software.online',
#    'type': 'domain-name',
#    'value': 'all-free-software.online'}]}

# %%
outputs[3]
# Out:
# {'objects': [{'id': 'domain-name--siamaster.com.mx',
#    'type': 'domain-name',
#    'value': 'siamaster.com.mx'},
#   {'id': 'domain-name--cv-builder.site',
#    'type': 'domain-name',
#    'value': 'cv-builder.site'},
#   {'id': 'domain-name--chatgptex.us',
#    'type': 'domain-name',
#    'value': 'chatgptex.us'},
#   {'id': 'domain-name--allfreesoftware.online',
#    'type': 'domain-name',
#    'value': 'allfreesoftware.online'},
#   {'id': 'domain-name--all-free-software.online',
#    'type': 'domain-name',
#    'value': 'all-free-software.online'}]}

# %%
evaluator.evaluate_single(predicted=processed_preds4eval[3], actual=outputs[3])
# Out:
# (1.0,
#  1.0,
#  1.0,
#  {'domain-name': {'precision': 1.0,
#    'recall': 1.0,
#    'f1': 1.0,
#    'pred_count': 5,
#    'actual_count': 5,
#    'true_positives': 5,
#    'false_positives': 0,
#    'false_negatives': 0,
#    'weight': 5}})

# %%
for i, file in enumerate(os.listdir(test_path)):
    cti_type = file.split("--")[0]
    if cti_type not in include_cti_type:
        continue
    print(i, file)
# Out:
# 1 domain-name--ebdd1253-5d27-4c84-a9eb-09d534408d90.json
# 17 domain-name--28faa33a-990c-4a54-8750-fc09a515a236.json
# 36 domain-name--facefbb1-fe87-477f-aea8-2b3d856d49de.json
# 50 domain-name--f9583e0d-f3ac-4d4a-b20a-754b26bc7ecb.json
# 68 domain-name--76dae889-6ef3-4697-83c0-d47fa8c9dd71.json
# 95 domain-name--d7f6ec01-9499-4128-b010-32cba147d534.json
# 101 domain-name--979aad5d-b8d9-4368-acff-e2049ee5faca.json
# 133 domain-name--9eed6e0c-62b6-4795-b0d0-5571d63557a8.json
# 150 domain-name--06317c2b-ce2f-4a57-9bdd-2a5270447de8.json
# 169 domain-name--c9e742f1-4ea1-4e3e-8af5-2816052f8444.json
# 206 domain-name--047622b2-335f-4db6-ab5e-a4444016ba8e.json
# 212 domain-name--9837fa37-56cd-4d83-9292-b19be681453e.json
# 219 domain-name--49608eb2-8d5c-4840-a20c-842d02b63a85.json
# 262 domain-name--51858252-43d2-44e5-ac0c-b4da95a3afac.json
# 272 domain-name--e95ae185-32e4-41b2-832b-5de15d602ada.json
# 286 domain-name--ae4a2d1f-3859-492e-87e0-360d511b70b3.json
# 332 domain-name--fdca0b56-22a5-455a-89b2-6ec5f5e8a599.json
# 335 domain-name--e1df8ab7-884c-4082-b1d5-c4eff3e9cca9.json
# 345 domain-name--55a710a2-0218-4dc9-8cbd-3fe564e5cbc4.json
# 347 domain-name--ead7db0e-ff0a-48a0-acb8-504de88bc589.json
# 368 domain-name--6f88a5e3-f8ad-4069-a6f3-018164d704a1.json
# 386 domain-name--87b7f3cf-db33-4401-b976-95ccb20fc28c.json
# 388 domain-name--edee2147-79ba-4683-b707-5d7720a5ab9a.json
# 392 domain-name--bf5f4841-b45c-456d-a458-94faab09028b.json
# 397 domain-name--67234e9d-e8f9-4bb7-82a4-b90a10b5f6f4.json
# 406 domain-name--356d1048-705c-44aa-9324-2f3e63d916bc.json
# 407 domain-name--54f4f7a3-6d6e-47e5-914c-e9e23444c2d6.json
# 431 domain-name--3360c488-9439-4ea3-b253-91bfdcbd210b.json
# 472 domain-name--5156e4c7-2d11-4fd4-9eb7-611865d88135.json
# 519 domain-name--fff4fed3-41e4-4a9a-8161-d6c3214ea62a.json
# 537 domain-name--7fb3d88b-a788-4fbc-8510-5b6b91df8dc5.json
# 539 domain-name--652b91cf-4e59-43db-9fcb-6134cc7d953d.json
# 550 domain-name--5dc95895-ff93-4aac-b5d2-ec3b2069ff86.json
# 577 domain-name--f4f6b9a7-4086-4c65-b4df-6c4d9ace1266.json
# 579 domain-name--81cca5f8-716e-4dcb-ab41-25538ce99a48.json
# 590 domain-name--06702bff-4b94-4bfe-8c08-44ee5c074306.json
# 601 domain-name--89e42549-afcc-43b5-a31e-ede223890726.json
# 616 domain-name--c93e22c7-f345-468d-aabd-8fbaf0ad6d9b.json
# 656 domain-name--00f732b4-987f-4fca-965a-c8b1b788ba4b.json
# 661 domain-name--d9990418-ab7b-473b-8060-5c83173312b6.json
# 691 domain-name--d4e17c68-18cd-44c0-a1c7-b9b2af61ffc9.json
# 698 domain-name--8b7fe23e-8ea1-49aa-9e3e-10c9095f8b53.json
# 778 domain-name--4a41c0fe-1de5-41a3-8076-02089dc00f5c.json
# 787 domain-name--70441f97-9afe-4bf3-b07d-ae3fa2abd9e1.json
# 788 domain-name--aa8a2846-5742-4dd4-a22d-cbf2930d2331.json
# 790 domain-name--1caaedbc-5b25-4c22-9404-850f22838f20.json
# 841 domain-name--934675dc-8802-4844-b8c0-c73d57e09212.json
# 844 domain-name--fa3b57e7-96f3-41c1-a368-1a1fd25e4563.json
# 852 domain-name--a232a17e-ae8b-491e-9bc5-4fda419c53d7.json
# 883 domain-name--5aaaf115-9429-4303-b90f-34d9c3b41cfb.json
# 920 domain-name--01a9636f-8d63-415f-b31e-39b60907e478.json
# 950 domain-name--89715e52-d1c5-439d-8a1d-68869a87b911.json
# 995 domain-name--02e3d6c6-7766-402a-a6a8-dce946b80bf7.json
# 1011 domain-name--29242b8d-4983-4d1f-b192-edaffe8328d7.json
# 1086 domain-name--038464fd-e147-45a9-840c-2f846d1f382d.json
# 1089 domain-name--9a7ec652-ffbe-4f14-86f1-930550f8c426.json
# 1096 domain-name--f0dac27d-2574-4d2e-8177-b9e598e4a80e.json
# 1125 domain-name--b6147a48-a4e3-45b7-a87b-f9c80b2b3f37.json
# 1145 domain-name--4ede505f-a97e-4577-b9db-477d950e633a.json
# 1175 domain-name--45d9239d-06e2-4259-b960-3b76ed52c565.json
# 1188 domain-name--13b96c56-1f56-4a85-a5d7-dd7b30112b60.json
# 1207 domain-name--95199d2f-a59a-481d-b604-bfd65ba3291b.json
# 1216 domain-name--02797bd3-3a72-4e84-ae6d-fd4fe573bcc9.json
# 1220 domain-name--8b4a2deb-fef6-4e68-8afb-929781d32c9a.json
# 1225 domain-name--56a4a871-6cb3-49e6-a139-ddb0547aacd3.json
# 1237 domain-name--7fd4071c-a5d6-4f40-83d7-8dedb3a90e22.json
# 1277 domain-name--7f18b3ea-8a07-420b-8720-00a6bc98ad9d.json
# 1292 domain-name--cc4e4a93-e1b2-4e0d-8bd3-8b60c22d8266.json
# 1293 domain-name--bdbe1022-b7e3-4d9d-bd93-3e5aa8a27045.json
# 1314 domain-name--82781ac1-f17a-488b-b74a-8c32f447a559.json
# 1319 domain-name--e7b27293-a99d-47aa-8e66-f880df2e6094.json
# 1325 domain-name--507d5ea4-28d4-4c93-bed0-c8b2d05a0a4f.json
# 1343 domain-name--2c31b7b3-804a-47b6-bf29-ea5a451b18a7.json
# 1358 domain-name--2b580e07-22d0-4d90-93f9-7d18efa95cfe.json
# 1372 domain-name--b7024594-c6f3-4f7f-8cd3-712ec8615948.json
# 1375 domain-name--4748b5bb-5611-47b7-b6a3-70b15a9715e3.json
# 1390 domain-name--33ebf163-35d4-4a7c-8c45-7f94a5a88150.json
# 1412 domain-name--ef8d044a-1c4a-4fa6-adfc-0ef97473e9e8.json
# 1423 domain-name--459bf240-06b4-4cb0-b6cb-b4b6eec0d097.json
# 1458 domain-name--e6bd8add-b4b4-4bd1-a85c-a49c3fd401f3.json
# 1472 domain-name--4a70a2bd-7c59-4961-94db-fb32da194f05.json
# 1489 domain-name--8775851a-f163-4b40-a0c0-1ebd2ab115db.json
# 1495 domain-name--59715080-6b1d-43b5-a6db-da7391806016.json
# 1500 domain-name--eb5404c0-01a2-492a-a99d-88e8b05c30fb.json
# 1508 domain-name--b14f8cb2-6e13-431e-ae95-d372b84e98c5.json
# 1511 domain-name--7f0e6fe2-44ab-4578-a306-8efde93348a7.json
# 1535 domain-name--2153e26b-8b89-4d4c-9a6e-21a396cbe93d.json
# 1537 domain-name--68ba0a03-dafe-45e3-82d1-36356f78f339.json
# 1546 domain-name--f1518f22-7249-475b-afb7-b79f9c62a497.json
# 1561 domain-name--97229530-802f-445e-a56e-6b3fcde0076d.json
# 1562 domain-name--aa3e48a0-f51b-4fc9-9cfd-10e82f359abc.json
# 1585 domain-name--6d982508-1ffa-461a-8fdf-be75d2fb9979.json
# 1622 domain-name--9e20b2e6-a88c-42a0-8e7c-abcd8ec5df18.json
# 1632 domain-name--9252e9c2-f4ba-4423-a9f9-723fab3f69a2.json
# 1680 domain-name--d2775533-2522-44a5-84af-c7545480f2f2.json
# 1683 domain-name--9240bb7b-bcf2-48bb-a7e4-1480daedc89c.json
# 1693 domain-name--8e10ca40-dac0-4f20-a994-29df825a2979.json
# 1736 domain-name--16ede71f-74ca-4190-b4c9-c0692018099f.json
# 1749 domain-name--efd659d9-eaf6-48f2-8928-a5155b79e309.json
# 1759 domain-name--f98f6200-6592-4764-a268-21fd1148f69c.json
# 1773 domain-name--bdb689d5-de09-459a-9e7f-1794695eec6c.json
# 1781 domain-name--640ce74e-30d2-48b1-b888-5450747a4b42.json
# 1801 domain-name--992f28cc-0e4d-4f87-b4fb-29add0d55c30.json
# 1805 domain-name--9096ed32-1b51-4113-8c68-d57114a4272f.json
# 1808 domain-name--3decb585-93e0-4725-89f0-37d9e2be292d.json
# 1812 domain-name--3731b32e-2e09-4b8b-9167-5f6a2e79ff88.json
# 1815 domain-name--c9d03546-8c9d-434d-a2a3-e49b6e7b4985.json
# 1818 domain-name--8844d264-3d23-46e7-9d66-0720b8ced62b.json
# 1820 domain-name--ff373410-0cc8-4b11-9ba6-52ab3a5c7d68.json
# 1835 domain-name--07cbea9c-1c17-45df-9092-1881b80b2e61.json
# 1851 domain-name--d6b5d89c-d8cf-4897-98cd-f9c35014152b.json
# 1873 domain-name--40cac3b1-ae79-44c2-8038-c242930a6bba.json
# 1879 domain-name--b3f70f96-ba9c-46d6-a658-520a96f76f2f.json
# 1882 domain-name--c324c638-8558-4ed6-8ebc-9be15fd38b27.json
# 1886 domain-name--3b74c3d5-fd9b-43bd-bd27-5a0560df464c.json
# 1913 domain-name--a27a9860-046d-4b77-99ff-e1ed61de9ea8.json
# 1937 domain-name--b7c8b456-935f-4a26-8152-41104d66e4f7.json
# 1940 domain-name--2c471353-393f-4e94-8c96-5b5bf31d43d3.json
# 1950 domain-name--5a501e84-3364-4c85-8b2e-2747a5ce948f.json
# 1995 domain-name--b4b43550-1c10-49f4-9df9-9f446a42cae0.json
# 1996 domain-name--d27dd1e7-6f51-495f-ae03-54e0a2b29f86.json
# 1998 domain-name--76cba4c4-8a8f-4843-84fc-23bd2ec3e885.json
# 2001 domain-name--b12afa16-e152-4346-92f6-716428e2aebd.json
# 2009 domain-name--6047887b-f081-4703-a292-73788c6440ad.json
# 2017 domain-name--a61593b3-e2f2-4718-bd35-6f174e467539.json
# 2020 domain-name--d5de27ed-ec31-4fb8-9b04-24cc2bf972a2.json
# 2026 domain-name--3c503576-cfc0-463d-b0ad-bd542eaa6b2f.json
# 2036 domain-name--17e0d40b-30a4-47e7-b7c3-cab881e35349.json
# 2045 domain-name--06f42ca4-24e5-425e-a4c5-c0d5310615aa.json
# 2055 domain-name--809c4b6e-b08a-4944-8555-8af01f604568.json
# 2090 domain-name--65e454fd-4d89-4e12-aa2d-e2c59e867563.json
# 2131 domain-name--09703ff1-6b28-4b44-87c3-def329458a27.json
# 2139 domain-name--51036b35-8e79-4f7b-94fc-3c5b614ffc57.json
# 2160 domain-name--d4dfe685-0086-4bd0-a7c9-da13d3894903.json
# 2170 domain-name--2d032dd8-f6e6-45d0-adb9-4baa23702abe.json
# 2241 domain-name--440094f0-eb2b-4bd0-ab2a-da8ee04a50a3.json
# 2269 domain-name--c5c1ffe3-9a23-45ad-8108-808a89912501.json
# 2274 domain-name--2f2634b5-b109-4a8a-8c21-e1f4b5fe1654.json
# 2285 domain-name--5596cb81-8a3e-456a-877f-559455b824b4.json
# 2290 domain-name--5bb17291-a23f-4f2a-9678-d517a10e5790.json
# 2292 domain-name--6feffa50-675c-4a5e-9603-a3361ff3fd17.json
# 2311 domain-name--31778e7f-f4d7-416c-a64f-3ef5b4b714f5.json
# 2321 domain-name--e076881b-173d-46e2-a509-210394478f66.json
# 2330 domain-name--5b033f42-d3c8-4ff3-be60-8e97c2d7e867.json
# 2336 domain-name--8ef70820-52a3-42af-b150-66353520d6a2.json
# 2338 domain-name--2f4897ef-9ced-4886-bd7e-f02b86d11a2d.json
# 2353 domain-name--9d07f3ba-7d91-4960-bf53-bdf8ef00fc8f.json
# 2355 domain-name--becf00d6-32ae-4942-9a81-2c64dfab79b4.json
# 2361 domain-name--c3663f89-cb30-4ce5-906f-c702b8d9fbc0.json
# 2366 domain-name--98d3d179-f091-4a22-a872-658fa40705fa.json
# 2367 domain-name--4377693e-f7da-4ca9-8c3c-37ead536aff9.json
# 2388 domain-name--512084c6-f951-4c3f-ada7-531f71e19868.json
# 2416 domain-name--e825eb3d-88fc-4e7f-b0ef-718731494744.json
# 2429 domain-name--dbe149f3-24d3-44c0-a853-eac5c9a3fa54.json
# 2437 domain-name--9d0da48b-492e-479c-ba7e-3d1306c147c0.json
# 2487 domain-name--a4f43c8f-65bd-468e-b797-f4a1898f5634.json
# 2509 domain-name--a0ec91f6-1147-400f-ba02-7b63cfcfd2ea.json
# 2522 domain-name--e986d0b5-b55d-4324-9af9-9065a6819194.json
# 2594 domain-name--ab7e9b32-96c3-4d99-9143-c0393e4a5f4e.json
# 2598 domain-name--7c4507f1-43b7-49ce-bcb1-99d92b2e9439.json
# 2631 domain-name--8ffab167-83ec-4cbf-90b9-a9d663f85432.json
# 2681 domain-name--dfef1739-99c3-4604-aa05-065dd218c304.json
# 2691 domain-name--e5cc5e5b-c8a3-4820-b966-377da356af40.json
# 2696 domain-name--083adaec-ab26-4024-afa9-bc619e845d36.json
# 2708 domain-name--6c21f1db-9ec3-4cd5-8dd1-dcc22ec7a77d.json
# 2712 domain-name--f3de36e1-a3c3-4b68-b53e-322c43e7110c.json
# 2714 domain-name--4beb3673-c636-4e7e-9d83-08acd01a0258.json
# 2727 domain-name--eaff4a2f-b2b2-46ae-941c-3c90976389e0.json
# 2732 domain-name--40c98ff5-1fe2-4a88-8cbd-2ab3a3397004.json
# 2740 domain-name--cb9b9715-e069-4e2c-9ac0-90c776e80503.json
# 2749 domain-name--7297e454-4f27-435d-9582-59816071429a.json
# 2771 domain-name--db8709b4-f92e-4611-8032-b4a83ab9889a.json
# 2773 domain-name--660a42a8-bf29-4a64-853c-53c551bc0523.json
# 2776 domain-name--29dfcfc5-fd6b-4efc-9657-a1fe40a765c8.json
# 2812 domain-name--42b83b90-09e3-41cc-9ea6-fa49366db373.json
# 2834 domain-name--1f7c498f-1fb2-4735-a10f-dc52c8b6784b.json
# 2837 domain-name--28adbef3-4c02-439b-8d25-879b7ed7dd08.json
# 2859 domain-name--29aa3290-8aee-4248-9134-f9e87605749e.json
# 2876 domain-name--446011f2-2283-4419-81bc-6b8f175ed2f5.json
# 2908 domain-name--c9deaac5-3297-4cb9-a76c-e862210c42ae.json
# 2911 domain-name--e4d78c01-de09-4212-a7a3-62673c0a8ac2.json
# 2915 domain-name--b2940903-beef-42df-ae4c-79189c05f30c.json
# 2926 domain-name--f1418613-cdfc-4daa-987f-01411c166579.json
# 2971 domain-name--f447dfa8-8e3d-44a1-ae1c-a252697c9fe6.json
# 3002 domain-name--6b2bea5d-065f-48ca-89f5-4876d2063040.json
# 3025 domain-name--b6081e43-8d23-4ce7-b68a-03db85f4c548.json
# 3038 domain-name--dc372923-5243-45fe-95ee-fe5f37c9d038.json
# 3043 domain-name--ce452690-865e-49a3-8286-72a1a83fa79a.json
# 3067 domain-name--5e7715c2-6462-486b-beb6-faf25139b0e1.json
# 3072 domain-name--01368ec9-5e1b-48fd-a24a-2dfb61d71c16.json
# 3073 domain-name--84c692c2-edd6-4a25-9b4c-7acd68c25936.json
# 3096 domain-name--bc53355b-2d0f-4330-905b-c7d8e467f23b.json
# 3104 domain-name--ccf5eac4-9299-4d7f-9136-fee74a3259b6.json
# 3131 domain-name--0b1f4c4e-0f40-413c-8810-00dbc8ecb382.json
# 3153 domain-name--848f9dd5-02cf-4a94-9f9c-c78089818115.json
# 3156 domain-name--848dead3-12ae-4166-83af-07d57b0a0196.json
# 3161 domain-name--2c4b36c3-0b69-41d1-94d4-2e328b7d1395.json
# 3169 domain-name--255eba4e-a5d7-4804-8cac-d25ecf94b9ef.json
# 3170 domain-name--24312329-dd4c-4ee9-b8b0-601defead29b.json
# 3173 domain-name--85015e2c-26bf-40cf-81c7-105c17cfc794.json
# 3180 domain-name--31bc0091-123e-45d6-b7a0-c9831995bfb5.json
# 3185 domain-name--18abce43-6c02-4403-bf72-2e268009ad42.json
# 3193 domain-name--cada860c-3e04-4e99-bf8e-897b930dd734.json
# 3199 domain-name--28c63e31-d0a5-43c1-a9de-53c855a600ae.json
# 3201 domain-name--7218ee8d-fbb2-4c60-b04d-67eecf919cc4.json
# 3219 domain-name--281961f1-5689-4ae3-bf1c-1d9c5bb3ed61.json
# 3224 domain-name--b86c0959-f397-466d-92f8-a94a30ce8b71.json
# 3238 domain-name--f0121b46-6b6d-4237-b3b7-0d461a7ebf51.json
# 3239 domain-name--5357cd28-6ecc-446b-9ce1-084eaa6f6d65.json
# 3252 domain-name--399ec0ca-0eef-4312-b777-29de1ed59bf5.json
# 3253 domain-name--abe8ca28-020c-4236-bdc7-b06ea3031a99.json
# 3273 domain-name--8c64ea83-f6fb-49f4-b048-13cea5132c4f.json
# 3280 domain-name--ec648600-227f-4059-b729-d3e89dc80260.json
# 3283 domain-name--351ac134-ffac-4610-af8f-c0106682255a.json
# 3291 domain-name--98c89add-174d-44dc-a1b7-faa014c70584.json
# 3296 domain-name--34bd688e-458c-4582-b854-c4998a6f0a9d.json
# 3299 domain-name--b791fc2c-8551-4a43-9d29-dbd923a137b1.json
# 3307 domain-name--10ae423c-7bf4-4e27-bf92-4459b2d77453.json
# 3323 domain-name--78c91865-b300-4887-9c2c-d644fad6faf7.json
# 3343 domain-name--54fc485f-eca2-4ab8-827c-37d1241f4f01.json
# 3387 domain-name--0df833fa-33af-40ca-afde-e7f5a0eb15d0.json
# 3416 domain-name--8ba93ce9-6fd9-4e84-ae78-876d26e7c730.json
# 3442 domain-name--8e67219b-e7e6-44d1-97f5-86b880222b92.json
# 3460 domain-name--25f22c45-a8e9-4b83-8a3c-d6003dd35db1.json
# 3485 domain-name--9e8f042d-3893-4b76-848a-a043a167ae7e.json
# 3490 domain-name--671331e4-1c2e-420d-9fbc-c92b13e18769.json
# 3492 domain-name--a1e7a45b-6bcc-464b-ac9a-53056054ba31.json
# 3503 domain-name--6d710552-107f-4d9c-972b-4e7ab2bceed5.json
# 3507 domain-name--35d9fc32-21fb-48a0-a91f-19c3733be416.json
# 3514 domain-name--74b1221c-79dd-4bc0-91fb-c490224a3988.json
# 3541 domain-name--9bba7fad-4882-42f3-8da2-7699f5b519e4.json
# 3550 domain-name--3408298e-dcdd-4e77-b1b9-1257633675ca.json
# 3584 domain-name--889cb0fc-56f3-4fcf-965c-0381d68cae19.json
# 3595 domain-name--5c89e4d5-4179-4720-9ba3-02feb5517e03.json
# 3608 domain-name--cbd6c856-350a-4090-8c34-c7494d5efffc.json
# 3612 domain-name--800fc852-e386-42f0-8f33-13efb4e34590.json
# 3641 domain-name--7c6013b9-d76b-4190-86df-1a2a84f49b0d.json
# 3711 domain-name--c350c7e9-416a-4978-aed9-8522077e9943.json
# 3739 domain-name--ff043ac9-95a0-4047-ab10-047f8ee86f92.json
# 3755 domain-name--500edd94-725e-403b-b8ad-628e24c8e4df.json
# 3757 domain-name--0206906c-cd57-4436-ada7-1d800d36ae76.json
# 3777 domain-name--61d90b2e-8fc8-4247-be79-90cedbbe4147.json
# 3782 domain-name--fee314a1-bd0b-4c69-b50a-2b98f07df421.json
# 3786 domain-name--d3dc65b3-24a1-453a-92da-110e42142332.json
# 3789 domain-name--38f4cd07-237f-4267-a898-62689d615be0.json
# 3790 domain-name--f5a1d08f-6bbc-4f0b-ad15-064e05a8d02d.json
# 3811 domain-name--f8e6df5a-5ff7-48af-a881-bf26202801b1.json
# 3826 domain-name--69836ed6-b4e5-493c-a7de-995059538275.json
# 3847 domain-name--ed7ac960-c356-4bfe-86ce-55109f3e912c.json
# 3859 domain-name--b41bb23c-88a3-4e64-a524-6116c83e3126.json
# 3870 domain-name--0d16b500-b94a-46a6-ae28-10eb45bef2be.json
# 3875 domain-name--6c0a0ff6-9dae-428d-8870-820136483216.json
# 3877 domain-name--cd13a726-b34b-4962-acf4-6e4b58a94689.json
# 3898 domain-name--164b21ce-b802-418e-bdaf-6fdcd13a3b0e.json
# 3948 domain-name--9e0b1b10-0fbb-4f04-9dd1-9bcfc590b108.json
# 3954 domain-name--bdd27c09-239b-4bb1-bc4b-47455497c05c.json
# 3985 domain-name--688fedf9-d594-407d-9843-02ff6be27c29.json
# 3999 domain-name--de451d0c-f77b-4113-8b35-3c00742a2003.json
# 4011 domain-name--d960d61b-8f71-46b9-ac1e-ecdfbf399136.json
# 4019 domain-name--06d01c75-ff52-4cc1-8ada-04a83d446168.json
# 4022 domain-name--6eeda06c-0f0c-4213-ad17-eb1813148e2f.json
# 4032 domain-name--89549e23-1bb2-41d4-988b-00590921f887.json
# 4056 domain-name--a510d3ae-6f4f-402a-a63c-951c90006415.json
# 4073 domain-name--27236583-9838-41f0-bd72-e63a82d2d89a.json
# 4097 domain-name--1605958a-f62f-4254-9396-2615e0941ba0.json
# 4101 domain-name--502785cc-a844-48fa-8fca-54b5b0e91330.json
# 4102 domain-name--63653205-cbd0-453e-8863-19a52719ca55.json
# 4137 domain-name--4ca6190a-1e7a-4414-9519-64d63189fc70.json
# 4150 domain-name--3c6b17ac-c16f-44ce-9a7d-99fb8f27bde8.json
# 4160 domain-name--bc8e274a-e80c-4d74-a1a3-85c637fdcc7d.json
# 4253 domain-name--2e165945-bad1-4a54-ad5e-e5202ce4e333.json
# 4269 domain-name--06cbbf62-ddfe-46b8-9a9b-dff838933d48.json
# 4287 domain-name--8625c06e-bbc1-42f7-b9bf-52032e60f5d3.json
# 4310 domain-name--5ff4b34e-d69f-4e87-855e-b2bd6531064a.json
# 4311 domain-name--23976f87-2a0b-4a0c-9d08-03891a62cf37.json
# 4312 domain-name--dc9bd658-e299-49cb-aefb-71967141f0f4.json
# 4326 domain-name--1784d0e0-e2f6-4732-8eca-646ce23914fd.json
# 4375 domain-name--111326be-25f1-41f2-9bcc-10770b624793.json
# 4409 domain-name--a5065433-4861-4b44-a908-5d345efa442e.json
# 4410 domain-name--55405c3a-16ec-429c-afd7-84e8d64e626d.json
# 4448 domain-name--e44a64fe-d26b-476e-b559-2662a69d9baf.json
# 4452 domain-name--07dfece5-3830-4421-ab09-a196d0cd7a66.json
# 4454 domain-name--22bfac32-d932-4a40-877b-8ee81f982d36.json
# 4510 domain-name--396a4db9-cb32-49ac-a6f1-0ae6d1487225.json
# 4591 domain-name--049a8766-d18e-4b7c-9997-59c267ad144e.json
# 4595 domain-name--74a235db-9813-4762-bef5-6b8058f3f210.json
# 4598 domain-name--8d771870-f4d6-407f-b2d2-e1f001e86554.json
# 4652 domain-name--e79ca967-df1a-45b5-b707-d59df8db2c33.json
# 4701 domain-name--93de5635-7d1f-4324-be4e-844df02f4225.json
# 4702 domain-name--838410b7-a9bc-4f91-8b3b-e07f00c5a6bc.json
# 4704 domain-name--ce294018-ef29-43d3-8b71-155263661fd8.json
# 4735 domain-name--bf91935a-8d99-454d-9f22-2c38f5e2a156.json
# 4764 domain-name--bf5cdde0-9efc-4d01-a1ac-99a4cd17a534.json
# 4809 domain-name--54600bf5-8c10-4c02-917e-014c05eda5ef.json
# 4818 domain-name--92ccf73a-43f0-4eed-abbf-3398d43b0b37.json
# 4885 domain-name--58005872-de43-471d-a9b5-556f38d0ce9a.json
# 4897 domain-name--2d6cf661-9fa9-4759-aa4f-6867eba1659d.json
# 4910 domain-name--91b54ad4-51d4-486c-b6a2-0ebd1019caf7.json

# %%
for i in range(len(processed_preds4eval)):
    print(f"Predicted: {processed_preds4eval[i]}")
    print(f"Actual: {outputs[i]}")
    print("\n\n")
# Out:
# Predicted: {'objects': [{'id': 'domain-name--domain-voipfaqs.com', 'type': 'domain-name', 'value': 'voipfaqs.com'}, {'id': 'domain-name--domain-teamsbusiness.org', 'type': 'domain-name', 'value': 'teamsbusiness.org'}, {'id': 'domain-name--domain-locallyhyped.com', 'type': 'domain-name', 'value': 'locallyhyped.com'}]}
# Actual: {'objects': [{'id': 'domain-name--teamsbusiness.org', 'type': 'domain-name', 'value': 'teamsbusiness.org'}, {'id': 'domain-name--voipfaqs.com', 'type': 'domain-name', 'value': 'voipfaqs.com'}, {'id': 'domain-name--locallyhyped.com', 'type': 'domain-name', 'value': 'locallyhyped.com'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain-voipfaqs.com', 'type': 'domain-name', 'value': 'voipfaqs.com'}, {'id': 'domain-name--domain-teamsbusiness.org', 'type': 'domain-name', 'value': 'teamsbusiness.org'}, {'id': 'domain-name--domain-locallyhyped.com', 'type': 'domain-name', 'value': 'locallyhyped.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--linux.down-flash.com', 'type': 'domain-name', 'value': 'linux.down-flash.com'}, {'id': 'domain-name--domain--chrome.down-flash.com', 'type': 'domain-name', 'value': 'chrome.down-flash.com'}, {'id': 'domain-name--domain--cdn.google-au.ga', 'type': 'domain-name', 'value': 'cdn.google-au.ga'}, {'id': 'domain-name--domain--fonts.google-au.ga', 'type': 'domain-name', 'value': 'fonts.google-au.ga'}, {'id': 'domain-name--domain--static.tcplog.com', 'type': 'domain-name', 'value': 'static.tcplog.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--cv-builder.site', 'type': 'domain-name', 'value': 'cv-builder.site'}, {'id': 'domain-name--domain--siamaster.com.mx', 'type': 'domain-name', 'value': 'siamaster.com.mx'}, {'id': 'domain-name--domain--chatgptex.us', 'type': 'domain-name', 'value': 'chatgptex.us'}, {'id': 'domain-name--domain--allfreesoftware.online', 'type': 'domain-name', 'value': 'allfreesoftware.online'}, {'id': 'domain-name--domain--all-free-software.online', 'type': 'domain-name', 'value': 'all-free-software.online'}]}
# Actual: {'objects': [{'id': 'domain-name--siamaster.com.mx', 'type': 'domain-name', 'value': 'siamaster.com.mx'}, {'id': 'domain-name--cv-builder.site', 'type': 'domain-name', 'value': 'cv-builder.site'}, {'id': 'domain-name--chatgptex.us', 'type': 'domain-name', 'value': 'chatgptex.us'}, {'id': 'domain-name--allfreesoftware.online', 'type': 'domain-name', 'value': 'allfreesoftware.online'}, {'id': 'domain-name--all-free-software.online', 'type': 'domain-name', 'value': 'all-free-software.online'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--vndjgheruewy1.com', 'type': 'domain-name', 'value': 'vndjgheruewy1.com'}]}
# Actual: {'objects': [{'id': 'domain-name--vndjgheruewy1.com', 'type': 'domain-name', 'value': 'vndjgheruewy1.com'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--vndjgheruewy1.com', 'type': 'domain-name', 'value': 'vndjgheruewy1.com'}]}
# Actual: {'objects': [{'id': 'domain-name--telemetrysystemcollection.com', 'type': 'domain-name', 'value': 'telemetrysystemcollection.com'}, {'id': 'domain-name--extic.icu', 'type': 'domain-name', 'value': 'extic.icu'}, {'id': 'domain-name--reykh.icu', 'type': 'domain-name', 'value': 'reykh.icu'}, {'id': 'domain-name--collectiontelemetrysystem.com', 'type': 'domain-name', 'value': 'collectiontelemetrysystem.com'}]}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--belfaro.com.br', 'type': 'domain-name', 'value': 'belfaro.com.br'}, {'id': 'domain-name--domain--freedynamicdns.org', 'type': 'domain-name', 'value': 'freedynamicdns.org'}]}
# Actual: {'objects': [{'id': 'domain-name--freedynamicdns.org', 'type': 'domain-name', 'value': 'freedynamicdns.org'}, {'id': 'domain-name--belfaro.com.br', 'type': 'domain-name', 'value': 'belfaro.com.br'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--severdops.ddns.net', 'type': 'domain-name', 'value': 'severdops.ddns.net'}, {'id': 'domain-name--domain--nasyiahgamping.com', 'type': 'domain-name', 'value': 'nasyiahgamping.com'}]}
# Actual: {'objects': [{'id': 'domain-name--nasyiahgamping.com', 'type': 'domain-name', 'value': 'nasyiahgamping.com'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--severdops.ddns.net', 'type': 'domain-name', 'value': 'severdops.ddns.net'}, {'id': 'domain-name--domain--nasyiahgamping.com', 'type': 'domain-name', 'value': 'nasyiahgamping.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--papiculo.net', 'type': 'domain-name', 'value': 'papiculo.net'}, {'id': 'domain-name--domain--gitlab.com', 'type': 'domain-name', 'value': 'gitlab.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--cakeserver.online', 'type': 'domain-name', 'value': 'cakeserver.online'}, {'id': 'domain-name--domain--mestoxcalculator.com', 'type': 'domain-name', 'value': 'mestoxcalculator.com'}, {'id': 'domain-name--domain--web3protocol.online', 'type': 'domain-name', 'value': 'web3protocol.online'}, {'id': 'domain-name--domain--connectprotocol.app', 'type': 'domain-name', 'value': 'connectprotocol.app'}, {'id': 'domain-name--domain--median.co', 'type': 'domain-name', 'value': 'median.co'}, {'id': 'domain-name--domain--go.cb-w.com', 'type': 'domain-name', 'value': 'go.cb-w.com'}]}
# Actual: {'objects': [{'id': 'domain-name--web3protocol.online', 'type': 'domain-name', 'value': 'web3protocol.online'}, {'id': 'domain-name--mestoxcalculator.com', 'type': 'domain-name', 'value': 'mestoxcalculator.com'}, {'id': 'domain-name--cakeserver.online', 'type': 'domain-name', 'value': 'cakeserver.online'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--ctl.msedeapi.net', 'type': 'domain-name', 'value': 'ctl.msedeapi.net'}, {'id': 'domain-name--domain--cglr0weqq7002.ct1.msedgeapptest.com', 'type': 'domain-name', 'value': 'cglr0weqq7002.ct1.msedgeapptest.com'}, {'id': 'domain-name--domain--msedgeapptest.com', 'type': 'domain-name', 'value': 'msedgeapptest.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--ctl.msedeapi.net', 'type': 'domain-name', 'value': 'ctl.msedeapi.net'}, {'id': 'domain-name--domain--cglr0weqq7002.ct1.msedgeapptest.com', 'type': 'domain-name', 'value': 'cglr0weqq7002.ct1.msedgeapptest.com'}, {'id': 'domain-name--domain--msedgeapptest.com', 'type': 'domain-name', 'value': 'msedgeapptest.com'}]}
# Actual: {'objects': [{'id': 'domain-name--3x55o3u2b7cjs54eifja5m3ottxntlubhjzt6k6htp5nrocjmsxxh7ad.onion', 'type': 'domain-name', 'value': '3x55o3u2b7cjs54eifja5m3ottxntlubhjzt6k6htp5nrocjmsxxh7ad.onion'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--kmobile.bestunif.com', 'type': 'domain-name', 'value': 'kmobile.bestunif.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--ctl.msedeapi.net', 'type': 'domain-name', 'value': 'ctl.msedeapi.net'}, {'id': 'domain-name--domain--cglr0weqq7002.ct1.msedgeapptest.com', 'type': 'domain-name', 'value': 'cglr0weqq7002.ct1.msedgeapptest.com'}, {'id': 'domain-name--domain--msedgeapptest.com', 'type': 'domain-name', 'value': 'msedgeapptest.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--baronrtal.com', 'type': 'domain-name', 'value': 'baronrtal.com'}, {'id': 'domain-name--domain--bunadist.com', 'type': 'domain-name', 'value': 'bunadist.com'}, {'id': 'domain-name--domain--omnimature.com', 'type': 'domain-name', 'value': 'omnimature.com'}, {'id': 'domain-name--domain--vorkinal.com', 'type': 'domain-name', 'value': 'vorkinal.com'}, {'id': 'domain-name--domain--curanao.com', 'type': 'domain-name', 'value': 'curanao.com'}, {'id': 'domain-name--domain--goranism.com', 'type': 'domain-name', 'value': 'goranism.com'}, {'id': 'domain-name--domain--olodaris.com', 'type': 'domain-name', 'value': 'olodaris.com'}, {'id': 'domain-name--domain--xl3hndhptmnegy.appspot.com', 'type': 'domain-name', 'value': 'xl3hndhptmnegy.appspot.com'}, {'id': 'domain-name--domain--pz3ksj5t45tg4t.appspot.com', 'type': 'domain-name', 'value': 'pz3ksj5t45tg4t.appspot.com'}, {'id': 'domain-name--domain--oieqeh1cxwnd81.appspot.com', 'type': 'domain-name', 'value': 'oieqeh1cxwnd81.appspot.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': [{'id': 'domain-name--medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsqyfry4ebnxlcbkccyd.onion', 'type': 'domain-name', 'value': 'medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsqyfry4ebnxlcbkccyd.onion'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--cavoisatthu2023asd.com', 'type': 'domain-name', 'value': 'cavoisatthu2023asd.com'}, {'id': 'domain-name--domain--dauhetdau.com', 'type': 'domain-name', 'value': 'dauhetdau.com'}, {'id': 'domain-name--domain--motdanvoi20232023.com', 'type': 'domain-name', 'value': 'motdanvoi20232023.com'}, {'id': 'domain-name--domain--voiconprivatesv2083.com', 'type': 'domain-name', 'value': 'voiconprivatesv2083.com'}, {'id': 'domain-name--domain--2fa.live', 'type': 'domain-name', 'value': '2fa.live'}]}
# Actual: {'objects': [{'id': 'domain-name--voiconprivatesv2083.com', 'type': 'domain-name', 'value': 'voiconprivatesv2083.com'}, {'id': 'domain-name--motdanvoi20232023.com', 'type': 'domain-name', 'value': 'motdanvoi20232023.com'}, {'id': 'domain-name--dauhetdau.com', 'type': 'domain-name', 'value': 'dauhetdau.com'}, {'id': 'domain-name--cavoisatthu2023asd.com', 'type': 'domain-name', 'value': 'cavoisatthu2023asd.com'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--cavoisatthu2023asd.com', 'type': 'domain-name', 'value': 'cavoisatthu2023asd.com'}, {'id': 'domain-name--domain--dauhetdau.com', 'type': 'domain-name', 'value': 'dauhetdau.com'}, {'id': 'domain-name--domain--motdanvoi20232023.com', 'type': 'domain-name', 'value': 'motdanvoi20232023.com'}, {'id': 'domain-name--domain--voiconprivatesv2083.com', 'type': 'domain-name', 'value': 'voiconprivatesv2083.com'}, {'id': 'domain-name--domain--2fa.live', 'type': 'domain-name', 'value': '2fa.live'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--theconomics.net', 'type': 'domain-name', 'value': 'theconomics.net'}, {'id': 'domain-name--domain--inclusive-economy.com', 'type': 'domain-name', 'value': 'inclusive-economy.com'}, {'id': 'domain-name--domain--healthcaption.com', 'type': 'domain-name', 'value': 'healthcaption.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--theconomics.net', 'type': 'domain-name', 'value': 'theconomics.net'}, {'id': 'domain-name--domain--inclusive-economy.com', 'type': 'domain-name', 'value': 'inclusive-economy.com'}, {'id': 'domain-name--domain--healthcaption.com', 'type': 'domain-name', 'value': 'healthcaption.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--theconomics.net', 'type': 'domain-name', 'value': 'theconomics.net'}, {'id': 'domain-name--domain--inclusive-economy.com', 'type': 'domain-name', 'value': 'inclusive-economy.com'}, {'id': 'domain-name--domain--healthcaption.com', 'type': 'domain-name', 'value': 'healthcaption.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--theconomics.net', 'type': 'domain-name', 'value': 'theconomics.net'}, {'id': 'domain-name--domain--inclusive-economy.com', 'type': 'domain-name', 'value': 'inclusive-economy.com'}, {'id': 'domain-name--domain--healthcaption.com', 'type': 'domain-name', 'value': 'healthcaption.com'}]}
# Actual: {'objects': [{'id': 'domain-name--requestrepo.com', 'type': 'domain-name', 'value': 'requestrepo.com'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--securelist.com', 'type': 'domain-name', 'value': 'securelist.com'}, {'id': 'domain-name--domain--otx.alienvault.com', 'type': 'domain-name', 'value': 'otx.alienvault.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--securelist.com', 'type': 'domain-name', 'value': 'securelist.com'}, {'id': 'domain-name--domain--otx.alienvault.com', 'type': 'domain-name', 'value': 'otx.alienvault.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--securelist.com', 'type': 'domain-name', 'value': 'securelist.com'}, {'id': 'domain-name--domain--otx.alienvault.com', 'type': 'domain-name', 'value': 'otx.alienvault.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--securelist.com', 'type': 'domain-name', 'value': 'securelist.com'}, {'id': 'domain-name--domain--otx.alienvault.com', 'type': 'domain-name', 'value': 'otx.alienvault.com'}]}
# Actual: {'objects': [{'id': 'domain-name--wirexpro.com', 'type': 'domain-name', 'value': 'wirexpro.com'}, {'id': 'domain-name--telloo.io', 'type': 'domain-name', 'value': 'telloo.io'}, {'id': 'domain-name--strainservice.com', 'type': 'domain-name', 'value': 'strainservice.com'}, {'id': 'domain-name--rebelthumb.net', 'type': 'domain-name', 'value': 'rebelthumb.net'}, {'id': 'domain-name--oilycargo.com', 'type': 'domain-name', 'value': 'oilycargo.com'}, {'id': 'domain-name--bloxholder.com', 'type': 'domain-name', 'value': 'bloxholder.com'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--securelist.com', 'type': 'domain-name', 'value': 'securelist.com'}, {'id': 'domain-name--domain--otx.alienvault.com', 'type': 'domain-name', 'value': 'otx.alienvault.com'}]}
# Actual: {'objects': [{'id': 'domain-name--tibetyouthcongress.com', 'type': 'domain-name', 'value': 'tibetyouthcongress.com'}, {'id': 'domain-name--telecomly.info', 'type': 'domain-name', 'value': 'telecomly.info'}, {'id': 'domain-name--t1bet.net', 'type': 'domain-name', 'value': 't1bet.net'}, {'id': 'domain-name--seller-notification.live', 'type': 'domain-name', 'value': 'seller-notification.live'}, {'id': 'domain-name--secure.software', 'type': 'domain-name', 'value': 'secure.software'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--securelist.com', 'type': 'domain-name', 'value': 'securelist.com'}, {'id': 'domain-name--domain--otx.alienvault.com', 'type': 'domain-name', 'value': 'otx.alienvault.com'}]}
# Actual: {'objects': [{'id': 'domain-name--appleplus.shop', 'type': 'domain-name', 'value': 'appleplus.shop'}, {'id': 'domain-name--appleplus.sbs', 'type': 'domain-name', 'value': 'appleplus.sbs'}]}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--api-hw.com', 'type': 'domain-name', 'value': 'api-hw.com'}, {'id': 'domain-name--domain--pastebin.com', 'type': 'domain-name', 'value': 'pastebin.com'}, {'id': 'domain-name--domain--canary.discord.com', 'type': 'domain-name', 'value': 'canary.discord.com'}, {'id': 'domain-name--domain--discord.com', 'type': 'domain-name', 'value': 'discord.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--api-hw.com', 'type': 'domain-name', 'value': 'api-hw.com'}, {'id': 'domain-name--domain--pastebin.com', 'type': 'domain-name', 'value': 'pastebin.com'}, {'id': 'domain-name--domain--canary.discord.com', 'type': 'domain-name', 'value': 'canary.discord.com'}, {'id': 'domain-name--domain--discord.com', 'type': 'domain-name', 'value': 'discord.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--api-hw.com', 'type': 'domain-name', 'value': 'api-hw.com'}, {'id': 'domain-name--domain--pastebin.com', 'type': 'domain-name', 'value': 'pastebin.com'}, {'id': 'domain-name--domain--canary.discord.com', 'type': 'domain-name', 'value': 'canary.discord.com'}, {'id': 'domain-name--domain--discord.com', 'type': 'domain-name', 'value': 'discord.com'}]}
# Actual: {'objects': [{'id': 'domain-name--powersupportplan.com', 'type': 'domain-name', 'value': 'powersupportplan.com'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--api-hw.com', 'type': 'domain-name', 'value': 'api-hw.com'}, {'id': 'domain-name--domain--pastebin.com', 'type': 'domain-name', 'value': 'pastebin.com'}, {'id': 'domain-name--domain--canary.discord.com', 'type': 'domain-name', 'value': 'canary.discord.com'}, {'id': 'domain-name--domain--discord.com', 'type': 'domain-name', 'value': 'discord.com'}]}
# Actual: {'objects': [{'id': 'domain-name--webgoalarm.online', 'type': 'domain-name', 'value': 'webgoalarm.online'}, {'id': 'domain-name--nonbrowm.com', 'type': 'domain-name', 'value': 'nonbrowm.com'}, {'id': 'domain-name--mnksystem.online', 'type': 'domain-name', 'value': 'mnksystem.online'}, {'id': 'domain-name--backmnk.online', 'type': 'domain-name', 'value': 'backmnk.online'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--blender-s.org', 'type': 'domain-name', 'value': 'blender-s.org'}, {'id': 'domain-name--domain--blendersa.org', 'type': 'domain-name', 'value': 'blendersa.org'}, {'id': 'domain-name--domain--blender3dorg.fras6899.odns.fr', 'type': 'domain-name', 'value': 'blender3dorg.fras6899.odns.fr'}]}
# Actual: {'objects': [{'id': 'domain-name--blender-s.org', 'type': 'domain-name', 'value': 'blender-s.org'}, {'id': 'domain-name--blendersa.org', 'type': 'domain-name', 'value': 'blendersa.org'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--access-confirmation.com', 'type': 'domain-name', 'value': 'access-confirmation.com'}, {'id': 'domain-name--domain--allow-access.com', 'type': 'domain-name', 'value': 'allow-access.com'}, {'id': 'domain-name--domain--antibots-service.com', 'type': 'domain-name', 'value': 'antibots-service.com'}, {'id': 'domain-name--domain--blueskynetwork-shared.com', 'type': 'domain-name', 'value': 'blueskynetwork-shared.com'}, {'id': 'domain-name--domain--botguard-checker.com', 'type': 'domain-name', 'value': 'botguard-checker.com'}, {'id': 'domain-name--domain--botguard-web.com', 'type': 'domain-name', 'value': 'botguard-web.com'}, {'id': 'domain-name--domain--challenge-identifier.com', 'type': 'domain-name', 'value': 'challenge-identifier.com'}, {'id': 'domain-name--domain--checker-bot.com', 'type': 'domain-name', 'value': 'checker-bot.com'}, {'id': 'domain-name--domain--cji-docs.com', 'type': 'domain-name', 'value': 'cija-docs.com'}, {'id': 'domain-name--domain--cloud-safety.online', 'type': 'domain-name', 'value': 'cloud-safety.online'}, {'id': 'domain-name--domain--cloud-us.online', 'type': 'domain-name', 'value': 'cloud-us.online'}, {'id': 'domain-name--domain--dns-cache.online', 'type': 'domain-name', 'value': 'dns-cache.online'}, {'id': 'domain-name--domain--dns-cookie.com', 'type': 'domain-name', 'value': 'dns-cookie.com'}, {'id': 'domain-name--domain--dns-mvd.ru', 'type': 'domain-name', 'value': 'dns-mvd.ru'}, {'id': 'domain-name--domain--docs-web.online', 'type': 'domain-name', 'value': 'docs-web.online'}, {'id': 'domain-name--domain--drive-control.com', 'type': 'domain-name', 'value': 'drive-control.com'}, {'id': 'domain-name--domain--drive-globalordnance.com', 'type': 'domain-name', 'value': 'drive-globalordnance.com'}, {'id': 'domain-name--domain--drive-previewer.com', 'type': 'domain-name', 'value': 'drive-previewer.com'}, {'id': 'domain-name--domain--drive-us.online', 'type': 'domain-name', 'value': 'drive-us.online'}, {'id': 'domain-name--domain--dtgruelle-drive.com', 'type': 'domain-name', 'value': 'dtgruelle-drive.com'}, {'id': 'domain-name--domain--dtgruelle-us.com', 'type': 'domain-name', 'value': 'dtgruelle-us.com'}, {'id': 'domain-name--domain--encompass-shared.com', 'type': 'domain-name', 'value': 'encompass-shared.com'}, {'id': 'domain-name--domain--filter-bot.com', 'type': 'domain-name', 'value': 'filter-bot.com'}, {'id': 'domain-name--domain--goweb-protect.com', 'type': 'domain-name', 'value': 'goweb-protect.com'}, {'id': 'domain-name--domain--guard-checker.com', 'type': 'domain-name', 'value': 'guard-checker.com'}, {'id': 'domain-name--domain--land-of-service.com', 'type': 'domain-name', 'value': 'land-of-service.com'}, {'id': 'domain-name--domain--live-identifier.com', 'type': 'domain-name', 'value': 'live-identifier.com'}, {'id': 'domain-name--domain--mvd-redir.ru', 'type': 'domain-name', 'value': 'mvd-redir.ru'}, {'id': 'domain-name--domain--network-storage-ltd.com', 'type': 'domain-name', 'value': 'network-storage-ltd.com'}, {'id': 'domain-name--domain--nonviolent-conflict-service.com', 'type': 'domain-name', 'value': 'nonviolent-conflict-service.com'}, {'id': 'domain-name--domain--proxycrioisolation.com', 'type': 'domain-name', 'value': 'proxycrioisolation.com'}, {'id': 'domain-name--domain--redir-document.com', 'type': 'domain-name', 'value': 'redir-document.com'}, {'id': 'domain-name--domain--response-filter.com', 'type': 'domain-name', 'value': 'response-filter.com'}, {'id': 'domain-name--domain--response-redir.com', 'type': 'domain-name', 'value': 'response-redir.com'}, {'id': 'domain-name--domain--sangrail-share.com', 'type': 'domain-name', 'value': 'sangrail-share.com'}, {'id': 'domain-name--domain--share-drive-ua.com', 'type': 'domain-name', 'value': 'share-drive-ua.com'}, {'id': 'domain-name--domain--transfer-record.com', 'type': 'domain-name', 'value': 'transfer-record.com'}, {'id': 'domain-name--domain--umopl-drive.com', 'type': 'domain-name', 'val ...
# Actual: {'objects': [{'id': 'domain-name--umopl-drive.com', 'type': 'domain-name', 'value': 'umopl-drive.com'}, {'id': 'domain-name--transfer-record.com', 'type': 'domain-name', 'value': 'transfer-record.com'}, {'id': 'domain-name--sangrail-share.com', 'type': 'domain-name', 'value': 'sangrail-share.com'}, {'id': 'domain-name--share-drive-ua.com', 'type': 'domain-name', 'value': 'share-drive-ua.com'}, {'id': 'domain-name--response-redir.com', 'type': 'domain-name', 'value': 'response-redir.com'}, {'id': 'domain-name--response-filter.com', 'type': 'domain-name', 'value': 'response-filter.com'}, {'id': 'domain-name--redir-document.com', 'type': 'domain-name', 'value': 'redir-document.com'}, {'id': 'domain-name--proxycrioisolation.com', 'type': 'domain-name', 'value': 'proxycrioisolation.com'}, {'id': 'domain-name--nonviolent-conflict-service.com', 'type': 'domain-name', 'value': 'nonviolent-conflict-service.com'}, {'id': 'domain-name--network-storage-ltd.com', 'type': 'domain-name', 'value': 'network-storage-ltd.com'}, {'id': 'domain-name--mvd-redir.ru', 'type': 'domain-name', 'value': 'mvd-redir.ru'}, {'id': 'domain-name--land-of-service.com', 'type': 'domain-name', 'value': 'land-of-service.com'}, {'id': 'domain-name--live-identifier.com', 'type': 'domain-name', 'value': 'live-identifier.com'}, {'id': 'domain-name--guard-checker.com', 'type': 'domain-name', 'value': 'guard-checker.com'}, {'id': 'domain-name--goweb-protect.com', 'type': 'domain-name', 'value': 'goweb-protect.com'}, {'id': 'domain-name--filter-bot.com', 'type': 'domain-name', 'value': 'filter-bot.com'}, {'id': 'domain-name--dtgruelle-us.com', 'type': 'domain-name', 'value': 'dtgruelle-us.com'}, {'id': 'domain-name--encompass-shared.com', 'type': 'domain-name', 'value': 'encompass-shared.com'}, {'id': 'domain-name--drive-previewer.com', 'type': 'domain-name', 'value': 'drive-previewer.com'}, {'id': 'domain-name--drive-us.online', 'type': 'domain-name', 'value': 'drive-us.online'}, {'id': 'domain-name--dtgruelle-drive.com', 'type': 'domain-name', 'value': 'dtgruelle-drive.com'}, {'id': 'domain-name--drive-globalordnance.com', 'type': 'domain-name', 'value': 'drive-globalordnance.com'}, {'id': 'domain-name--drive-control.com', 'type': 'domain-name', 'value': 'drive-control.com'}, {'id': 'domain-name--docs-web.online', 'type': 'domain-name', 'value': 'docs-web.online'}, {'id': 'domain-name--dns-cookie.com', 'type': 'domain-name', 'value': 'dns-cookie.com'}, {'id': 'domain-name--dns-mvd.ru', 'type': 'domain-name', 'value': 'dns-mvd.ru'}, {'id': 'domain-name--dns-cache.online', 'type': 'domain-name', 'value': 'dns-cache.online'}, {'id': 'domain-name--cloud-safety.online', 'type': 'domain-name', 'value': 'cloud-safety.online'}, {'id': 'domain-name--cloud-us.online', 'type': 'domain-name', 'value': 'cloud-us.online'}, {'id': 'domain-name--checker-bot.com', 'type': 'domain-name', 'value': 'checker-bot.com'}, {'id': 'domain-name--cija-docs.com', 'type': 'domain-name', 'value': 'cija-docs.com'}, {'id': 'domain-name--challenge-identifier.com', 'type': 'domain-name', 'value': 'challenge-identifier.com'}, {'id': 'domain-name--botguard-web.com', 'type': 'domain-name', 'value': 'botguard-web.com'}, {'id': 'domain-name--botguard-checker.com', 'type': 'domain-name', 'value': 'botguard-checker.com'}, {'id': 'domain-name--blueskynetwork-shared.com', 'type': 'domain-name', 'value': 'blueskynetwork-shared.com'}, {'id': 'domain-name--access-confirmation.com', 'type': 'domain-name', 'value': 'access-confirmation.com'}, {'id': 'domain-name--allow-access.com', 'type': 'domain-name', 'value': 'allow-access.com'}, {'id': 'domain-name--antibots-service.com', 'type': 'domain-name', 'value': 'antibots-service.com'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--bobocam365.icu', 'type': 'domain-name', 'value': 'bobocam365.icu'}, {'id': 'domain-name--domain--refundkorea.cyou', 'type': 'domain-name', 'value': 'refundkorea.cyou'}]}
# Actual: {'objects': [{'id': 'domain-name--refundkorea.cyou', 'type': 'domain-name', 'value': 'refundkorea.cyou'}, {'id': 'domain-name--bobocam365.icu', 'type': 'domain-name', 'value': 'bobocam365.icu'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--bobocam365.icu', 'type': 'domain-name', 'value': 'bobocam365.icu'}, {'id': 'domain-name--domain--refundkorea.cyou', 'type': 'domain-name', 'value': 'refundkorea.cyou'}]}
# Actual: {'objects': [{'id': 'domain-name--wuriye.com', 'type': 'domain-name', 'value': 'wuriye.com'}, {'id': 'domain-name--wilandsabim.info', 'type': 'domain-name', 'value': 'wilandsabim.info'}, {'id': 'domain-name--unicredibank.top', 'type': 'domain-name', 'value': 'unicredibank.top'}, {'id': 'domain-name--unicrebitdank.top', 'type': 'domain-name', 'value': 'unicrebitdank.top'}, {'id': 'domain-name--ttlpcs.lat', 'type': 'domain-name', 'value': 'ttlpcs.lat'}, {'id': 'domain-name--sharepoint2024.one', 'type': 'domain-name', 'value': 'sharepoint2024.one'}, {'id': 'domain-name--sapconcur.top', 'type': 'domain-name', 'value': 'sapconcur.top'}, {'id': 'domain-name--sapconcur.one', 'type': 'domain-name', 'value': 'sapconcur.one'}, {'id': 'domain-name--sapconcur.team', 'type': 'domain-name', 'value': 'sapconcur.team'}, {'id': 'domain-name--otpdank24.top', 'type': 'domain-name', 'value': 'otpdank24.top'}, {'id': 'domain-name--ms-antispam.live', 'type': 'domain-name', 'value': 'ms-antispam.live'}, {'id': 'domain-name--meet-goo.org', 'type': 'domain-name', 'value': 'meet-goo.org'}, {'id': 'domain-name--miles-and-mroe.com', 'type': 'domain-name', 'value': 'miles-and-mroe.com'}, {'id': 'domain-name--meet2024.com', 'type': 'domain-name', 'value': 'meet2024.com'}, {'id': 'domain-name--meet-goo.net', 'type': 'domain-name', 'value': 'meet-goo.net'}, {'id': 'domain-name--meet-gl.com', 'type': 'domain-name', 'value': 'meet-gl.com'}, {'id': 'domain-name--lexisnexis.top', 'type': 'domain-name', 'value': 'lexisnexis.top'}, {'id': 'domain-name--lexisnexis.lat', 'type': 'domain-name', 'value': 'lexisnexis.lat'}, {'id': 'domain-name--lexisnexis.pro', 'type': 'domain-name', 'value': 'lexisnexis.pro'}, {'id': 'domain-name--lexisnexis.one', 'type': 'domain-name', 'value': 'lexisnexis.one'}, {'id': 'domain-name--lexisnex.pro', 'type': 'domain-name', 'value': 'lexisnex.pro'}, {'id': 'domain-name--lexisnex.top', 'type': 'domain-name', 'value': 'lexisnex.top'}, {'id': 'domain-name--lexisnex.team', 'type': 'domain-name', 'value': 'lexisnex.team'}, {'id': 'domain-name--lexis2024.pro', 'type': 'domain-name', 'value': 'lexis2024.pro'}, {'id': 'domain-name--law360.one', 'type': 'domain-name', 'value': 'law360.one'}, {'id': 'domain-name--lexis2024.info', 'type': 'domain-name', 'value': 'lexis2024.info'}, {'id': 'domain-name--law2024.top', 'type': 'domain-name', 'value': 'law2024.top'}, {'id': 'domain-name--law2024.info', 'type': 'domain-name', 'value': 'law2024.info'}, {'id': 'domain-name--gogogononono.xyz', 'type': 'domain-name', 'value': 'gogogononono.xyz'}, {'id': 'domain-name--gogogononono.top', 'type': 'domain-name', 'value': 'gogogononono.top'}, {'id': 'domain-name--gogogogogotests.xyz', 'type': 'domain-name', 'value': 'gogogogogotests.xyz'}, {'id': 'domain-name--gl-meet2024.com', 'type': 'domain-name', 'value': 'gl-meet2024.com'}, {'id': 'domain-name--edankhk.top', 'type': 'domain-name', 'value': 'edankhk.top'}, {'id': 'domain-name--dr1v3.top', 'type': 'domain-name', 'value': 'dr1v3.top'}, {'id': 'domain-name--dr1v3.one', 'type': 'domain-name', 'value': 'dr1v3.one'}, {'id': 'domain-name--dhlpost.sbs', 'type': 'domain-name', 'value': 'dhlpost.sbs'}, {'id': 'domain-name--dhlpost.nl', 'type': 'domain-name', 'value': 'dhlpost.nl'}, {'id': 'domain-name--dhlpost.lat', 'type': 'domain-name', 'value': 'dhlpost.lat'}, {'id': 'domain-name--clio2024.top', 'type': 'domain-name', 'value': 'clio2024.top'}, {'id': 'domain-name--clio2024.one', 'type': 'domain-name', 'value': 'clio2024.one'}, {'id': 'domain-name--clio2024.info', 'type': 'domain-name', 'value': 'clio2024.info'}, {'id': 'domain-name--clio.pw', 'type': 'domain-name', 'value': 'clio.pw'}, {'id': 'domain-name--clio.lat', 'type': 'domain-name', 'value': 'clio.lat'}, {'id': 'domain-name--blackrock-alladin.pro', 'type': 'domain-name', 'value': 'blackrock-alladin.pro'}, {'id': 'domain-name--ariba.lat', 'type': 'domain-name', 'value': 'ariba.lat'}, {'id': 'domain-name--antispam-ms.pro', 'type': 'domain-name', 'value ...
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--bobocam365.icu', 'type': 'domain-name', 'value': 'bobocam365.icu'}, {'id': 'domain-name--domain--refundkorea.cyou', 'type': 'domain-name', 'value': 'refundkorea.cyou'}]}
# Actual: {'objects': [{'id': 'domain-name--jilinebyli.top', 'type': 'domain-name', 'value': 'jilinebyli.top'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--bobocam365.icu', 'type': 'domain-name', 'value': 'bobocam365.icu'}, {'id': 'domain-name--domain--refundkorea.cyou', 'type': 'domain-name', 'value': 'refundkorea.cyou'}]}
# Actual: {'objects': [{'id': 'domain-name--vilnius-summit.lt', 'type': 'domain-name', 'value': 'vilnius-summit.lt'}, {'id': 'domain-name--viilnius.lt', 'type': 'domain-name', 'value': 'viilnius.lt'}, {'id': 'domain-name--urm-lt.com', 'type': 'domain-name', 'value': 'urm-lt.com'}, {'id': 'domain-name--te-storg.com', 'type': 'domain-name', 'value': 'te-storg.com'}, {'id': 'domain-name--sso-log.com', 'type': 'domain-name', 'value': 'sso-log.com'}, {'id': 'domain-name--socialistii.com', 'type': 'domain-name', 'value': 'socialistii.com'}, {'id': 'domain-name--socialisti.md', 'type': 'domain-name', 'value': 'socialisti.md'}, {'id': 'domain-name--social-moldova.md', 'type': 'domain-name', 'value': 'social-moldova.md'}, {'id': 'domain-name--sapsap.site', 'type': 'domain-name', 'value': 'sapsap.site'}, {'id': 'domain-name--pass-check.online', 'type': 'domain-name', 'value': 'pass-check.online'}, {'id': 'domain-name--otllook.com', 'type': 'domain-name', 'value': 'otllook.com'}, {'id': 'domain-name--noname05716.ru', 'type': 'domain-name', 'value': 'noname05716.ru'}, {'id': 'domain-name--nnmnnm.ru', 'type': 'domain-name', 'value': 'nnmnnm.ru'}, {'id': 'domain-name--nask-pl.com', 'type': 'domain-name', 'value': 'nask-pl.com'}, {'id': 'domain-name--moldova-social.md', 'type': 'domain-name', 'value': 'moldova-social.md'}, {'id': 'domain-name--moldova-mediu.md', 'type': 'domain-name', 'value': 'moldova-mediu.md'}, {'id': 'domain-name--moldova-energie.md', 'type': 'domain-name', 'value': 'moldova-energie.md'}, {'id': 'domain-name--mec-gov.md', 'type': 'domain-name', 'value': 'mec-gov.md'}, {'id': 'domain-name--md-mec.com', 'type': 'domain-name', 'value': 'md-mec.com'}, {'id': 'domain-name--mcgov.md', 'type': 'domain-name', 'value': 'mcgov.md'}, {'id': 'domain-name--mc-md.com', 'type': 'domain-name', 'value': 'mc-md.com'}, {'id': 'domain-name--mailos.ru', 'type': 'domain-name', 'value': 'mailos.ru'}, {'id': 'domain-name--mailorun.su', 'type': 'domain-name', 'value': 'mailorun.su'}, {'id': 'domain-name--mailgon.online', 'type': 'domain-name', 'value': 'mailgon.online'}, {'id': 'domain-name--litexpo-portal.lt', 'type': 'domain-name', 'value': 'litexpo-portal.lt'}, {'id': 'domain-name--ivention.pl', 'type': 'domain-name', 'value': 'ivention.pl'}, {'id': 'domain-name--isw-org.pl', 'type': 'domain-name', 'value': 'isw-org.pl'}, {'id': 'domain-name--gov-md.com', 'type': 'domain-name', 'value': 'gov-md.com'}, {'id': 'domain-name--interior-gov.es', 'type': 'domain-name', 'value': 'interior-gov.es'}, {'id': 'domain-name--golebewski.pl', 'type': 'domain-name', 'value': 'golebewski.pl'}, {'id': 'domain-name--freepresunlimited.org', 'type': 'domain-name', 'value': 'freepresunlimited.org'}, {'id': 'domain-name--europa.study', 'type': 'domain-name', 'value': 'europa.study'}, {'id': 'domain-name--europa.social', 'type': 'domain-name', 'value': 'europa.social'}, {'id': 'domain-name--europa-eppo.eu', 'type': 'domain-name', 'value': 'europa-eppo.eu'}, {'id': 'domain-name--europa-ec.eu', 'type': 'domain-name', 'value': 'europa-ec.eu'}, {'id': 'domain-name--eupm-moldova.md', 'type': 'domain-name', 'value': 'eupm-moldova.md'}, {'id': 'domain-name--energie-gov.md', 'type': 'domain-name', 'value': 'energie-gov.md'}, {'id': 'domain-name--comunidad-madrid.es', 'type': 'domain-name', 'value': 'comunidad-madrid.es'}, {'id': 'domain-name--comunicacion-presidencia-gov.es', 'type': 'domain-name', 'value': 'comunicacion-presidencia-gov.es'}, {'id': 'domain-name--cert-pl.pl', 'type': 'domain-name', 'value': 'cert-pl.pl'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--gofile.io', 'type': 'domain-name', 'value': 'gofile.io'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--gofile.io', 'type': 'domain-name', 'value': 'gofile.io'}]}
# Actual: {'objects': [{'id': 'domain-name--sanchaar.net', 'type': 'domain-name', 'value': 'sanchaar.net'}, {'id': 'domain-name--newsinlevel.cc', 'type': 'domain-name', 'value': 'newsinlevel.cc'}, {'id': 'domain-name--asistechs.com', 'type': 'domain-name', 'value': 'asistechs.com'}, {'id': 'domain-name--wooofi.com', 'type': 'domain-name', 'value': 'wooofi.com'}, {'id': 'domain-name--slackforbusiness.net', 'type': 'domain-name', 'value': 'slackforbusiness.net'}, {'id': 'domain-name--nextnovatech.com', 'type': 'domain-name', 'value': 'nextnovatech.com'}, {'id': 'domain-name--macpaw.us', 'type': 'domain-name', 'value': 'macpaw.us'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--download.studymathlive.com', 'type': 'domain-name', 'value': 'download.studymathlive.com'}, {'id': 'domain-name--domain--iplogger.org', 'type': 'domain-name', 'value': 'iplogger.org'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--netskope.com', 'type': 'domain-name', 'value': 'netskope.com'}, {'id': 'domain-name--domain--otx.alienvault.com', 'type': 'domain-name', 'value': 'otx.alienvault.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--netskope.com', 'type': 'domain-name', 'value': 'netskope.com'}, {'id': 'domain-name--domain--otx.alienvault.com', 'type': 'domain-name', 'value': 'otx.alienvault.com'}]}
# Actual: {'objects': [{'id': 'domain-name--tmpfiles.org', 'type': 'domain-name', 'value': 'tmpfiles.org'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--cppcccare.com', 'type': 'domain-name', 'value': 'cppcccare.com'}, {'id': 'domain-name--domain--ftp.cppcccare.com', 'type': 'domain-name', 'value': 'ftp.cppcccare.com'}]}
# Actual: {'objects': [{'id': 'domain-name--cppcccare.com', 'type': 'domain-name', 'value': 'cppcccare.com'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--cppcccare.com', 'type': 'domain-name', 'value': 'cppcccare.com'}, {'id': 'domain-name--domain--ftp.cppcccare.com', 'type': 'domain-name', 'value': 'ftp.cppcccare.com'}]}
# Actual: {'objects': [{'id': 'domain-name--7oukjxwkbnwyg7cekudzp66okrchbuubde2j3h6fkpis6izywoj2eqad.onion', 'type': 'domain-name', 'value': '7oukjxwkbnwyg7cekudzp66okrchbuubde2j3h6fkpis6izywoj2eqad.onion'}]}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--tavangyl.com', 'type': 'domain-name', 'value': 'tavangyl.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--krakenfiles.com', 'type': 'domain-name', 'value': 'krakenfiles.com'}, {'id': 'domain-name--domain--send.cm', 'type': 'domain-name', 'value': 'send.cm'}, {'id': 'domain-name--domain--easybytez.com', 'type': 'domain-name', 'value': 'easybytez.com'}, {'id': 'domain-name--domain--easyupload.io', 'type': 'domain-name', 'value': 'easyupload.io'}, {'id': 'domain-name--domain--wetransfer.com', 'type': 'domain-name', 'value': 'wetransfer.com'}, {'id': 'domain-name--domain--www.mediafire.com', 'type': 'domain-name', 'value': 'www.mediafire.com'}, {'id': 'domain-name--domain--51-83-136-132.xyz', 'type': 'domain-name', 'value': '51-83-136-132.xyz'}, {'id': 'domain-name--domain--s1-filecr.xyz', 'type': 'domain-name', 'value': 's1-filecr.xyz'}, {'id': 'domain-name--domain--dynsys.is-a-guru.com', 'type': 'domain-name', 'value': 'dynsys.is-a-guru.com'}, {'id': 'domain-name--domain--fon1.sells-it.net', 'type': 'domain-name', 'value': 'fon1.sells-it.net'}, {'id': 'domain-name--domain--foxn1.sells-it.net', 'type': 'domain-name', 'value': 'foxn1.sells-it.net'}, {'id': 'domain-name--domain--rec.casacam.net', 'type': 'domain-name', 'value': 'rec.casacam.net'}, {'id': 'domain-name--domain--samaerx.ddnsfree.com', 'type': 'domain-name', 'value': 'samaerx.ddnsfree.com'}, {'id': 'domain-name--domain--srxy123.is-a-geek.com', 'type': 'domain-name', 'value': 'srxy123.is-a-geek.com'}, {'id': 'domain-name--domain--websites.theworkpc.com', 'type': 'domain-name', 'value': 'websites.theworkpc.com'}]}
# Actual: {'objects': [{'id': 'domain-name--51-83-136-132.xyz', 'type': 'domain-name', 'value': '51-83-136-132.xyz'}, {'id': 'domain-name--s1-filecr.xyz', 'type': 'domain-name', 'value': 's1-filecr.xyz'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--krakenfiles.com', 'type': 'domain-name', 'value': 'krakenfiles.com'}, {'id': 'domain-name--domain--send.cm', 'type': 'domain-name', 'value': 'send.cm'}, {'id': 'domain-name--domain--easybytez.com', 'type': 'domain-name', 'value': 'easybytez.com'}, {'id': 'domain-name--domain--easyupload.io', 'type': 'domain-name', 'value': 'easyupload.io'}, {'id': 'domain-name--domain--wetransfer.com', 'type': 'domain-name', 'value': 'wetransfer.com'}, {'id': 'domain-name--domain--www.mediafire.com', 'type': 'domain-name', 'value': 'www.mediafire.com'}, {'id': 'domain-name--domain--51-83-136-132.xyz', 'type': 'domain-name', 'value': '51-83-136-132.xyz'}, {'id': 'domain-name--domain--s1-filecr.xyz', 'type': 'domain-name', 'value': 's1-filecr.xyz'}, {'id': 'domain-name--domain--dynsys.is-a-guru.com', 'type': 'domain-name', 'value': 'dynsys.is-a-guru.com'}, {'id': 'domain-name--domain--fon1.sells-it.net', 'type': 'domain-name', 'value': 'fon1.sells-it.net'}, {'id': 'domain-name--domain--foxn1.sells-it.net', 'type': 'domain-name', 'value': 'foxn1.sells-it.net'}, {'id': 'domain-name--domain--rec.casacam.net', 'type': 'domain-name', 'value': 'rec.casacam.net'}, {'id': 'domain-name--domain--samaerx.ddnsfree.com', 'type': 'domain-name', 'value': 'samaerx.ddnsfree.com'}, {'id': 'domain-name--domain--srxy123.is-a-geek.com', 'type': 'domain-name', 'value': 'srxy123.is-a-geek.com'}, {'id': 'domain-name--domain--websites.theworkpc.com', 'type': 'domain-name', 'value': 'websites.theworkpc.com'}]}
# Actual: {'objects': [{'id': 'domain-name--ssq4zimieeanazkzc5ld4v5hdibi2nzwzdibfh5n5w4pw5mcik76lzyd.onion', 'type': 'domain-name', 'value': 'ssq4zimieeanazkzc5ld4v5hdibi2nzwzdibfh5n5w4pw5mcik76lzyd.onion'}, {'id': 'domain-name--gunyhng6pabzcurl7ipx2pbmjxpvqnu6mxf2h3vdeenam34inj4ndryd.onion', 'type': 'domain-name', 'value': 'gunyhng6pabzcurl7ipx2pbmjxpvqnu6mxf2h3vdeenam34inj4ndryd.onion'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--content.dropboxapi.com', 'type': 'domain-name', 'value': 'content.dropboxapi.com'}, {'id': 'domain-name--domain--www.googleapis.com', 'type': 'domain-name', 'value': 'www.googleapis.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': [{'id': 'domain-name--theshirtsummit.com', 'type': 'domain-name', 'value': 'theshirtsummit.com'}, {'id': 'domain-name--propertynear.co.uk', 'type': 'domain-name', 'value': 'propertynear.co.uk'}, {'id': 'domain-name--rosewoodlaminates.com', 'type': 'domain-name', 'value': 'rosewoodlaminates.com'}, {'id': 'domain-name--kmphi.com', 'type': 'domain-name', 'value': 'kmphi.com'}, {'id': 'domain-name--graficalevi.com.br', 'type': 'domain-name', 'value': 'graficalevi.com.br'}, {'id': 'domain-name--cica.com.co', 'type': 'domain-name', 'value': 'cica.com.co'}, {'id': 'domain-name--chimpcity.com', 'type': 'domain-name', 'value': 'chimpcity.com'}, {'id': 'domain-name--centerkick.com', 'type': 'domain-name', 'value': 'centerkick.com'}, {'id': 'domain-name--capitalperurrhh.com', 'type': 'domain-name', 'value': 'capitalperurrhh.com'}, {'id': 'domain-name--abhishekmeena.in', 'type': 'domain-name', 'value': 'abhishekmeena.in'}, {'id': 'domain-name--agtendelperu.com', 'type': 'domain-name', 'value': 'agtendelperu.com'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--otx.alienvault.com', 'type': 'domain-name', 'value': 'otx.alienvault.com'}, {'id': 'domain-name--domain--blog.sonicwall.com', 'type': 'domain-name', 'value': 'blog.sonicwall.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': [{'id': 'domain-name--userfeedsync.com', 'type': 'domain-name', 'value': 'userfeedsync.com'}, {'id': 'domain-name--commonline.space', 'type': 'domain-name', 'value': 'commonline.space'}]}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': [{'id': 'domain-name--rendinfo.shop', 'type': 'domain-name', 'value': 'rendinfo.shop'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--webhook.site', 'type': 'domain-name', 'value': 'webhook.site'}, {'id': 'domain-name--domain--fedko.org', 'type': 'domain-name', 'value': 'fedko.org'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--webhook.site', 'type': 'domain-name', 'value': 'webhook.site'}, {'id': 'domain-name--domain--fedko.org', 'type': 'domain-name', 'value': 'fedko.org'}]}
# Actual: {'objects': [{'id': 'domain-name--advanced-ip-scanners.net', 'type': 'domain-name', 'value': 'advanced-ip-scanners.net'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--360billingservices.com', 'type': 'domain-name', 'value': '360billingservices.com'}, {'id': 'domain-name--domain--aadigital.online', 'type': 'domain-name', 'value': 'aadigital.online'}, {'id': 'domain-name--domain--billmediums.com', 'type': 'domain-name', 'value': 'billmediums.com'}, {'id': 'domain-name--domain--citrexsolutions.co', 'type': 'domain-name', 'value': 'citrexsolutions.co'}, {'id': 'domain-name--domain--digitelcare.com', 'type': 'domain-name', 'value': 'digitelcare.com'}, {'id': 'domain-name--domain--directenergyservice.com', 'type': 'domain-name', 'value': 'directenergyservice.com'}, {'id': 'domain-name--domain--eco-designs.co', 'type': 'domain-name', 'value': 'eco-designs.co'}, {'id': 'domain-name--domain--eco-designs.store', 'type': 'domain-name', 'value': 'eco-designs.store'}, {'id': 'domain-name--domain--economical-deals.co', 'type': 'domain-name', 'value': 'economical-deals.co'}, {'id': 'domain-name--domain--electricenergybundle.com', 'type': 'domain-name', 'value': 'electricenergybundle.com'}, {'id': 'domain-name--domain--electricenergyservice.com', 'type': 'domain-name', 'value': 'electricenergyservice.com'}, {'id': 'domain-name--domain--electricpowerdeal.com', 'type': 'domain-name', 'value': 'electricpowerdeal.com'}, {'id': 'domain-name--domain--energpaybill.com', 'type': 'domain-name', 'value': 'energpaybill.com'}, {'id': 'domain-name--domain--energy.pics', 'type': 'domain-name', 'value': 'energy.pics'}, {'id': 'domain-name--domain--energy-billing.online', 'type': 'domain-name', 'value': 'energy-billing.online'}, {'id': 'domain-name--domain--energybilling.net', 'type': 'domain-name', 'value': 'energybilling.net'}, {'id': 'domain-name--domain--energybillingdepartment.store', 'type': 'domain-name', 'value': 'energybillingdepartment.store'}, {'id': 'domain-name--domain--energybillservice.online', 'type': 'domain-name', 'value': 'energybillservice.online'}, {'id': 'domain-name--domain--energybillsolutions.xyz', 'type': 'domain-name', 'value': 'energybillsolutions.xyz'}, {'id': 'domain-name--domain--energybundledeal.com', 'type': 'domain-name', 'value': 'energybundledeal.com'}, {'id': 'domain-name--domain--energycredits.online', 'type': 'domain-name', 'value': 'energycredits.online'}, {'id': 'domain-name--domain--energyexpertservice.com', 'type': 'domain-name', 'value': 'energyexpertservice.com'}, {'id': 'domain-name--domain--energyhelpcenter.com', 'type': 'domain-name', 'value': 'energyhelpcenter.com'}, {'id': 'domain-name--domain--energypayment.shop', 'type': 'domain-name', 'value': 'energypayment.shop'}, {'id': 'domain-name--domain--energypoweroffer.com', 'type': 'domain-name', 'value': 'energypoweroffer.com'}, {'id': 'domain-name--domain--gabbar-solutions.online', 'type': 'domain-name', 'value': 'gabbar-solutions.online'}, {'id': 'domain-name--domain--globalenergysolutionz.com', 'type': 'domain-name', 'value': 'globalenergysolutionz.com'}, {'id': 'domain-name--domain--globaltechsmc.com', 'type': 'domain-name', 'value': 'globaltechsmc.com'}, {'id': 'domain-name--domain--homeutilityservices.com', 'type': 'domain-name', 'value': 'homeutilityservices.com'}, {'id': 'domain-name--domain--makeabillpayment.com', 'type': 'domain-name', 'value': 'makeabillpayment.com'}, {'id': 'domain-name--domain--paysenergy.online', 'type': 'domain-name', 'value': 'paysenergy.online'}, {'id': 'domain-name--domain--powerelectricoffers.com', 'type': 'domain-name', 'value': 'powerelectricoffers.com'}, {'id': 'domain-name--domain--qasmic.com', 'type': 'domain-name', 'value': 'qasmic.com'}, {'id': 'domain-name--domain--rebornsolutions.co', 'type': 'domain-name', 'value': 'rebornsolutions.co'}, {'id': 'domain-name--domain--telecombilling.us', 'type': 'domain-name', 'value': 'telecombilling.us'}, {'id': 'domain-name--domain--telecomcredits.us', 'type': 'domain-name', 'value': 'telecomcredits.us'}, {'id': 'domain-name--domain--thepowerpayllc.org', 'type': 'domain-name', 'value': 'thepowe ...
# ...
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain-www.activ-ketodietakjsy620.cloud', 'type': 'domain-name', 'value': 'www.activ-ketodietakjsy620.cloud'}, {'id': 'domain-name--domain-www.akrsnamchi.com', 'type': 'domain-name', 'value': 'www.akrsnamchi.com'}, {'id': 'domain-name--domain-www.brioche-amsterdam.com', 'type': 'domain-name', 'value': 'www.brioche-amsterdam.com'}, {'id': 'domain-name--domain-www.corkagenexus.com', 'type': 'domain-name', 'value': 'www.corkagenexus.com'}, {'id': 'domain-name--domain-www.growind.info', 'type': 'domain-name', 'value': 'www.growind.info'}, {'id': 'domain-name--domain-www.hatch.computer', 'type': 'domain-name', 'value': 'www.hatch.computer'}, {'id': 'domain-name--domain-www.kiavisa.com', 'type': 'domain-name', 'value': 'www.kiavisa.com'}, {'id': 'domain-name--domain-www.lushespets.com', 'type': 'domain-name', 'value': 'www.lushespets.com'}, {'id': 'domain-name--domain-www.mommachic.com', 'type': 'domain-name', 'value': 'www.mommachic.com'}, {'id': 'domain-name--domain-www.nationalrecoveryllc.com', 'type': 'domain-name', 'value': 'www.nationalrecoveryllc.com'}, {'id': 'domain-name--domain-www.pinksugarpopmontana.com', 'type': 'domain-name', 'value': 'www.pinksugarpopmontana.com'}, {'id': 'domain-name--domain-www.qhsbobfv.top', 'type': 'domain-name', 'value': 'www.qhsbobfv.top'}, {'id': 'domain-name--domain-www.qq9122.com', 'type': 'domain-name', 'value': 'www.qq9122.com'}, {'id': 'domain-name--domain-www.raveready.shop', 'type': 'domain-name', 'value': 'www.raveready.shop'}, {'id': 'domain-name--domain-www.spv88.online', 'type': 'domain-name', 'value': 'www.spv88.online'}, {'id': 'domain-name--domain-www.switchmerge.com', 'type': 'domain-name', 'value': 'www.switchmerge.com'}]}
# Actual: {'objects': [{'id': 'domain-name--kamisatu.top', 'type': 'domain-name', 'value': 'kamisatu.top'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--e2tika.com', 'type': 'domain-name', 'value': 'e2tika.com'}, {'id': 'domain-name--domain--hornebnew.com', 'type': 'domain-name', 'value': 'hornebnew.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain-zeph.kryptex.network', 'type': 'domain-name', 'value': 'zeph.kryptex.network'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain-zeph.kryptex.network', 'type': 'domain-name', 'value': 'zeph.kryptex.network'}]}
# Actual: {'objects': [{'id': 'domain-name--signalplus.org', 'type': 'domain-name', 'value': 'signalplus.org'}, {'id': 'domain-name--flygram.org', 'type': 'domain-name', 'value': 'flygram.org'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain-zeph.kryptex.network', 'type': 'domain-name', 'value': 'zeph.kryptex.network'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain-zeph.kryptex.network', 'type': 'domain-name', 'value': 'zeph.kryptex.network'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--ingarchi.com', 'type': 'domain-name', 'value': 'ingarchi.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--delphidigital.org', 'type': 'domain-name', 'value': 'delphidigital.org'}]}
# Actual: {'objects': [{'id': 'domain-name--delphidigital.org', 'type': 'domain-name', 'value': 'delphidigital.org'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--delphidigital.org', 'type': 'domain-name', 'value': 'delphidigital.org'}]}
# Actual: {'objects': [{'id': 'domain-name--veast.site', 'type': 'domain-name', 'value': 'veast.site'}, {'id': 'domain-name--tableq.xyz', 'type': 'domain-name', 'value': 'tableq.xyz'}, {'id': 'domain-name--pizz.site', 'type': 'domain-name', 'value': 'pizz.site'}, {'id': 'domain-name--ryderlawns.xyz', 'type': 'domain-name', 'value': 'ryderlawns.xyz'}, {'id': 'domain-name--maydoo.xyz', 'type': 'domain-name', 'value': 'maydoo.xyz'}, {'id': 'domain-name--hesit.xyz', 'type': 'domain-name', 'value': 'hesit.xyz'}, {'id': 'domain-name--atzipfinder.com', 'type': 'domain-name', 'value': 'atzipfinder.com'}, {'id': 'domain-name--ferdo.xyz', 'type': 'domain-name', 'value': 'ferdo.xyz'}, {'id': 'domain-name--amazonsell.pro', 'type': 'domain-name', 'value': 'amazonsell.pro'}, {'id': 'domain-name--amaazoon.org', 'type': 'domain-name', 'value': 'amaazoon.org'}, {'id': 'domain-name--akochar.site', 'type': 'domain-name', 'value': 'akochar.site'}, {'id': 'domain-name--601rajilg.xyz', 'type': 'domain-name', 'value': '601rajilg.xyz'}]}
#
#
#
# Predicted: {'objects': []}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--delphidigital.org', 'type': 'domain-name', 'value': 'delphidigital.org'}]}
# Actual: {'objects': [{'id': 'domain-name--mediacloud.space', 'type': 'domain-name', 'value': 'mediacloud.space'}, {'id': 'domain-name--smartappsfoursix.xyz', 'type': 'domain-name', 'value': 'smartappsfoursix.xyz'}, {'id': 'domain-name--filesindrive.info', 'type': 'domain-name', 'value': 'filesindrive.info'}, {'id': 'domain-name--filecloudservices.xyz', 'type': 'domain-name', 'value': 'filecloudservices.xyz'}, {'id': 'domain-name--edupoliceam.info', 'type': 'domain-name', 'value': 'edupoliceam.info'}, {'id': 'domain-name--avvpassport.info', 'type': 'domain-name', 'value': 'avvpassport.info'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--delphidigital.org', 'type': 'domain-name', 'value': 'delphidigital.org'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--delphidigital.org', 'type': 'domain-name', 'value': 'delphidigital.org'}]}
# Actual: {'objects': [{'id': 'domain-name--yous.ai', 'type': 'domain-name', 'value': 'yous.ai'}, {'id': 'domain-name--wuwelej.top', 'type': 'domain-name', 'value': 'wuwelej.top'}, {'id': 'domain-name--voico.io', 'type': 'domain-name', 'value': 'voico.io'}, {'id': 'domain-name--vinrevildsports.shop', 'type': 'domain-name', 'value': 'vinrevildsports.shop'}, {'id': 'domain-name--tydime.io', 'type': 'domain-name', 'value': 'tydime.io'}, {'id': 'domain-name--tidymeapp.io', 'type': 'domain-name', 'value': 'tidymeapp.io'}, {'id': 'domain-name--tidyme.io', 'type': 'domain-name', 'value': 'tidyme.io'}, {'id': 'domain-name--supme.io', 'type': 'domain-name', 'value': 'supme.io'}, {'id': 'domain-name--sinergijiasport.shop', 'type': 'domain-name', 'value': 'sinergijiasport.shop'}, {'id': 'domain-name--runeonlineworld.io', 'type': 'domain-name', 'value': 'runeonlineworld.io'}, {'id': 'domain-name--refvhnhkkolmjbg.shop', 'type': 'domain-name', 'value': 'refvhnhkkolmjbg.shop'}, {'id': 'domain-name--peerme.io', 'type': 'domain-name', 'value': 'peerme.io'}, {'id': 'domain-name--partyroyaleplay.io', 'type': 'domain-name', 'value': 'partyroyaleplay.io'}, {'id': 'domain-name--partyroyaleplay.com', 'type': 'domain-name', 'value': 'partyroyaleplay.com'}, {'id': 'domain-name--partyroyale.games', 'type': 'domain-name', 'value': 'partyroyale.games'}, {'id': 'domain-name--partyroyale.fun', 'type': 'domain-name', 'value': 'partyroyale.fun'}, {'id': 'domain-name--izxxd.top', 'type': 'domain-name', 'value': 'izxxd.top'}, {'id': 'domain-name--gurunsmilrsports.shop', 'type': 'domain-name', 'value': 'gurunsmilrsports.shop'}, {'id': 'domain-name--edvhukkkmvgcct.shop', 'type': 'domain-name', 'value': 'edvhukkkmvgcct.shop'}, {'id': 'domain-name--dustfightergame.com', 'type': 'domain-name', 'value': 'dustfightergame.com'}, {'id': 'domain-name--dintrinnssports.shop', 'type': 'domain-name', 'value': 'dintrinnssports.shop'}, {'id': 'domain-name--batverssaports.shop', 'type': 'domain-name', 'value': 'batverssaports.shop'}, {'id': 'domain-name--astrosounsports.shop', 'type': 'domain-name', 'value': 'astrosounsports.shop'}, {'id': 'domain-name--1h343lkxf4pikjd.dad', 'type': 'domain-name', 'value': '1h343lkxf4pikjd.dad'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--delphidigital.org', 'type': 'domain-name', 'value': 'delphidigital.org'}]}
# Actual: {'objects': [{'id': 'domain-name--yourtube.fun', 'type': 'domain-name', 'value': 'yourtube.fun'}, {'id': 'domain-name--ytcache.fun', 'type': 'domain-name', 'value': 'ytcache.fun'}, {'id': 'domain-name--youbesttube.gq', 'type': 'domain-name', 'value': 'youbesttube.gq'}, {'id': 'domain-name--wispields.ml', 'type': 'domain-name', 'value': 'wispields.ml'}, {'id': 'domain-name--wpcache.ml', 'type': 'domain-name', 'value': 'wpcache.ml'}, {'id': 'domain-name--whatsappvideos.ml', 'type': 'domain-name', 'value': 'whatsappvideos.ml'}, {'id': 'domain-name--videosdahora.fun', 'type': 'domain-name', 'value': 'videosdahora.fun'}, {'id': 'domain-name--virvida.com', 'type': 'domain-name', 'value': 'virvida.com'}, {'id': 'domain-name--videocdn.fun', 'type': 'domain-name', 'value': 'videocdn.fun'}, {'id': 'domain-name--toptube.fun', 'type': 'domain-name', 'value': 'toptube.fun'}, {'id': 'domain-name--uwatchtube.ml', 'type': 'domain-name', 'value': 'uwatchtube.ml'}, {'id': 'domain-name--tecnowebclub.ga', 'type': 'domain-name', 'value': 'tecnowebclub.ga'}, {'id': 'domain-name--techyclub.in', 'type': 'domain-name', 'value': 'techyclub.in'}, {'id': 'domain-name--tcache.ml', 'type': 'domain-name', 'value': 'tcache.ml'}, {'id': 'domain-name--tapcache.ml', 'type': 'domain-name', 'value': 'tapcache.ml'}, {'id': 'domain-name--supercache.top', 'type': 'domain-name', 'value': 'supercache.top'}, {'id': 'domain-name--streamix.tv', 'type': 'domain-name', 'value': 'streamix.tv'}, {'id': 'domain-name--satishmoheyt.ml', 'type': 'domain-name', 'value': 'satishmoheyt.ml'}, {'id': 'domain-name--satishmoheyt.in', 'type': 'domain-name', 'value': 'satishmoheyt.in'}, {'id': 'domain-name--primesinfo.ml', 'type': 'domain-name', 'value': 'primesinfo.ml'}, {'id': 'domain-name--poptube.fun', 'type': 'domain-name', 'value': 'poptube.fun'}, {'id': 'domain-name--primesinfo.com', 'type': 'domain-name', 'value': 'primesinfo.com'}, {'id': 'domain-name--pharmabeaver.ml', 'type': 'domain-name', 'value': 'pharmabeaver.ml'}, {'id': 'domain-name--newsworldcity.ml', 'type': 'domain-name', 'value': 'newsworldcity.ml'}, {'id': 'domain-name--pharmabeaver.com', 'type': 'domain-name', 'value': 'pharmabeaver.com'}, {'id': 'domain-name--newsworldcity.com', 'type': 'domain-name', 'value': 'newsworldcity.com'}, {'id': 'domain-name--mikerin.ml', 'type': 'domain-name', 'value': 'mikerin.ml'}, {'id': 'domain-name--myplayer.ml', 'type': 'domain-name', 'value': 'myplayer.ml'}, {'id': 'domain-name--mikerin.com', 'type': 'domain-name', 'value': 'mikerin.com'}, {'id': 'domain-name--melhoresdomomento.ml', 'type': 'domain-name', 'value': 'melhoresdomomento.ml'}, {'id': 'domain-name--megasearch.gq', 'type': 'domain-name', 'value': 'megasearch.gq'}, {'id': 'domain-name--megacdn.top', 'type': 'domain-name', 'value': 'megacdn.top'}, {'id': 'domain-name--megacdn.ml', 'type': 'domain-name', 'value': 'megacdn.ml'}, {'id': 'domain-name--mcdn.ga', 'type': 'domain-name', 'value': 'mcdn.ga'}, {'id': 'domain-name--mbyte.gq', 'type': 'domain-name', 'value': 'mbyte.gq'}, {'id': 'domain-name--maxcache.ml', 'type': 'domain-name', 'value': 'maxcache.ml'}, {'id': 'domain-name--livrosdereceita.ml', 'type': 'domain-name', 'value': 'livrosdereceita.ml'}, {'id': 'domain-name--kbyte.ml', 'type': 'domain-name', 'value': 'kbyte.ml'}, {'id': 'domain-name--jscache.live', 'type': 'domain-name', 'value': 'jscache.live'}, {'id': 'domain-name--journeywithvision.ga', 'type': 'domain-name', 'value': 'journeywithvision.ga'}, {'id': 'domain-name--journeywithvision.com', 'type': 'domain-name', 'value': 'journeywithvision.com'}, {'id': 'domain-name--investwell.site', 'type': 'domain-name', 'value': 'investwell.site'}, {'id': 'domain-name--jestick.ml', 'type': 'domain-name', 'value': 'jestick.ml'}, {'id': 'domain-name--investwell.ml', 'type': 'domain-name', 'value': 'investwell.ml'}, {'id': 'domain-name--hypercdn3.ml', 'type': 'domain-name', 'value': 'hypercdn3.ml'}, {'id': 'domain-name--hypercdn.ml', 'type': 'domain-name', 'value': ...
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain-dogmupdate.com', 'type': 'domain-name', 'value': 'dogmupdate.com'}, {'id': 'domain-name--domain-flexiblemaria.com', 'type': 'domain-name', 'value': 'flexiblemaria.com'}, {'id': 'domain-name--domain-mylittlecabbage.net', 'type': 'domain-name', 'value': 'mylittlecabbage.net'}, {'id': 'domain-name--domain-jenniferwelsh.com', 'type': 'domain-name', 'value': 'jenniferwelsh.com'}, {'id': 'domain-name--domain-linktoxic34.com', 'type': 'domain-name', 'value': 'linktoxic34.com'}, {'id': 'domain-name--domain-rockcreekdds.com', 'type': 'domain-name', 'value': 'rockcreekdds.com'}]}
# Actual: {'objects': [{'id': 'domain-name--mylittlecabbage.net', 'type': 'domain-name', 'value': 'mylittlecabbage.net'}, {'id': 'domain-name--linktoxic34.com', 'type': 'domain-name', 'value': 'linktoxic34.com'}, {'id': 'domain-name--jenniferwelsh.com', 'type': 'domain-name', 'value': 'jenniferwelsh.com'}, {'id': 'domain-name--flexiblemaria.com', 'type': 'domain-name', 'value': 'flexiblemaria.com'}, {'id': 'domain-name--dogmupdate.com', 'type': 'domain-name', 'value': 'dogmupdate.com'}]}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain-6014.anonymousrat5.com', 'type': 'domain-name', 'value': '6014.anonymousrat5.com'}, {'id': 'domain-name--domain-6014.anonymousrat6.com', 'type': 'domain-name', 'value': '6014.anonymousrat6.com'}, {'id': 'domain-name--domain-6014.anonymousrat7.com', 'type': 'domain-name', 'value': '6014.anonymousrat7.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain-6014.anonymousrat5.com', 'type': 'domain-name', 'value': '6014.anonymousrat5.com'}, {'id': 'domain-name--domain-6014.anonymousrat6.com', 'type': 'domain-name', 'value': '6014.anonymousrat6.com'}, {'id': 'domain-name--domain-6014.anonymousrat7.com', 'type': 'domain-name', 'value': '6014.anonymousrat7.com'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--xscapezo.capetown', 'type': 'domain-name', 'value': 'xscapezo.capetown'}, {'id': 'domain-name--domain--serverdops.ddns.net', 'type': 'domain-name', 'value': 'serverdops.ddns.net'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--xscapezo.capetown', 'type': 'domain-name', 'value': 'xscapezo.capetown'}, {'id': 'domain-name--domain--serverdops.ddns.net', 'type': 'domain-name', 'value': 'serverdops.ddns.net'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--xscapezo.capetown', 'type': 'domain-name', 'value': 'xscapezo.capetown'}, {'id': 'domain-name--domain--serverdops.ddns.net', 'type': 'domain-name', 'value': 'serverdops.ddns.net'}]}
# Actual: {'objects': []}
#
#
#
# Predicted: {'objects': [{'id': 'domain-name--domain--xscapezo.capetown', 'type': 'domain-name', 'value': 'xscapezo.capetown'}, {'id': 'domain-name--domain--serverdops.ddns.net', 'type': 'domain-name', 'value': 'serverdops.ddns.net'}]}
# Actual: {'objects': []}

# %%
for i in range(len(preds)-1):
    if preds[i]==preds[i+1]:
        print(i)

# %%
print(preds[0])
# Out:
# ```json
# {
#   "objects": [
#     {
#       "id": "domain-voipfaqs.com",
#       "type": "domain",
#       "value": "voipfaqs.com"
#     },
#     {
#       "id": "domain-teamsbusiness.org",
#       "type": "domain",
#       "value": "teamsbusiness.org"
#     },
#     {
#       "id": "domain-locallyhyped.com",
#       "type": "domain",
#       "value": "locallyhyped.com"
#     }
#   ]
# }
# ```

# %%
print(preds[1])
# Out:
# The Play ransomware team that stole data from the IACS environment used the following TTPs (ATT&CK® techniques) in their attack chain:
#
# | ATT&CK ID | Technique | How it was used |
# |-----------|-----------|-----------------|
# | **T1568.002** | **Domain Generation Algorithms** | The Play campaign used a hidden link‑shortener service (Prolific Puma) that generated dozens of short domains to host the download payload and C2 URLs. |
# | **T1489** | **Service Stop** | The Linux variant shuts down ESXi services (via `esxcli`) and stops all VMs before encrypting. |
# | **T1083** | **File & Directory Discovery** | The malware enumerates VM files and other targets, collecting a list of items to encrypt. |
# | **T1491.001** | **Internal Defacement** | The ransom note (PLAY_Readme.txt) is written to the ESXi host client and console, and a Tor‑link is supplied to the victim. |
# | **T1041** | **Exfiltration Over C2 Channel** | The Coroxy backdoor (and the Play Linux binary) communicates with the remote C2 server over a stealthy channel. |
# | **T1059.004** | **Unix Shell** | The Play ransomware uses a Unix shell to launch commands (e.g., `esxcli` for VM shutdown, file deletion). |
# | **T1486** | **Data Encrypted for Impact** | All VM disk files (.vmdk, .vmem, .vmsd, etc.) are encrypted and given the .PLAY extension. |
# | **T1570** | **Lateral Tool Transfer** | The payload pulls the Coroxy backdoor and the Play binary into the target host during execution. |
# | **T1070.004** | **File Deletion** | The malware deletes original files or clears logs to hide its activity. |
# | **T1046** | **Network Service Scanning** | The tool probes the network for open services (e.g., VMware, ESXi ports). |
# | **T1105** | **Ingress Tool Transfer** | The Play binary is transferred over the network to the victim host (e.g., via the C2 channel). |
#
# These techniques together constitute the full TTP profile of the Play ransomware group that stole data from the industrial control system.

# %%
preds4eval = []
failed_preds = []
pattern = r'\{\s*"id"\s*:\s*"[^"]*"\s*,\s*"type"\s*:\s*"[^"]*"\s*,\s*"value"\s*:\s*"[^"]*"\s*\}'

for p in preds[:2]:

    p = p.lower().replace("\t", "")

    try:
        objects = json.loads(p)["objects"]
    except:
        objects = re.findall(pattern, p)
        if not objects and '"objects": []' not in p:
            failed_preds.append(p)
        elif objects:
            objects = [json.loads(obj) for obj in objects]
    
    preds4eval.append(
            {
                "objects":objects
                }
        )

# %%
len(preds4eval)
# Out:
# 2

# %%
preds4eval[0]
# Out:
# {'objects': [{'id': 'domain-voipfaqs.com',
#    'type': 'domain',
#    'value': 'voipfaqs.com'},
#   {'id': 'domain-teamsbusiness.org',
#    'type': 'domain',
#    'value': 'teamsbusiness.org'},
#   {'id': 'domain-locallyhyped.com',
#    'type': 'domain',
#    'value': 'locallyhyped.com'}]}

# %%
preds4eval[1]
# Out:
# {'objects': []}
